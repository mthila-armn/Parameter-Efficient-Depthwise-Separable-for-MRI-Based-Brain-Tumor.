# %% [markdown]
# # **CoAtNet0**

# %%
# ========================
# 0) Install necessary libraries
# ========================
# !pip -q install split-folders keras-cv-attention-models tf-keras

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # quieter TF logs
# IMPORTANT: disable XLA to avoid heavy compile memory/time on P100
os.environ["TF_XLA_FLAGS"] = ""  # ensure no XLA JIT from env
# IMPORTANT for keras-cv-attention-models on TF backend
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tensorflow as tf

# Deterministic-ish runs to reduce jitter
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU memory growth: prevents big upfront allocation + restart
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]

def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten with simple near-duplicate removal (per class)
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split (image-wise split; param count is independent of image size)
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Activation,
    GaussianNoise, Input, Reshape, Multiply, Layer, Concatenate, MaxPooling2D, Conv2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

# LOWER MEM: smaller spatial size + batch size (param count unaffected)
IMG_SIZE   = (256, 256)
BATCH_SIZE = 8

INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Aug controls (annealed later)
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se / re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) Backbone: CoAtNet0 (frozen) + light head with ParamPad to hit EXACT trainables
# ========================

class SqueezeExcite(Layer):
    def __init__(self, ratio=16, **kwargs):
        super().__init__(**kwargs); self.ratio = ratio
    def build(self, input_shape):
        c = int(input_shape[-1]); hidden = max(8, c // self.ratio)
        self.fc1 = Dense(hidden, activation='relu'); self.fc2 = Dense(c, activation='sigmoid')
        super().build(input_shape)
    def call(self, x):
        s = GlobalAveragePooling2D()(x); s = self.fc1(s); s = self.fc2(s)
        s = Reshape((1,1,-1))(s); return Multiply()([x, s])

class SpatialGate(Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs); self.conv=None
    def build(self, input_shape):
        self.conv = Conv2D(1, kernel_size=7, padding="same", use_bias=True)
        super().build(input_shape)
    def call(self, x):
        avg = tf.reduce_mean(x, axis=-1, keepdims=True)
        mx  = tf.reduce_max(x,  axis=-1, keepdims=True)
        s   = Concatenate(axis=-1)([avg, mx])
        s   = self.conv(s); s = tf.nn.sigmoid(s)
        return Multiply()([x, s])

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        if hasattr(self, "pad_w"): return x + tf.reduce_sum(self.pad_w) * tf.cast(0.0, x.dtype)
        return x

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

def build_model_coatnet0(num_classes, img_size):
    inputs = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x = GaussianNoise(0.01)(inputs)

    # Prefer KCAM CoAtNet0
    try:
        from keras_cv_attention_models import coatnet
        backbone = coatnet.CoAtNet0(input_shape=(img_size[0], img_size[1], 3),
                                    num_classes=0, pretrained="imagenet")
        print("[INFO] Using KCAM CoAtNet0 backbone.")
    except Exception as e:
        raise RuntimeError("CoAtNet0 backbone not available. Ensure keras-cv-attention-models installed.") from e

    backbone.trainable = False  # freeze backbone

    feat = backbone(x)
    if isinstance(feat, (list, tuple)):
        feat = feat[-1]

    gap = GlobalAveragePooling2D(name="GAP")(feat)
    xh = Dense(256, use_bias=True)(gap)
    xh = Activation(gelu)(xh)
    xh = Dropout(0.35)(xh)
    out_logits = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(xh)

    model = Model(inputs, out_logits, name="coatnet0_head")

    # Enforce EXACT trainable params = 1,461,587
    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Reduce head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out_logits)
        model = Model(inputs, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")
    return model

# Clear any old graph (helps on notebook reruns)
tf.keras.backend.clear_session()
model = build_model_coatnet0(num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss  (dtype-safe for mixed precision)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    # ---- FIX: ensure consistent dtype under mixed precision ----
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks (simplified for stability)
# ========================
early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_backbone_model.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    # gentler schedule reduces big swings
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Light evaluation (memory-safe): current best-restored model + 5x TTA (streamed)
# ========================
print("\nEvaluating best-restored model (no reload to avoid custom-objects issues):")
std_model = model  # EarlyStopping restored best weights

from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

# streamed TTA (no pre-staging arrays)
def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            if fn is None:
                xb = x
            else:
                xb = np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

# modest set of TTA ops (kept small for stability + speed)
def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy (CoAtNet0 + 5xTTA): {acc*100:.2f}%")

# Confusion matrix & report
cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title('Confusion Matrix (VAL, CoAtNet0+TTA)'); plt.show()
print("\nClassification Report (VAL, CoAtNet0+TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save final model
# ========================
final_model_path = "/kaggle/working/coatnet0_paramfixed.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.6/802.6 kB 30.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.0 MB/s eta 0:00:00
# 2025-10-02 08:05:47.199511: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759392347.344062      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759392347.386883      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 7458.19 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# I0000 00:00:1759392405.176691      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/coatnet/coatnet0_224_imagenet.h5
# 93747824/93747824 [==============================] - 1s 0us/step
# >>>> Load pretrained from: /root/.keras/models/coatnet0_224_imagenet.h5
# >>>> Reload mismatched weights: 224 -> (256, 256)
# >>>> Reload layer: stack_3_block_1_mhsa_pos_emb
# >>>> Reload layer: stack_3_block_2_mhsa_pos_emb
# >>>> Reload layer: stack_3_block_3_mhsa_pos_emb
# >>>> Reload layer: stack_3_block_4_mhsa_pos_emb
# >>>> Reload layer: stack_3_block_5_mhsa_pos_emb
# >>>> Reload layer: stack_4_block_1_mhsa_pos_emb
# >>>> Reload layer: stack_4_block_2_mhsa_pos_emb
# [INFO] Using KCAM CoAtNet0 backbone.
# [ParamTarget] Trainable BEFORE pad: 197,892
# [ParamTarget] Added ParamPad with 1,263,695 -> final trainables = 1,461,587
# Model: "coatnet0_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)       0
#  ise)
#
#  coatnet0 (Functional)       (None, 8, 8, 768)         22536762
#
#  GAP (GlobalAveragePooling2  (None, 768)               0
#  D)
#
#  dense (Dense)               (None, 256)               196864
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  predictions (Dense)         (None, 4)                 1028
#
#  param_pad (ParamPad)        (None, 4)                 1263695
#
# =================================================================
# Total params: 23998349 (91.55 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 22536762 (85.97 MB)
# _________________________________________________________________
# Epoch 1/50
# I0000 00:00:1759392423.786318     107 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   3/541 [..............................] - ETA: 24s - loss: 2.1021 - accuracy: 0.2917
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759392427.919187     105 service.cc:148] XLA service 0x7fc52c3736a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759392427.920006     105 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759392428.132507     105 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 1.1988 - accuracy: 0.5300
# Epoch 1: val_accuracy improved from -inf to 0.76091, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 95s 145ms/step - loss: 1.1988 - accuracy: 0.5300 - val_loss: 0.7901 - val_accuracy: 0.7609
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6407 - accuracy: 0.7994
# Epoch 2: val_accuracy improved from 0.76091 to 0.81497, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 75s 139ms/step - loss: 0.6407 - accuracy: 0.7994 - val_loss: 0.6370 - val_accuracy: 0.8150
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6652 - accuracy: 0.7984
# Epoch 3: val_accuracy improved from 0.81497 to 0.84407, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 95s 175ms/step - loss: 0.6652 - accuracy: 0.7984 - val_loss: 0.5676 - val_accuracy: 0.8441
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6158 - accuracy: 0.8287
# Epoch 4: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 95s 175ms/step - loss: 0.6158 - accuracy: 0.8287 - val_loss: 0.5733 - val_accuracy: 0.8399
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6021 - accuracy: 0.8315
# Epoch 5: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 93s 173ms/step - loss: 0.6021 - accuracy: 0.8315 - val_loss: 0.6032 - val_accuracy: 0.8170
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5877 - accuracy: 0.8396
# Epoch 6: val_accuracy improved from 0.84407 to 0.86902, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 96s 178ms/step - loss: 0.5877 - accuracy: 0.8396 - val_loss: 0.5075 - val_accuracy: 0.8690
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5700 - accuracy: 0.8456
# Epoch 7: val_accuracy did not improve from 0.86902
# 541/541 [==============================] - 95s 175ms/step - loss: 0.5700 - accuracy: 0.8456 - val_loss: 0.5333 - val_accuracy: 0.8586
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5370 - accuracy: 0.8621
# Epoch 8: val_accuracy improved from 0.86902 to 0.89189, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 93s 171ms/step - loss: 0.5370 - accuracy: 0.8621 - val_loss: 0.4686 - val_accuracy: 0.8919
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5506 - accuracy: 0.8551
# Epoch 9: val_accuracy improved from 0.89189 to 0.89397, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 94s 175ms/step - loss: 0.5506 - accuracy: 0.8551 - val_loss: 0.4549 - val_accuracy: 0.8940
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5396 - accuracy: 0.8630
# Epoch 10: val_accuracy improved from 0.89397 to 0.89605, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 95s 175ms/step - loss: 0.5396 - accuracy: 0.8630 - val_loss: 0.4599 - val_accuracy: 0.8960
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5451 - accuracy: 0.8422
# Epoch 11: val_accuracy did not improve from 0.89605
# 541/541 [==============================] - 109s 201ms/step - loss: 0.5451 - accuracy: 0.8422 - val_loss: 0.4266 - val_accuracy: 0.8877
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5024 - accuracy: 0.8604
# Epoch 12: val_accuracy did not improve from 0.89605
# 541/541 [==============================] - 105s 194ms/step - loss: 0.5024 - accuracy: 0.8604 - val_loss: 0.4220 - val_accuracy: 0.8857
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5288 - accuracy: 0.8565
# Epoch 13: val_accuracy did not improve from 0.89605
# 541/541 [==============================] - 107s 198ms/step - loss: 0.5288 - accuracy: 0.8565 - val_loss: 0.5121 - val_accuracy: 0.8420
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5176 - accuracy: 0.8561
# Epoch 14: val_accuracy improved from 0.89605 to 0.89813, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 108s 200ms/step - loss: 0.5176 - accuracy: 0.8561 - val_loss: 0.3810 - val_accuracy: 0.8981
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5130 - accuracy: 0.8660
# Epoch 15: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 108s 200ms/step - loss: 0.5130 - accuracy: 0.8660 - val_loss: 0.5200 - val_accuracy: 0.8565
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4994 - accuracy: 0.8690
# Epoch 16: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 106s 196ms/step - loss: 0.4994 - accuracy: 0.8690 - val_loss: 0.3901 - val_accuracy: 0.8919
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4895 - accuracy: 0.8734
# Epoch 17: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 104s 192ms/step - loss: 0.4895 - accuracy: 0.8734 - val_loss: 0.4854 - val_accuracy: 0.8565
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4949 - accuracy: 0.8706
# Epoch 18: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 106s 196ms/step - loss: 0.4949 - accuracy: 0.8706 - val_loss: 0.4352 - val_accuracy: 0.8794
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4915 - accuracy: 0.8743
# Epoch 19: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 106s 196ms/step - loss: 0.4915 - accuracy: 0.8743 - val_loss: 0.4279 - val_accuracy: 0.8794
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4976 - accuracy: 0.8757
# Epoch 20: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 106s 196ms/step - loss: 0.4976 - accuracy: 0.8757 - val_loss: 0.4224 - val_accuracy: 0.8753
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4812 - accuracy: 0.8801
# Epoch 21: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 105s 194ms/step - loss: 0.4812 - accuracy: 0.8801 - val_loss: 0.4074 - val_accuracy: 0.8898
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4949 - accuracy: 0.8646
# Epoch 22: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 106s 197ms/step - loss: 0.4949 - accuracy: 0.8646 - val_loss: 0.4274 - val_accuracy: 0.8877
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4686 - accuracy: 0.8824
# Epoch 23: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 105s 194ms/step - loss: 0.4686 - accuracy: 0.8824 - val_loss: 0.4314 - val_accuracy: 0.8815
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4708 - accuracy: 0.8790
# Epoch 24: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 105s 194ms/step - loss: 0.4708 - accuracy: 0.8790 - val_loss: 0.4134 - val_accuracy: 0.8877
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4637 - accuracy: 0.8822
# Epoch 25: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 105s 194ms/step - loss: 0.4637 - accuracy: 0.8822 - val_loss: 0.4542 - val_accuracy: 0.8794
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4446 - accuracy: 0.8915
# Epoch 26: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 105s 195ms/step - loss: 0.4446 - accuracy: 0.8915 - val_loss: 0.3916 - val_accuracy: 0.8898
# Epoch 26: early stopping
# Restoring model weights from the end of the best epoch: 14.
# Evaluating best-restored model (no reload to avoid custom-objects issues):
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (CoAtNet0 + 5xTTA): 90.44%
# Classification Report (VAL, CoAtNet0+TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.9569    0.9250    0.9407       120
#   meningioma     0.9118    0.7440    0.8194       125
#     no_tumor     0.9286    0.9891    0.9579        92
#    pituitary     0.8485    0.9722    0.9061       144
#
#     accuracy                         0.9044       481
#    macro avg     0.9114    0.9076    0.9060       481
# weighted avg     0.9073    0.9044    0.9021       481
#
# Saved base model to: /kaggle/working/coatnet0_paramfixed.keras

# %% [markdown]
# # **NextViT S**

# %%
# ========================
# 0) Install necessary libraries
# ========================
# !pip -q install split-folders keras-cv-attention-models tf-keras

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # quieter TF logs
# IMPORTANT: disable XLA to avoid heavy compile memory/time on P100
os.environ["TF_XLA_FLAGS"] = ""  # ensure no XLA JIT from env
# IMPORTANT for keras-cv-attention-models on TF backend
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tensorflow as tf

# Deterministic-ish runs to reduce jitter
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU memory growth: prevents big upfront allocation + restart
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]

def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten with simple near-duplicate removal (per class)
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split (image-wise split; param count is independent of image size)
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, Activation,
    GaussianNoise, Input, Reshape, Multiply, Layer, Concatenate, Conv2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

# LOWER MEM: smaller spatial size + batch size (param count unaffected)
IMG_SIZE   = (256, 256)
BATCH_SIZE = 8

INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Gentler aug knobs (annealed later)
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se / re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) Backbone: NextViT-S (with fallback)
# ========================

# minor utilities (kept from earlier; safe even if unused)
class SqueezeExcite(Layer):
    def __init__(self, ratio=16, **kwargs):
        super().__init__(**kwargs); self.ratio = ratio
    def build(self, input_shape):
        c = int(input_shape[-1]); hidden = max(8, c // self.ratio)
        self.fc1 = Dense(hidden, activation='relu'); self.fc2 = Dense(c, activation='sigmoid')
        super().build(input_shape)
    def call(self, x):
        s = GlobalAveragePooling2D()(x); s = self.fc1(s); s = self.fc2(s)
        s = Reshape((1,1,-1))(s); return Multiply()([x, s])

class SpatialGate(Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs); self.conv=None
    def build(self, input_shape):
        self.conv = Conv2D(1, kernel_size=7, padding="same", use_bias=True)
        super().build(input_shape)
    def call(self, x):
        avg = tf.reduce_mean(x, axis=-1, keepdims=True)
        mx  = tf.reduce_max(x,  axis=-1, keepdims=True)
        s   = Concatenate(axis=-1)([avg, mx])
        s   = self.conv(s); s = tf.nn.sigmoid(s)
        return Multiply()([x, s])

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        if hasattr(self, "pad_w"): return x + tf.reduce_sum(self.pad_w) * tf.cast(0.0, x.dtype)
        return x

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

# Only one option requested now
BACKBONE_NAME = 'nextvit_s'  # NextViT Small

def build_model_with_nextvit_s(num_classes, img_size):
    inputs = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x = GaussianNoise(0.01)(inputs)

    # Try NextViT-S from keras-cv-attention-models; fallback to ConvNeXt Tiny
    backbone = None
    try:
        from keras_cv_attention_models import nextvit
        # KCAM models return a Keras model; set num_classes=0 to get features
        backbone = nextvit.NextViTSmall(input_shape=(img_size[0], img_size[1], 3),
                                        num_classes=0, pretrained="imagenet")
        print("[INFO] Using NextViT-S from keras-cv-attention-models.")
    except Exception as e:
        print("[WARN] NextViT-S unavailable, falling back to ConvNeXt-Tiny.")
        try:
            from keras_cv_attention_models import convnext
            backbone = convnext.ConvNeXtTiny(input_shape=(img_size[0], img_size[1], 3),
                                             num_classes=0, pretrained="imagenet")
        except Exception:
            # Final fallback: tf.keras.applications ConvNeXtTiny (no num_classes arg)
            from tensorflow.keras.applications import convnext as tf_cnv
            backbone = tf_cnv.ConvNeXtTiny(include_top=False, weights="imagenet",
                                           input_shape=(img_size[0], img_size[1], 3))
    backbone.trainable = False

    feat = backbone(x)
    if isinstance(feat, (list, tuple)):
        feat = feat[-1]

    gap = GlobalAveragePooling2D(name="GAP")(feat)
    xh  = Dense(256, use_bias=True)(gap)
    xh  = Activation(gelu)(xh)
    xh  = Dropout(0.35)(xh)
    out_logits = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(xh)

    model = Model(inputs, out_logits, name="nextvit_s_head")

    # Enforce EXACT trainable params = 1,461,587
    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Reduce head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out_logits)
        model = Model(inputs, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")
    return model

# Clear any old graph (helps on notebook reruns)
tf.keras.backend.clear_session()
model = build_model_with_nextvit_s(num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss  (dtype-safe for mixed precision)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    # dtype-safe under mixed precision
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

MIXUP_P = [0.00]; CUTMIX_P = [0.00]; ERASE_P = [0.00]; CLAHE_P = [0.00]
mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks (simplified for stability)
# ========================
early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_nextvit_s.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    # gentler schedule reduces big swings
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Evaluation with 5x TTA (using best-restored in-memory model)
# ========================
print("\nEvaluating best-restored model (no reload to avoid custom-objects issues):")
std_model = model  # EarlyStopping restored best weights

from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            xb = x if fn is None else np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy (NextViT-S + 5xTTA): {acc*100:.2f}%")

# Confusion matrix & report
cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title('Confusion Matrix (VAL, NextViT-S + TTA)'); plt.show()
print("\nClassification Report (VAL, NextViT-S + TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save final model
# ========================
final_model_path = "/kaggle/working/nextvit_s_paramfixed.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 4.4 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.6/802.6 kB 19.4 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.7 MB/s eta 0:00:00
# 2025-10-03 21:18:12.538237: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759526292.721302      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759526292.774813      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 7268.94 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# [WARN] NextViT-S unavailable, falling back to ConvNeXt-Tiny.
# I0000 00:00:1759526357.941477      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/convnext/convnext_tiny_imagenet.h5
# 114829704/114829704 [==============================] - 1s 0us/step
# >>>> Load pretrained from: /root/.keras/models/convnext_tiny_imagenet.h5
# [ParamTarget] Trainable BEFORE pad: 197,892
# [ParamTarget] Added ParamPad with 1,263,695 -> final trainables = 1,461,587
# Model: "nextvit_s_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)       0
#  ise)
#
#  convnext_tiny (Functional)  (None, 8, 8, 768)         27818592
#
#  GAP (GlobalAveragePooling2  (None, 768)               0
#  D)
#
#  dense (Dense)               (None, 256)               196864
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  predictions (Dense)         (None, 4)                 1028
#
#  param_pad (ParamPad)        (None, 4)                 1263695
#
# =================================================================
# Total params: 29280179 (111.70 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 27818592 (106.12 MB)
# _________________________________________________________________
# Epoch 1/50
# E0000 00:00:1759526377.199901      36 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape innextvit_s_head/convnext_tiny/stack1_block2_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1759526377.960728     106 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   2/541 [..............................] - ETA: 33s - loss: 3.2595 - accuracy: 0.3125
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759526381.378402     107 service.cc:148] XLA service 0x78b98878df60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759526381.379132     107 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759526381.586269     107 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 1.6191 - accuracy: 0.3941
# Epoch 1: val_accuracy improved from -inf to 0.67568, saving model to /kaggle/working/best_nextvit_s.keras
# 541/541 [==============================] - 101s 155ms/step - loss: 1.6191 - accuracy: 0.3941 - val_loss: 0.8946 - val_accuracy: 0.6757
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 0.8544 - accuracy: 0.7096
# Epoch 2: val_accuracy improved from 0.67568 to 0.73181, saving model to /kaggle/working/best_nextvit_s.keras
# 541/541 [==============================] - 80s 147ms/step - loss: 0.8544 - accuracy: 0.7096 - val_loss: 0.7756 - val_accuracy: 0.7318
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 0.7871 - accuracy: 0.7528
# Epoch 3: val_accuracy improved from 0.73181 to 0.78794, saving model to /kaggle/working/best_nextvit_s.keras
# 541/541 [==============================] - 99s 183ms/step - loss: 0.7871 - accuracy: 0.7528 - val_loss: 0.6914 - val_accuracy: 0.7879
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 0.7246 - accuracy: 0.7852
# Epoch 4: val_accuracy did not improve from 0.78794
# 541/541 [==============================] - 100s 184ms/step - loss: 0.7246 - accuracy: 0.7852 - val_loss: 0.6724 - val_accuracy: 0.7838
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6850 - accuracy: 0.7959
# Epoch 5: val_accuracy improved from 0.78794 to 0.81497, saving model to /kaggle/working/best_nextvit_s.keras
# 541/541 [==============================] - 96s 178ms/step - loss: 0.6850 - accuracy: 0.7959 - val_loss: 0.6340 - val_accuracy: 0.8150
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6636 - accuracy: 0.8109
# Epoch 6: val_accuracy did not improve from 0.81497
# 541/541 [==============================] - 97s 179ms/step - loss: 0.6636 - accuracy: 0.8109 - val_loss: 0.7235 - val_accuracy: 0.7672
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6481 - accuracy: 0.8107
# Epoch 7: val_accuracy improved from 0.81497 to 0.84407, saving model to /kaggle/working/best_nextvit_s.keras
# 541/541 [==============================] - 100s 184ms/step - loss: 0.6481 - accuracy: 0.8107 - val_loss: 0.5665 - val_accuracy: 0.8441
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6203 - accuracy: 0.8290
# Epoch 8: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 102s 188ms/step - loss: 0.6203 - accuracy: 0.8290 - val_loss: 0.6068 - val_accuracy: 0.8441
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5886 - accuracy: 0.8454
# Epoch 9: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 100s 184ms/step - loss: 0.5886 - accuracy: 0.8454 - val_loss: 0.6327 - val_accuracy: 0.8025
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6005 - accuracy: 0.8431
# Epoch 10: val_accuracy improved from 0.84407 to 0.85447, saving model to /kaggle/working/best_nextvit_s.keras
# 541/541 [==============================] - 103s 190ms/step - loss: 0.6005 - accuracy: 0.8431 - val_loss: 0.5511 - val_accuracy: 0.8545
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6133 - accuracy: 0.8179
# Epoch 11: val_accuracy did not improve from 0.85447
# 541/541 [==============================] - 116s 214ms/step - loss: 0.6133 - accuracy: 0.8179 - val_loss: 0.5578 - val_accuracy: 0.8150
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6149 - accuracy: 0.8234
# Epoch 12: val_accuracy did not improve from 0.85447
# 541/541 [==============================] - 115s 213ms/step - loss: 0.6149 - accuracy: 0.8234 - val_loss: 0.5038 - val_accuracy: 0.8378
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6019 - accuracy: 0.8250
# Epoch 13: val_accuracy did not improve from 0.85447
# 541/541 [==============================] - 113s 209ms/step - loss: 0.6019 - accuracy: 0.8250 - val_loss: 0.5700 - val_accuracy: 0.8316
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5891 - accuracy: 0.8225
# Epoch 14: val_accuracy improved from 0.85447 to 0.85655, saving model to /kaggle/working/best_nextvit_s.keras
# 541/541 [==============================] - 113s 209ms/step - loss: 0.5891 - accuracy: 0.8225 - val_loss: 0.4893 - val_accuracy: 0.8565
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5874 - accuracy: 0.8280
# Epoch 15: val_accuracy did not improve from 0.85655
# 541/541 [==============================] - 110s 203ms/step - loss: 0.5874 - accuracy: 0.8280 - val_loss: 0.5675 - val_accuracy: 0.8378
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5843 - accuracy: 0.8371
# Epoch 16: val_accuracy did not improve from 0.85655
# 541/541 [==============================] - 109s 202ms/step - loss: 0.5843 - accuracy: 0.8371 - val_loss: 0.5483 - val_accuracy: 0.8358
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5591 - accuracy: 0.8392
# Epoch 17: val_accuracy did not improve from 0.85655
# 541/541 [==============================] - 108s 199ms/step - loss: 0.5591 - accuracy: 0.8392 - val_loss: 0.5216 - val_accuracy: 0.8503
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5609 - accuracy: 0.8334
# Epoch 18: val_accuracy did not improve from 0.85655
# 541/541 [==============================] - 111s 204ms/step - loss: 0.5609 - accuracy: 0.8334 - val_loss: 0.5802 - val_accuracy: 0.8274
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5478 - accuracy: 0.8436
# Epoch 19: val_accuracy improved from 0.85655 to 0.85863, saving model to /kaggle/working/best_nextvit_s.keras
# 541/541 [==============================] - 112s 207ms/step - loss: 0.5478 - accuracy: 0.8436 - val_loss: 0.5274 - val_accuracy: 0.8586
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5535 - accuracy: 0.8415
# Epoch 20: val_accuracy improved from 0.85863 to 0.87526, saving model to /kaggle/working/best_nextvit_s.keras
# 541/541 [==============================] - 112s 206ms/step - loss: 0.5535 - accuracy: 0.8415 - val_loss: 0.4967 - val_accuracy: 0.8753
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5585 - accuracy: 0.8408
# Epoch 21: val_accuracy did not improve from 0.87526
# 541/541 [==============================] - 111s 206ms/step - loss: 0.5585 - accuracy: 0.8408 - val_loss: 0.5571 - val_accuracy: 0.8462
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5443 - accuracy: 0.8442
# Epoch 22: val_accuracy did not improve from 0.87526
# 541/541 [==============================] - 110s 203ms/step - loss: 0.5443 - accuracy: 0.8442 - val_loss: 0.4825 - val_accuracy: 0.8753
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5610 - accuracy: 0.8355
# Epoch 23: val_accuracy did not improve from 0.87526
# 541/541 [==============================] - 111s 205ms/step - loss: 0.5610 - accuracy: 0.8355 - val_loss: 0.4763 - val_accuracy: 0.8753
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5487 - accuracy: 0.8489
# Epoch 24: val_accuracy improved from 0.87526 to 0.89605, saving model to /kaggle/working/best_nextvit_s.keras
# 541/541 [==============================] - 111s 204ms/step - loss: 0.5487 - accuracy: 0.8489 - val_loss: 0.4578 - val_accuracy: 0.8960
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5343 - accuracy: 0.8604
# Epoch 25: val_accuracy did not improve from 0.89605
# 541/541 [==============================] - 110s 204ms/step - loss: 0.5343 - accuracy: 0.8604 - val_loss: 0.5114 - val_accuracy: 0.8649
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5185 - accuracy: 0.8581
# Epoch 26: val_accuracy did not improve from 0.89605
# 541/541 [==============================] - 108s 200ms/step - loss: 0.5185 - accuracy: 0.8581 - val_loss: 0.5007 - val_accuracy: 0.8649
# Epoch 27/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5416 - accuracy: 0.8496
# Epoch 27: val_accuracy did not improve from 0.89605
# 541/541 [==============================] - 109s 202ms/step - loss: 0.5416 - accuracy: 0.8496 - val_loss: 0.4880 - val_accuracy: 0.8690
# Epoch 28/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5252 - accuracy: 0.8533
# Epoch 28: val_accuracy did not improve from 0.89605
# 541/541 [==============================] - 109s 202ms/step - loss: 0.5252 - accuracy: 0.8533 - val_loss: 0.4762 - val_accuracy: 0.8836
# Epoch 29/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5168 - accuracy: 0.8648
# Epoch 29: val_accuracy did not improve from 0.89605
# 541/541 [==============================] - 108s 200ms/step - loss: 0.5168 - accuracy: 0.8648 - val_loss: 0.4708 - val_accuracy: 0.8940
# Epoch 30/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5157 - accuracy: 0.8593
# Epoch 30: val_accuracy did not improve from 0.89605
# 541/541 [==============================] - 111s 204ms/step - loss: 0.5157 - accuracy: 0.8593 - val_loss: 0.4707 - val_accuracy: 0.8732
# Epoch 31/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5347 - accuracy: 0.8526
# Epoch 31: val_accuracy did not improve from 0.89605
# 541/541 [==============================] - 113s 208ms/step - loss: 0.5347 - accuracy: 0.8526 - val_loss: 0.4941 - val_accuracy: 0.8690
# Epoch 32/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5066 - accuracy: 0.8565
# Epoch 32: val_accuracy did not improve from 0.89605
# 541/541 [==============================] - 112s 207ms/step - loss: 0.5066 - accuracy: 0.8565 - val_loss: 0.4828 - val_accuracy: 0.8690
# Epoch 33/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5266 - accuracy: 0.8598
# Epoch 33: val_accuracy did not improve from 0.89605
# 541/541 [==============================] - 113s 208ms/step - loss: 0.5266 - accuracy: 0.8598 - val_loss: 0.5063 - val_accuracy: 0.8607
# Epoch 34/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5164 - accuracy: 0.8642
# Epoch 34: val_accuracy improved from 0.89605 to 0.91684, saving model to /kaggle/working/best_nextvit_s.keras
# 541/541 [==============================] - 110s 204ms/step - loss: 0.5164 - accuracy: 0.8642 - val_loss: 0.4461 - val_accuracy: 0.9168
# Epoch 35/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5166 - accuracy: 0.8621
# Epoch 35: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 109s 202ms/step - loss: 0.5166 - accuracy: 0.8621 - val_loss: 0.4715 - val_accuracy: 0.8773
# Epoch 36/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5078 - accuracy: 0.8655
# Epoch 36: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 114s 210ms/step - loss: 0.5078 - accuracy: 0.8655 - val_loss: 0.4944 - val_accuracy: 0.8628
# Epoch 37/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1883 - accuracy: 0.9306
# Epoch 37: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 78s 143ms/step - loss: 0.1883 - accuracy: 0.9306 - val_loss: 0.3708 - val_accuracy: 0.8669
# Epoch 38/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1856 - accuracy: 0.9313
# Epoch 38: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 77s 143ms/step - loss: 0.1856 - accuracy: 0.9313 - val_loss: 0.3660 - val_accuracy: 0.8773
# Epoch 39/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9315
# Epoch 39: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 76s 141ms/step - loss: 0.1889 - accuracy: 0.9315 - val_loss: 0.3437 - val_accuracy: 0.8773
# Epoch 40/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1663 - accuracy: 0.9361
# Epoch 40: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 77s 141ms/step - loss: 0.1663 - accuracy: 0.9361 - val_loss: 0.3407 - val_accuracy: 0.8898
# Epoch 41/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1781 - accuracy: 0.9303
# Epoch 41: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 76s 141ms/step - loss: 0.1781 - accuracy: 0.9303 - val_loss: 0.3406 - val_accuracy: 0.8857
# Epoch 42/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.9338
# Epoch 42: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 76s 141ms/step - loss: 0.1795 - accuracy: 0.9338 - val_loss: 0.3362 - val_accuracy: 0.8815
# Epoch 43/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1745 - accuracy: 0.9303
# Epoch 43: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 77s 142ms/step - loss: 0.1745 - accuracy: 0.9303 - val_loss: 0.3508 - val_accuracy: 0.8690
# Epoch 44/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1724 - accuracy: 0.9333
# Epoch 44: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 77s 142ms/step - loss: 0.1724 - accuracy: 0.9333 - val_loss: 0.3378 - val_accuracy: 0.8815
# Epoch 45/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1753 - accuracy: 0.9340
# Epoch 45: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 76s 141ms/step - loss: 0.1753 - accuracy: 0.9340 - val_loss: 0.3625 - val_accuracy: 0.8607
# Epoch 46/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1777 - accuracy: 0.9324
# Epoch 46: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 78s 144ms/step - loss: 0.1777 - accuracy: 0.9324 - val_loss: 0.3563 - val_accuracy: 0.8690
# Epoch 46: early stopping
# Restoring model weights from the end of the best epoch: 34.
# Evaluating best-restored model (no reload to avoid custom-objects issues):
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (NextViT-S + 5xTTA): 91.27%
# Classification Report (VAL, NextViT-S + TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.9806    0.8417    0.9058       120
#   meningioma     0.8824    0.8400    0.8607       125
#     no_tumor     0.8932    1.0000    0.9436        92
#    pituitary     0.9038    0.9792    0.9400       144
#
#     accuracy                         0.9127       481
#    macro avg     0.9150    0.9152    0.9125       481
# weighted avg     0.9154    0.9127    0.9115       481
#
# Saved base model to: /kaggle/working/nextvit_s_paramfixed.keras

# %% [markdown]
# # **PoolFormer (MetaFormer) poolformer_s12**

# %%
# ========================
# 0) Install minimal deps (no KCAM)
# ========================
# !pip -q install split-folders tf-keras

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # quieter TF logs
os.environ["TF_XLA_FLAGS"] = ""           # disable XLA JIT on P100

import tensorflow as tf

# Deterministic-ish runs
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU mem growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]

def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten + simple per-class near-dup removal
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, Activation, GaussianNoise, Input,
    Reshape, Multiply, Layer, Concatenate, Conv2D, LayerNormalization, AveragePooling2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

# LOWER MEM settings
IMG_SIZE   = (256, 256)
BATCH_SIZE = 8

INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Aug knobs (annealed later)
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se / re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) Self-contained PoolFormer-S (MetaFormer) backbone + fixed-param head
# ========================

class SqueezeExcite(Layer):
    def __init__(self, ratio=16, **kwargs):
        super().__init__(**kwargs); self.ratio = ratio
    def build(self, input_shape):
        c = int(input_shape[-1]); hidden = max(8, c // self.ratio)
        self.fc1 = Dense(hidden, activation='relu'); self.fc2 = Dense(c, activation='sigmoid')
        super().build(input_shape)
    def call(self, x):
        s = GlobalAveragePooling2D()(x); s = self.fc1(s); s = self.fc2(s)
        s = Reshape((1,1,-1))(s); return Multiply()([x, s])

class SpatialGate(Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs); self.conv=None
    def build(self, input_shape):
        self.conv = Conv2D(1, kernel_size=7, padding="same", use_bias=True)
        super().build(input_shape)
    def call(self, x):
        avg = tf.reduce_mean(x, axis=-1, keepdims=True)
        mx  = tf.reduce_max(x,  axis=-1, keepdims=True)
        s   = Concatenate(axis=-1)([avg, mx])
        s   = self.conv(s); s = tf.nn.sigmoid(s)
        return Multiply()([x, s])

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        # cast to x dtype to avoid mixed-precision mismatches
        return x + tf.cast(tf.reduce_sum(getattr(self, "pad_w", 0.0)), x.dtype) * tf.cast(0.0, x.dtype)

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

# ----- MetaFormer (PoolFormer) blocks -----
class TokenMixerPool(Layer):
    """Pooling token mixer: y = AvgPool3x3(x) - x"""
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
        self.pool = AveragePooling2D(pool_size=3, strides=1, padding="same")
    def call(self, x):
        return self.pool(x) - x

class MLPConv(Layer):
    """1x1 conv MLP: C -> C*ratio -> GELU -> C"""
    def __init__(self, channels, ratio=4, drop_rate=0.0, **kwargs):
        super().__init__(**kwargs)
        self.channels = channels; self.ratio = ratio; self.drop_rate = drop_rate
    def build(self, input_shape):
        hidden = int(self.channels * self.ratio)
        self.fc1 = Conv2D(hidden, kernel_size=1, padding="same", use_bias=True)
        self.fc2 = Conv2D(self.channels, kernel_size=1, padding="same", use_bias=True)
        self.dropout = tf.keras.layers.Dropout(self.drop_rate)
        super().build(input_shape)
    def call(self, x, training=False):
        x = self.fc1(x); x = tf.nn.gelu(x); x = self.dropout(x, training=training)
        x = self.fc2(x); x = self.dropout(x, training=training)
        return x

class MetaFormerBlock(Layer):
    def __init__(self, channels, mlp_ratio=4, drop_rate=0.0, **kwargs):
        super().__init__(**kwargs)
        self.channels = channels
        self.norm1 = LayerNormalization(epsilon=1e-6)
        self.token_mixer = TokenMixerPool()
        self.norm2 = LayerNormalization(epsilon=1e-6)
        self.mlp = MLPConv(channels, ratio=mlp_ratio, drop_rate=drop_rate)
    def call(self, x, training=False):
        y = self.norm1(x)
        y = self.token_mixer(y)
        x = x + y
        y = self.norm2(x)
        y = self.mlp(y, training=training)
        return x + y

def Downsample(channels, name):
    """LayerNorm + Conv stride-2"""
    return tf.keras.Sequential([
        LayerNormalization(epsilon=1e-6),
        Conv2D(channels, kernel_size=3, strides=2, padding="same", use_bias=True)
    ], name=name)

def PatchEmbed(channels, name):
    """Conv 7x7 stride 4"""
    return tf.keras.Sequential([
        Conv2D(channels, kernel_size=7, strides=4, padding="same", use_bias=True)
    ], name=name)

def build_poolformer_backbone_s(img_size=(256,256), variant="s12"):
    # Configs from paper: channels and depths
    if variant == "s12":
        depths = [2, 2, 6, 2]
        dims   = [64, 128, 320, 512]
    elif variant == "s24":
        depths = [4, 4, 12, 4]
        dims   = [64, 128, 320, 512]
    elif variant == "s36":
        depths = [6, 6, 18, 6]
        dims   = [64, 128, 320, 512]
    else:
        depths = [2, 2, 6, 2]; dims = [64, 128, 320, 512]

    inputs = Input(shape=(img_size[0], img_size[1], 3))
    x = PatchEmbed(dims[0], name="stem")(inputs)

    # Stage 1
    for i in range(depths[0]):
        x = MetaFormerBlock(dims[0], name=f"s1_b{i+1}")(x)
    x = Downsample(dims[1], name="down1")(x)
    # Stage 2
    for i in range(depths[1]):
        x = MetaFormerBlock(dims[1], name=f"s2_b{i+1}")(x)
    x = Downsample(dims[2], name="down2")(x)
    # Stage 3
    for i in range(depths[2]):
        x = MetaFormerBlock(dims[2], name=f"s3_b{i+1}")(x)
    x = Downsample(dims[3], name="down3")(x)
    # Stage 4
    for i in range(depths[3]):
        x = MetaFormerBlock(dims[3], name=f"s4_b{i+1}")(x)

    return Model(inputs, x, name=f"poolformer_{variant}")

# Choose variant
BACKBONE_NAME = "poolformer_s12"  # 'poolformer_s12' | 'poolformer_s24' | 'poolformer_s36'

def build_model_with_poolformer(backbone_name, num_classes, img_size):
    variant = backbone_name.split("_")[-1]  # 's12' / 's24' / 's36'
    inp = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x = GaussianNoise(0.01)(inp)

    backbone = build_poolformer_backbone_s(img_size=img_size, variant=variant)
    backbone.trainable = False  # freeze backbone
    feat = backbone(x)
    if isinstance(feat, (list, tuple)): feat = feat[-1]

    gap = GlobalAveragePooling2D(name="GAP")(feat)
    head = Dense(256, use_bias=True)(gap)
    head = Activation(gelu)(head)
    head = Dropout(0.35)(head)
    out = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(head)

    model = Model(inp, out, name=f"{backbone.name}_head")

    # Exact trainable param target
    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Reduce head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out)
        model = Model(inp, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")
    return model

# Build
tf.keras.backend.clear_session()
model = build_model_with_poolformer(BACKBONE_NAME, num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss (dtype-safe)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

MIXUP_P = [0.00]; CUTMIX_P = [0.00]; ERASE_P = [0.00]; CLAHE_P = [0.00]
mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks (simplified for stability)
# ========================
early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_poolformer_model.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Light evaluation (memory-safe): best-restored model + 5x TTA
# ========================
print("\nEvaluating best-restored model (no reload to avoid custom-objects issues):")
std_model = model  # EarlyStopping restored best weights

from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            xb = x if fn is None else np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy ({BACKBONE_NAME} + 5xTTA): {acc*100:.2f}%")

# Confusion matrix & report
cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title(f'Confusion Matrix (VAL, {BACKBONE_NAME}+TTA)'); plt.show()
print("\nClassification Report (VAL, PoolFormer+TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save final model
# ========================
final_model_path = f"/kaggle/working/{BACKBONE_NAME}_head_paramfixed.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 7399.13 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# I0000 00:00:1759534063.921259      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# [ParamTarget] Trainable BEFORE pad: 132,356
# [ParamTarget] Added ParamPad with 1,329,231 -> final trainables = 1,461,587
# Model: "poolformer_s12_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)       0
#  ise)
#
#  poolformer_s12 (Functional  (None, 8, 8, 512)         11395520
#  )
#
#  GAP (GlobalAveragePooling2  (None, 512)               0
#  D)
#
#  dense (Dense)               (None, 256)               131328
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  predictions (Dense)         (None, 4)                 1028
#
#  param_pad (ParamPad)        (None, 4)                 1329231
#
# =================================================================
# Total params: 12857107 (49.05 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 11395520 (43.47 MB)
# _________________________________________________________________
# Epoch 1/50
# I0000 00:00:1759534077.689074     130 cuda_dnn.cc:529] Loaded cuDNN version 90300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759534081.135710     129 service.cc:148] XLA service 0x7c91a0aea8b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759534081.136499     129 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759534081.313469     129 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 1.4761 - accuracy: 0.3353
# Epoch 1: val_accuracy improved from -inf to 0.38669, saving model to /kaggle/working/best_poolformer_model.keras
# 541/541 [==============================] - 89s 138ms/step - loss: 1.4761 - accuracy: 0.3353 - val_loss: 1.3509 - val_accuracy: 0.3867
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1329 - accuracy: 0.5196
# Epoch 2: val_accuracy improved from 0.38669 to 0.41788, saving model to /kaggle/working/best_poolformer_model.keras
# 541/541 [==============================] - 74s 136ms/step - loss: 1.1329 - accuracy: 0.5196 - val_loss: 1.3228 - val_accuracy: 0.4179
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1295 - accuracy: 0.5302
# Epoch 3: val_accuracy improved from 0.41788 to 0.42620, saving model to /kaggle/working/best_poolformer_model.keras
# 541/541 [==============================] - 93s 171ms/step - loss: 1.1295 - accuracy: 0.5302 - val_loss: 1.2728 - val_accuracy: 0.4262
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1085 - accuracy: 0.5464
# Epoch 4: val_accuracy improved from 0.42620 to 0.45114, saving model to /kaggle/working/best_poolformer_model.keras
# 541/541 [==============================] - 95s 175ms/step - loss: 1.1085 - accuracy: 0.5464 - val_loss: 1.1750 - val_accuracy: 0.4511
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1075 - accuracy: 0.5522
# Epoch 5: val_accuracy did not improve from 0.45114
# 541/541 [==============================] - 94s 173ms/step - loss: 1.1075 - accuracy: 0.5522 - val_loss: 1.2488 - val_accuracy: 0.4345
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0940 - accuracy: 0.5550
# Epoch 6: val_accuracy did not improve from 0.45114
# 541/541 [==============================] - 97s 179ms/step - loss: 1.0940 - accuracy: 0.5550 - val_loss: 1.2975 - val_accuracy: 0.3929
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0747 - accuracy: 0.5684
# Epoch 7: val_accuracy did not improve from 0.45114
# 541/541 [==============================] - 95s 175ms/step - loss: 1.0747 - accuracy: 0.5684 - val_loss: 1.3222 - val_accuracy: 0.4179
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0602 - accuracy: 0.5716
# Epoch 8: val_accuracy did not improve from 0.45114
# 541/541 [==============================] - 95s 176ms/step - loss: 1.0602 - accuracy: 0.5716 - val_loss: 1.3016 - val_accuracy: 0.4304
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0474 - accuracy: 0.5776
# Epoch 9: val_accuracy did not improve from 0.45114
# 541/541 [==============================] - 92s 171ms/step - loss: 1.0474 - accuracy: 0.5776 - val_loss: 1.2221 - val_accuracy: 0.4345
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0516 - accuracy: 0.5878
# Epoch 10: val_accuracy did not improve from 0.45114
# 541/541 [==============================] - 94s 174ms/step - loss: 1.0516 - accuracy: 0.5878 - val_loss: 1.2871 - val_accuracy: 0.4304
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0634 - accuracy: 0.5769
# Epoch 11: val_accuracy did not improve from 0.45114
# 541/541 [==============================] - 108s 199ms/step - loss: 1.0634 - accuracy: 0.5769 - val_loss: 1.3184 - val_accuracy: 0.4096
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0500 - accuracy: 0.5695
# Epoch 12: val_accuracy did not improve from 0.45114
# 541/541 [==============================] - 106s 196ms/step - loss: 1.0500 - accuracy: 0.5695 - val_loss: 1.3617 - val_accuracy: 0.4262
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0384 - accuracy: 0.5855
# Epoch 13: val_accuracy improved from 0.45114 to 0.48857, saving model to /kaggle/working/best_poolformer_model.keras
# 541/541 [==============================] - 107s 199ms/step - loss: 1.0384 - accuracy: 0.5855 - val_loss: 1.1057 - val_accuracy: 0.4886
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0287 - accuracy: 0.5795
# Epoch 14: val_accuracy did not improve from 0.48857
# 541/541 [==============================] - 106s 197ms/step - loss: 1.0287 - accuracy: 0.5795 - val_loss: 1.1753 - val_accuracy: 0.4740
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0330 - accuracy: 0.5827
# Epoch 15: val_accuracy did not improve from 0.48857
# 541/541 [==============================] - 110s 203ms/step - loss: 1.0330 - accuracy: 0.5827 - val_loss: 1.4839 - val_accuracy: 0.4012
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0234 - accuracy: 0.5860
# Epoch 16: val_accuracy did not improve from 0.48857
# 541/541 [==============================] - 105s 193ms/step - loss: 1.0234 - accuracy: 0.5860 - val_loss: 1.2334 - val_accuracy: 0.4345
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0211 - accuracy: 0.5790
# Epoch 17: val_accuracy did not improve from 0.48857
# 541/541 [==============================] - 108s 201ms/step - loss: 1.0211 - accuracy: 0.5790 - val_loss: 1.2363 - val_accuracy: 0.4532
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0102 - accuracy: 0.5945
# Epoch 18: val_accuracy did not improve from 0.48857
# 541/541 [==============================] - 109s 202ms/step - loss: 1.0102 - accuracy: 0.5945 - val_loss: 1.3294 - val_accuracy: 0.4096
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0096 - accuracy: 0.5969
# Epoch 19: val_accuracy did not improve from 0.48857
# 541/541 [==============================] - 105s 193ms/step - loss: 1.0096 - accuracy: 0.5969 - val_loss: 1.3213 - val_accuracy: 0.4241
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0024 - accuracy: 0.6012
# Epoch 20: val_accuracy did not improve from 0.48857
# 541/541 [==============================] - 107s 197ms/step - loss: 1.0024 - accuracy: 0.6012 - val_loss: 1.2912 - val_accuracy: 0.4366
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0139 - accuracy: 0.5906
# Epoch 21: val_accuracy improved from 0.48857 to 0.50104, saving model to /kaggle/working/best_poolformer_model.keras
# 541/541 [==============================] - 109s 202ms/step - loss: 1.0139 - accuracy: 0.5906 - val_loss: 1.1177 - val_accuracy: 0.5010
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9975 - accuracy: 0.6033
# Epoch 22: val_accuracy improved from 0.50104 to 0.53222, saving model to /kaggle/working/best_poolformer_model.keras
# 541/541 [==============================] - 111s 205ms/step - loss: 0.9975 - accuracy: 0.6033 - val_loss: 1.0709 - val_accuracy: 0.5322
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9958 - accuracy: 0.6010
# Epoch 23: val_accuracy did not improve from 0.53222
# 541/541 [==============================] - 109s 202ms/step - loss: 0.9958 - accuracy: 0.6010 - val_loss: 1.2898 - val_accuracy: 0.4387
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0001 - accuracy: 0.6033
# Epoch 24: val_accuracy did not improve from 0.53222
# 541/541 [==============================] - 110s 204ms/step - loss: 1.0001 - accuracy: 0.6033 - val_loss: 1.5210 - val_accuracy: 0.4262
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9793 - accuracy: 0.6163
# Epoch 25: val_accuracy did not improve from 0.53222
# 541/541 [==============================] - 107s 197ms/step - loss: 0.9793 - accuracy: 0.6163 - val_loss: 1.2199 - val_accuracy: 0.4657
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9951 - accuracy: 0.5973
# Epoch 26: val_accuracy did not improve from 0.53222
# 541/541 [==============================] - 110s 203ms/step - loss: 0.9951 - accuracy: 0.5973 - val_loss: 1.1452 - val_accuracy: 0.4802
# Epoch 27/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9798 - accuracy: 0.6128
# Epoch 27: val_accuracy did not improve from 0.53222
# 541/541 [==============================] - 108s 200ms/step - loss: 0.9798 - accuracy: 0.6128 - val_loss: 1.1350 - val_accuracy: 0.4906
# Epoch 28/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9840 - accuracy: 0.6158
# Epoch 28: val_accuracy did not improve from 0.53222
# 541/541 [==============================] - 109s 202ms/step - loss: 0.9840 - accuracy: 0.6158 - val_loss: 1.1699 - val_accuracy: 0.4761
# Epoch 29/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9632 - accuracy: 0.6237
# Epoch 29: val_accuracy did not improve from 0.53222
# 541/541 [==============================] - 106s 196ms/step - loss: 0.9632 - accuracy: 0.6237 - val_loss: 1.2921 - val_accuracy: 0.4449
# Epoch 30/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9667 - accuracy: 0.6119
# Epoch 30: val_accuracy did not improve from 0.53222
# 541/541 [==============================] - 109s 201ms/step - loss: 0.9667 - accuracy: 0.6119 - val_loss: 1.1821 - val_accuracy: 0.4906
# Epoch 31/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9717 - accuracy: 0.6015
# Epoch 31: val_accuracy did not improve from 0.53222
# 541/541 [==============================] - 105s 194ms/step - loss: 0.9717 - accuracy: 0.6015 - val_loss: 1.2819 - val_accuracy: 0.4511
# Epoch 32/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9730 - accuracy: 0.6237
# Epoch 32: val_accuracy did not improve from 0.53222
# 541/541 [==============================] - 106s 196ms/step - loss: 0.9730 - accuracy: 0.6237 - val_loss: 1.3246 - val_accuracy: 0.4324
# Epoch 33/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9569 - accuracy: 0.6230
# Epoch 33: val_accuracy did not improve from 0.53222
# 541/541 [==============================] - 106s 195ms/step - loss: 0.9569 - accuracy: 0.6230 - val_loss: 1.3493 - val_accuracy: 0.4387
# Epoch 34/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9740 - accuracy: 0.6195
# Epoch 34: val_accuracy did not improve from 0.53222
# 541/541 [==============================] - 107s 198ms/step - loss: 0.9740 - accuracy: 0.6195 - val_loss: 1.2314 - val_accuracy: 0.4449
# Epoch 34: early stopping
# Restoring model weights from the end of the best epoch: 22.
# Evaluating best-restored model (no reload to avoid custom-objects issues):
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (poolformer_s12 + 5xTTA): 54.26%
# Classification Report (VAL, PoolFormer+TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.8571    0.1000    0.1791       120
#   meningioma     0.4653    0.5360    0.4981       125
#     no_tumor     0.8727    0.5217    0.6531        92
#    pituitary     0.5000    0.9306    0.6505       144
#
#     accuracy                         0.5426       481
#    macro avg     0.6738    0.5221    0.4952       481
# weighted avg     0.6514    0.5426    0.4938       481
#
# Saved base model to: /kaggle/working/poolformer_s12_head_paramfixed.keras

# %% [markdown]
# # **GhostNetV2**

# %%
# ================================
# GHOSTNETV2 (full fine-tune, 50 epochs)
# Fix: serializable WarmupCosine (get_config)
# ================================

# ---- env BEFORE TF/Keras imports ----
import os
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
os.environ["TF_XLA_FLAGS"] = ""                # avoid long XLA compiles on P100
os.environ["TF_USE_LEGACY_KERAS"] = "1"        # force tf.keras API

# ---- installs ----
# !pip -q install -U split-folders keras-cv-attention-models --no-warn-conflicts

# ---- imports ----
import sys, shutil, random, math, hashlib
import numpy as np
def log(m): print(f">>> {m}", flush=True)

import tensorflow as tf
import cv2, matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict, Counter
from sklearn.metrics import confusion_matrix, classification_report

log(f"Python {sys.version}")
log(f"TensorFlow {tf.__version__}")

# ---- seed & GPU ----
SEED = 42
random.seed(SEED); np.random.seed(SEED); tf.random.set_seed(SEED)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    for g in gpus:
        try: tf.config.experimental.set_memory_growth(g, True)
        except Exception as e: log(f"GPU memory growth failed: {e}")
log(f"GPUs: {gpus}")

# ========================
# 1) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
]
def looks_like_class_root(p: Path) -> bool:
    return p.exists() and p.is_dir() and sum(1 for d in p.iterdir() if d.is_dir()) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p): SRC = p; break
if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p): SRC = p; break
if SRC is None:
    brain_patterns = ["Brain Tumor MRI Dataset","brain-tumor-mri-dataset","brain_tumor_mri_dataset","brain-tumor-mri","Brain-Tumor-MRI-Dataset"]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p/"Training").exists() and looks_like_class_root(p/"Training"): SRC = p/"Training"; break
            if looks_like_class_root(p): SRC = p; break
        if SRC is not None: break
assert SRC is not None, "Couldn't find the dataset root."
log(f"Class root: {SRC}")

classes_src = [p for p in SRC.iterdir() if p.is_dir()]
log("Top-level classes:\n  " + "\n  ".join(sorted(d.name for d in classes_src)))

def _norm(s): return s.lower().replace('-', '_').replace(' ', '_')
def is_bt_class_name(name: str) -> bool:
    s = _norm(name); return s in {"glioma","meningioma","pituitary","no_tumor","glioma_tumor","meningioma_tumor","pituitary_tumor","notumor","no","no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING","Test","test","Validation","validation","VALIDATION","valid"]
IMG_EXT = {".jpg",".jpeg",".png",".bmp",".tif",".tiff",".gif"}

bt_class_dirs=[]
for cont in bt_containers:
    p = SRC/cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)
if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if is_bt_class_name(d.name)]
if bt_class_dirs:
    classes_src = bt_class_dirs
    log("[Brain Tumor MRI] Using these class folders:\n  " + "\n  ".join(sorted(d.as_posix() for d in bt_class_dirs)))

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set); write_counters = defaultdict(int); total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"
    dst = FLAT/cls_name; dst.mkdir(parents=True, exist_ok=True)
    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]: dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1; local_count += 1
            shutil.copy2(str(f), str(dst/f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"))
    log(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

log("Final per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir(): log(f" - {d.name}: {sum(1 for _ in d.iterdir() if _.is_file())}")
log(f"Total images collected: {total}")
assert total > 0, "No images found."

if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)
train_dir = OUT/"train"; val_dir = OUT/"val"
log(f"Sanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
log(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 2) Data pipeline (MixUp / CutMix)
# ========================
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMG_SIZE   = (224, 224)
BATCH_SIZE = 32
EPOCHS     = 50
INIT_LR    = 2e-3
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.0

def preprocess01(x):
    x = np.clip(x, 0, 255).astype(np.float32) / 255.0
    return x

train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess01,
    horizontal_flip=True,
    rotation_range=12,
    width_shift_range=0.08,
    height_shift_range=0.08,
    zoom_range=0.20,
    shear_range=6,
    brightness_range=(0.9, 1.1),
    fill_mode='reflect'
)
val_datagen = ImageDataGenerator(preprocessing_function=preprocess01)

train_gen_base = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen_base.num_classes
log(f"Classes: {train_gen_base.class_indices}")

counts = Counter(train_gen_base.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
log(f"Class counts: {dict(counts)}")
log(f"Class weights: {class_weight}")

def _sample_batch(gen):
    x, y = next(gen); return x.astype(np.float32), y.astype(np.float32)

class MixGen:
    def __init__(self, gen, mixup=0.35, cutmix=0.35):
        self.g = gen; self.mixup = mixup; self.cutmix = cutmix; self.num_classes = gen.num_classes
    def __iter__(self): return self
    def __next__(self):
        x1, y1 = _sample_batch(self.g)
        r = np.random.rand()
        if r < self.mixup + self.cutmix:
            x2, y2 = _sample_batch(self.g)
            n, h, w, c = x1.shape
            if r < self.cutmix:
                rx, ry = np.random.randint(w//8, w - w//8), np.random.randint(h//8, h - h//8)
                rw, rh = np.random.randint(w//8, w//3), np.random.randint(h//8, h//3)
                x = x1.copy()
                x[:, ry:ry+rh, rx:rx+rw, :] = x2[:, ry:ry+rh, rx:rx+rw, :]
                lam = 1.0 - (rw*rh)/(w*h)
                y = lam*y1 + (1-lam)*y2
                return x, y
            else:
                lam = np.random.beta(0.3, 0.3)
                x = lam*x1 + (1-lam)*x2
                y = lam*y1 + (1-lam)*y2
                return x, y
        return x1, y1
    def __len__(self): return len(self.g)

mix_train = MixGen(train_gen_base, mixup=0.35, cutmix=0.35)

# ========================
# 3) Model: GhostNetV2 (DFC disabled) – FULL fine-tuning
# ========================
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, GaussianNoise, GlobalAveragePooling2D, Dense, Dropout, Activation
from tensorflow.keras.activations import gelu

import keras_cv_attention_models as kcam
from keras_cv_attention_models import ghostnet
log(f"kcam version: {getattr(kcam,'__version__','unknown')}")

inputs = Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3), name="input")
x = GaussianNoise(0.01)(inputs)

# Disable DFC path to avoid KerasTensor→TF op issue
backbone = ghostnet.GhostNetV2(
    input_shape=(IMG_SIZE[0], IMG_SIZE[1], 3),
    num_classes=0,
    pretrained=None,
    num_ghost_module_v1_stacks=-1
)
backbone.trainable = True   # full FT

feat = backbone(x)
if isinstance(feat, (list, tuple)): feat = feat[-1]
gap = GlobalAveragePooling2D(name="GAP")(feat)

y = Dense(1024, use_bias=True, name="dense_1024")(gap)
y = Activation(gelu, name="gelu_1024")(y)
y = Dropout(0.4, name="drop_1024")(y)
logits = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(y)

model = Model(inputs, logits, name="ghostnetv2_head_1024")

# Smoke test
log("Smoke test forward pass...")
_ = model(np.zeros((1, *IMG_SIZE, 3), dtype=np.float32))
log("Smoke test OK.")
model.summary()

# ========================
# 4) Optimizer, schedule, loss  (FIXED: get_config implemented)
# ========================
from tensorflow.keras.optimizers.schedules import LearningRateSchedule
from tensorflow.keras import optimizers

@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(LearningRateSchedule):
    def __init__(self, base_lr=2e-3, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {
            "base_lr": self.base_lr,
            "warmup_steps": self.warmup_steps,
            "decay_steps": self.decay_steps,
            "min_lr": self.min_lr,
            "name": self.name,
        }

steps_per_epoch = len(train_gen_base)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

def cce_smooth(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    if LABEL_SMOOTH > 0:
        k = tf.cast(tf.shape(y_true)[-1], tf.float32)
        y_true = (1.0 - LABEL_SMOOTH) * y_true + LABEL_SMOOTH / k
    return tf.keras.losses.categorical_crossentropy(y_true, y_pred)

model.compile(optimizer=opt, loss=cce_smooth, metrics=['accuracy'])

# ========================
# 5) Train (50 epochs)
# ========================
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early = EarlyStopping(monitor='val_accuracy', patience=10, restore_best_weights=True, verbose=1)
ckpt_path = "/kaggle/working/best_ghostnetv2.keras"
ckpt = ModelCheckpoint(ckpt_path, monitor='val_accuracy', save_best_only=True, verbose=1)

# wrap MixGen into an iterable with explicit steps
def iter_like(mix_iter, steps):
    for _ in range(steps): yield next(mix_iter)

mix_iter = iter(mix_train)
log("Starting training...")
history = model.fit(
    iter_like(mix_iter, steps_per_epoch),
    steps_per_epoch=steps_per_epoch,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[early, ckpt],
    class_weight=class_weight,
    verbose=1
)
log("Training finished.")

# ========================
# 6) Curves + Eval (5x TTA)
# ========================
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o'); plt.title('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o'); plt.title('Loss'); plt.legend(); plt.show()

log("Evaluating with 5x TTA...")
def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=10):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

val_plain = val_datagen.flow_from_directory(str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
                                            class_mode='categorical', shuffle=False)
labels = list(val_plain.class_indices.keys()); y_true = val_plain.classes

def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames); prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32); idx0=0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]  # already [0,1]
        bs = x.shape[0]; acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            xb = x if fn is None else np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0); acc += p.astype(np.float32)
        acc /= float(len(tta_list)); prob_sum[idx0:idx0+bs] = acc; idx0 += bs
    return prob_sum

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +10), lambda x: tta_rotate(x, -10), lambda x: tta_gamma(x, 1.05)]
probs = tta_preds(model, val_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
log(f"Validation accuracy (GhostNetV2 FT + MixGen + 5xTTA): {acc*100:.2f}%")

cm = confusion_matrix(y_true, y_pred)
import seaborn as sns
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title('Confusion Matrix (VAL)'); plt.show()
print("\nClassification Report (VAL):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 7) Save
# ========================
final_path = "/kaggle/working/ghostnetv2_ft.keras"
model.save(final_path)
log(f"Saved model to: {final_path}")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 9.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.6/802.6 kB 43.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.0 MB/s eta 0:00:00
# 2025-10-04 07:21:27.104683: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759562487.282230      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759562487.332142      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# >>> Python 3.11.13 (main, Jun  4 2025, 08:57:29) [GCC 11.4.0]
# >>> TensorFlow 2.18.0
# >>> GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# >>> Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# >>> Top-level classes:
#   glioma
#   meningioma
#   notumor
#   pituitary
# >>> [Brain Tumor MRI] Using these class folders:
#   /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#   /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#   /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#   /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# >>> Collected  1196 (skipped dup  125) from glioma → 'glioma'
# >>> Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# >>> Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# >>> Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
# >>> Final per-class image counts:
# >>>  - glioma: 1196
# >>>  - meningioma: 1246
# >>>  - no_tumor: 920
# >>>  - pituitary: 1440
# >>> Total images collected: 4802
# Copying files: 4802 files [00:00, 7483.09 files/s]
# >>> Sanity: train files = 4321
# >>> Sanity: val   files = 481
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# >>> Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# >>> Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# >>> Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# >>> kcam version: 1.4.2
# I0000 00:00:1759562574.876782      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# >>> Smoke test forward pass...
# I0000 00:00:1759562578.608603      36 cuda_dnn.cc:529] Loaded cuDNN version 90300
# >>> Smoke test OK.
# Model: "ghostnetv2_head_1024"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 224, 224, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 224, 224, 3)       0
#  ise)
#
#  ghostnetv2 (Functional)     (None, 7, 7, 960)         2693396
#
#  GAP (GlobalAveragePooling2  (None, 960)               0
#  D)
#
#  dense_1024 (Dense)          (None, 1024)              984064
#
#  gelu_1024 (Activation)      (None, 1024)              0
#
#  drop_1024 (Dropout)         (None, 1024)              0
#
#  predictions (Dense)         (None, 4)                 4100
#
# =================================================================
# Total params: 3681560 (14.04 MB)
# Trainable params: 3659592 (13.96 MB)
# Non-trainable params: 21968 (85.81 KB)
# _________________________________________________________________
# >>> Starting training...
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759562621.811437     101 service.cc:148] XLA service 0x78d385bab0b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759562621.812154     101 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759562622.004953     101 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 136/136 [==============================] - ETA: 0s - loss: 1.1103 - accuracy: 0.5262
# Epoch 1: val_accuracy improved from -inf to 0.60083, saving model to /kaggle/working/best_ghostnetv2.keras
# 136/136 [==============================] - 156s 728ms/step - loss: 1.1103 - accuracy: 0.5262 - val_loss: 1.0274 - val_accuracy: 0.6008
# Epoch 2/50
#
# Epoch 2: val_accuracy did not improve from 0.60083
# 136/136 [==============================] - 2s 13ms/step - loss: 0.0000e+00 - accuracy: 0.0000e+00 - val_loss: 1.0274 - val_accuracy: 0.6008
# Restoring model weights from the end of the best epoch: 1.
# >>> Training finished.
# >>> Evaluating with 5x TTA...
# Found 481 images belonging to 4 classes.
# >>> Validation accuracy (GhostNetV2 FT + MixGen + 5xTTA): 59.25%
# Classification Report (VAL):
#
#               precision    recall  f1-score   support
#
#       glioma     0.7980    0.6583    0.7215       120
#   meningioma     0.3882    0.7920    0.5211       125
#     no_tumor     0.8229    0.8587    0.8404        92
#    pituitary     0.9032    0.1944    0.3200       144
#
#     accuracy                         0.5925       481
#    macro avg     0.7281    0.6259    0.6007       481
# weighted avg     0.7278    0.5925    0.5719       481
#
# >>> Saved model to: /kaggle/working/ghostnetv2_ft.keras

# %% [markdown]
# # **MLP-Mixer (S)**

# %%
# ========================
# 0) Install necessary libraries
# ========================
# !pip -q install split-folders keras-cv-attention-models tf-keras

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"          # quieter TF logs
os.environ["TF_XLA_FLAGS"] = ""                   # avoid XLA compile on P100
os.environ["TF_USE_LEGACY_KERAS"] = "1"           # for keras-cv-attention-models

import tensorflow as tf
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU memory growth
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]
def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten with simple near-duplicate removal (per class)
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, GlobalAveragePooling1D,
    Dense, Dropout, BatchNormalization, Activation,
    GaussianNoise, Input, Reshape, Multiply, Layer, Concatenate, MaxPooling2D, Conv2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

IMG_SIZE   = (256, 256)
BATCH_SIZE = 8
INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Augs
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se / re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) Backbone: MLP-Mixer (Small) via keras-cv-attention-models
# ========================

class SqueezeExcite(Layer):  # retained for checkpoint compatibility
    def __init__(self, ratio=16, **kwargs):
        super().__init__(**kwargs); self.ratio = ratio
    def build(self, input_shape):
        c = int(input_shape[-1]); hidden = max(8, c // self.ratio)
        self.fc1 = Dense(hidden, activation='relu'); self.fc2 = Dense(c, activation='sigmoid')
        super().build(input_shape)
    def call(self, x):
        s = tf.keras.layers.GlobalAveragePooling2D()(x)
        s = self.fc1(s); s = self.fc2(s)
        s = Reshape((1,1,-1))(s); return Multiply()([x, s])

class SpatialGate(Layer):    # retained for checkpoint compatibility
    def __init__(self, **kwargs):
        super().__init__(**kwargs); self.conv=None
    def build(self, input_shape):
        self.conv = Conv2D(1, kernel_size=7, padding="same", use_bias=True)
        super().build(input_shape)
    def call(self, x):
        avg = tf.reduce_mean(x, axis=-1, keepdims=True)
        mx  = tf.reduce_max(x,  axis=-1, keepdims=True)
        s   = Concatenate(axis=-1)([avg, mx])
        s   = self.conv(s); s = tf.nn.sigmoid(s)
        return Multiply()([x, s])

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        if hasattr(self, "pad_w"): return x + tf.reduce_sum(self.pad_w) * tf.cast(0.0, x.dtype)
        return x

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

# Choose MLP-Mixer Small variant:
# 'mlpmixer_s16'  -> Mixer-S/16 (patch 16)
# 'mlpmixer_s32'  -> Mixer-S/32 (patch 32)
BACKBONE_NAME = 'mlpmixer_s16'

def build_model_with_backbone(backbone_name, num_classes, img_size):
    inputs = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x = GaussianNoise(0.01)(inputs)

    from keras_cv_attention_models import mlp_mixer as mm
    if backbone_name == 'mlpmixer_s16':
        backbone = mm.MLPMixerS16(input_shape=(img_size[0], img_size[1], 3), num_classes=0, pretrained="imagenet")
    elif backbone_name == 'mlpmixer_s32':
        backbone = mm.MLPMixerS32(input_shape=(img_size[0], img_size[1], 3), num_classes=0, pretrained="imagenet")
    else:
        raise ValueError("Unsupported backbone for this notebook. Use 'mlpmixer_s16' or 'mlpmixer_s32'.")

    backbone.trainable = False  # freeze features

    feat = backbone(x)
    # Handle possible shapes from KCAM (2D / 3D / 4D)
    if isinstance(feat, (list, tuple)): feat = feat[-1]
    if len(feat.shape) == 4:
        gap = GlobalAveragePooling2D(name="GAP")(feat)
    elif len(feat.shape) == 3:
        gap = GlobalAveragePooling1D(name="GAP1D")(feat)
    elif len(feat.shape) == 2:
        gap = feat
    else:
        raise ValueError(f"Unexpected feature shape from backbone: {feat.shape}")

    xh = Dense(256, use_bias=True)(gap)
    xh = Activation(gelu)(xh)
    xh = Dropout(0.35)(xh)
    out_logits = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(xh)

    model = Model(inputs, out_logits, name=f"{backbone_name}_head")

    # Exact trainable params = 1,461,587
    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Reduce head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out_logits)
        model = Model(inputs, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")
    return model

tf.keras.backend.clear_session()
model = build_model_with_backbone(BACKBONE_NAME, num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss (dtype-safe)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    # dtype-safe under mixed precision
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks
# ========================
early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_mlpmixer_model.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train (50 epochs)
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Evaluation + 5x TTA (streamed)
# ========================
print("\nEvaluating best-restored model (no reload to avoid custom-objects issues):")
std_model = model

val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            xb = x if fn is None else np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy (MLP-Mixer Small + 5xTTA): {acc*100:.2f}%")

cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title('Confusion Matrix (VAL, MLP-MixerS+TTA)'); plt.show()
print("\nClassification Report (VAL, MLP-MixerS+TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save final model
# ========================
final_model_path = f"/kaggle/working/{BACKBONE_NAME}_head_paramfixed.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.6/802.6 kB 26.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.5 MB/s eta 0:00:00
# 2025-10-04 08:27:42.218436: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759566462.400604      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759566462.453402      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 7389.48 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# I0000 00:00:1759566518.592269      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# >>>> No pretrained available, model will be randomly initialized
# [ParamTarget] Trainable BEFORE pad: 132,356
# [ParamTarget] Added ParamPad with 1,329,231 -> final trainables = 1,461,587
# Model: "mlpmixer_s16_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)       0
#  ise)
#
#  mlp_mixer_s16 (Functional)  (None, 256, 512)          18261504
#
#  GAP1D (GlobalAveragePoolin  (None, 512)               0
#  g1D)
#
#  dense (Dense)               (None, 256)               131328
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  predictions (Dense)         (None, 4)                 1028
#
#  param_pad (ParamPad)        (None, 4)                 1329231
#
# =================================================================
# Total params: 19723091 (75.24 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 18261504 (69.66 MB)
# _________________________________________________________________
# Epoch 1/50
# I0000 00:00:1759566532.190300     107 cuda_dnn.cc:529] Loaded cuDNN version 90300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759566535.074383     106 service.cc:148] XLA service 0x7811147a5100 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759566535.075300     106 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759566535.286648     106 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 1.3955 - accuracy: 0.2615
# Epoch 1: val_accuracy improved from -inf to 0.31601, saving model to /kaggle/working/best_mlpmixer_model.keras
# 541/541 [==============================] - 91s 144ms/step - loss: 1.3955 - accuracy: 0.2615 - val_loss: 1.3506 - val_accuracy: 0.3160
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3546 - accuracy: 0.3414
# Epoch 2: val_accuracy improved from 0.31601 to 0.44491, saving model to /kaggle/working/best_mlpmixer_model.keras
# 541/541 [==============================] - 77s 142ms/step - loss: 1.3546 - accuracy: 0.3414 - val_loss: 1.2903 - val_accuracy: 0.4449
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3161 - accuracy: 0.3798
# Epoch 3: val_accuracy improved from 0.44491 to 0.47401, saving model to /kaggle/working/best_mlpmixer_model.keras
# 541/541 [==============================] - 98s 181ms/step - loss: 1.3161 - accuracy: 0.3798 - val_loss: 1.2337 - val_accuracy: 0.4740
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 1.2809 - accuracy: 0.4050
# Epoch 4: val_accuracy improved from 0.47401 to 0.48233, saving model to /kaggle/working/best_mlpmixer_model.keras
# 541/541 [==============================] - 96s 177ms/step - loss: 1.2809 - accuracy: 0.4050 - val_loss: 1.1754 - val_accuracy: 0.4823
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 1.2680 - accuracy: 0.4219
# Epoch 5: val_accuracy did not improve from 0.48233
# 541/541 [==============================] - 98s 181ms/step - loss: 1.2680 - accuracy: 0.4219 - val_loss: 1.1865 - val_accuracy: 0.4719
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 1.2583 - accuracy: 0.4342
# Epoch 6: val_accuracy improved from 0.48233 to 0.50936, saving model to /kaggle/working/best_mlpmixer_model.keras
# 541/541 [==============================] - 94s 173ms/step - loss: 1.2583 - accuracy: 0.4342 - val_loss: 1.1425 - val_accuracy: 0.5094
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 1.2434 - accuracy: 0.4413
# Epoch 7: val_accuracy improved from 0.50936 to 0.55925, saving model to /kaggle/working/best_mlpmixer_model.keras
# 541/541 [==============================] - 96s 178ms/step - loss: 1.2434 - accuracy: 0.4413 - val_loss: 1.1124 - val_accuracy: 0.5593
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 1.2125 - accuracy: 0.4619
# Epoch 8: val_accuracy did not improve from 0.55925
# 541/541 [==============================] - 94s 174ms/step - loss: 1.2125 - accuracy: 0.4619 - val_loss: 1.1179 - val_accuracy: 0.5177
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 1.2155 - accuracy: 0.4555
# Epoch 9: val_accuracy did not improve from 0.55925
# 541/541 [==============================] - 94s 175ms/step - loss: 1.2155 - accuracy: 0.4555 - val_loss: 1.0992 - val_accuracy: 0.5447
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 1.2146 - accuracy: 0.4587
# Epoch 10: val_accuracy did not improve from 0.55925
# 541/541 [==============================] - 96s 177ms/step - loss: 1.2146 - accuracy: 0.4587 - val_loss: 1.0707 - val_accuracy: 0.5489
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 1.2110 - accuracy: 0.4585
# Epoch 11: val_accuracy improved from 0.55925 to 0.57588, saving model to /kaggle/working/best_mlpmixer_model.keras
# 541/541 [==============================] - 111s 206ms/step - loss: 1.2110 - accuracy: 0.4585 - val_loss: 1.0475 - val_accuracy: 0.5759
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 1.2144 - accuracy: 0.4497
# Epoch 12: val_accuracy did not improve from 0.57588
# 541/541 [==============================] - 112s 207ms/step - loss: 1.2144 - accuracy: 0.4497 - val_loss: 1.0488 - val_accuracy: 0.5572
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1899 - accuracy: 0.4638
# Epoch 13: val_accuracy did not improve from 0.57588
# 541/541 [==============================] - 114s 210ms/step - loss: 1.1899 - accuracy: 0.4638 - val_loss: 1.0228 - val_accuracy: 0.5738
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1843 - accuracy: 0.4608
# Epoch 14: val_accuracy did not improve from 0.57588
# 541/541 [==============================] - 112s 207ms/step - loss: 1.1843 - accuracy: 0.4608 - val_loss: 1.0841 - val_accuracy: 0.5405
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1816 - accuracy: 0.4710
# Epoch 15: val_accuracy did not improve from 0.57588
# 541/541 [==============================] - 108s 199ms/step - loss: 1.1816 - accuracy: 0.4710 - val_loss: 1.0256 - val_accuracy: 0.5655
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1812 - accuracy: 0.4758
# Epoch 16: val_accuracy improved from 0.57588 to 0.59044, saving model to /kaggle/working/best_mlpmixer_model.keras
# 541/541 [==============================] - 111s 205ms/step - loss: 1.1812 - accuracy: 0.4758 - val_loss: 1.0263 - val_accuracy: 0.5904
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1699 - accuracy: 0.4841
# Epoch 17: val_accuracy did not improve from 0.59044
# 541/541 [==============================] - 112s 208ms/step - loss: 1.1699 - accuracy: 0.4841 - val_loss: 1.0169 - val_accuracy: 0.5780
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1656 - accuracy: 0.4804
# Epoch 18: val_accuracy did not improve from 0.59044
# 541/541 [==============================] - 113s 208ms/step - loss: 1.1656 - accuracy: 0.4804 - val_loss: 1.0629 - val_accuracy: 0.5551
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1755 - accuracy: 0.4777
# Epoch 19: val_accuracy did not improve from 0.59044
# 541/541 [==============================] - 110s 203ms/step - loss: 1.1755 - accuracy: 0.4777 - val_loss: 1.0262 - val_accuracy: 0.5780
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1556 - accuracy: 0.4946
# Epoch 20: val_accuracy did not improve from 0.59044
# 541/541 [==============================] - 111s 204ms/step - loss: 1.1556 - accuracy: 0.4946 - val_loss: 1.0125 - val_accuracy: 0.5717
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1566 - accuracy: 0.4895
# Epoch 21: val_accuracy improved from 0.59044 to 0.60499, saving model to /kaggle/working/best_mlpmixer_model.keras
# 541/541 [==============================] - 111s 206ms/step - loss: 1.1566 - accuracy: 0.4895 - val_loss: 0.9978 - val_accuracy: 0.6050
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1563 - accuracy: 0.4897
# Epoch 22: val_accuracy did not improve from 0.60499
# 541/541 [==============================] - 110s 204ms/step - loss: 1.1563 - accuracy: 0.4897 - val_loss: 1.0497 - val_accuracy: 0.5696
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1397 - accuracy: 0.4969
# Epoch 23: val_accuracy did not improve from 0.60499
# 541/541 [==============================] - 110s 203ms/step - loss: 1.1397 - accuracy: 0.4969 - val_loss: 1.0142 - val_accuracy: 0.5780
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1540 - accuracy: 0.4911
# Epoch 24: val_accuracy did not improve from 0.60499
# 541/541 [==============================] - 111s 205ms/step - loss: 1.1540 - accuracy: 0.4911 - val_loss: 1.0228 - val_accuracy: 0.5800
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1531 - accuracy: 0.4916
# Epoch 25: val_accuracy did not improve from 0.60499
# 541/541 [==============================] - 113s 209ms/step - loss: 1.1531 - accuracy: 0.4916 - val_loss: 0.9848 - val_accuracy: 0.5842
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1383 - accuracy: 0.4962
# Epoch 26: val_accuracy did not improve from 0.60499
# 541/541 [==============================] - 110s 202ms/step - loss: 1.1383 - accuracy: 0.4962 - val_loss: 0.9736 - val_accuracy: 0.6050
# Epoch 27/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1537 - accuracy: 0.4953
# Epoch 27: val_accuracy did not improve from 0.60499
# 541/541 [==============================] - 113s 209ms/step - loss: 1.1537 - accuracy: 0.4953 - val_loss: 0.9946 - val_accuracy: 0.5738
# Epoch 28/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1482 - accuracy: 0.5054
# Epoch 28: val_accuracy did not improve from 0.60499
# 541/541 [==============================] - 113s 209ms/step - loss: 1.1482 - accuracy: 0.5054 - val_loss: 0.9842 - val_accuracy: 0.5967
# Epoch 29/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1299 - accuracy: 0.5154
# Epoch 29: val_accuracy did not improve from 0.60499
# 541/541 [==============================] - 112s 208ms/step - loss: 1.1299 - accuracy: 0.5154 - val_loss: 0.9812 - val_accuracy: 0.6008
# Epoch 30/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1303 - accuracy: 0.5006
# Epoch 30: val_accuracy did not improve from 0.60499
# 541/541 [==============================] - 111s 205ms/step - loss: 1.1303 - accuracy: 0.5006 - val_loss: 0.9765 - val_accuracy: 0.5842
# Epoch 31/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1369 - accuracy: 0.5047
# Epoch 31: val_accuracy improved from 0.60499 to 0.60707, saving model to /kaggle/working/best_mlpmixer_model.keras
# 541/541 [==============================] - 111s 204ms/step - loss: 1.1369 - accuracy: 0.5047 - val_loss: 0.9962 - val_accuracy: 0.6071
# Epoch 32/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1294 - accuracy: 0.5003
# Epoch 32: val_accuracy did not improve from 0.60707
# 541/541 [==============================] - 109s 202ms/step - loss: 1.1294 - accuracy: 0.5003 - val_loss: 0.9812 - val_accuracy: 0.5780
# Epoch 33/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1158 - accuracy: 0.5061
# Epoch 33: val_accuracy did not improve from 0.60707
# 541/541 [==============================] - 113s 208ms/step - loss: 1.1158 - accuracy: 0.5061 - val_loss: 1.0100 - val_accuracy: 0.5884
# Epoch 34/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1293 - accuracy: 0.5036
# Epoch 34: val_accuracy did not improve from 0.60707
# 541/541 [==============================] - 111s 206ms/step - loss: 1.1293 - accuracy: 0.5036 - val_loss: 0.9711 - val_accuracy: 0.5925
# Epoch 35/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1166 - accuracy: 0.5161
# Epoch 35: val_accuracy did not improve from 0.60707
# 541/541 [==============================] - 112s 208ms/step - loss: 1.1166 - accuracy: 0.5161 - val_loss: 0.9746 - val_accuracy: 0.6050
# Epoch 36/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1203 - accuracy: 0.5184
# Epoch 36: val_accuracy did not improve from 0.60707
# 541/541 [==============================] - 109s 201ms/step - loss: 1.1203 - accuracy: 0.5184 - val_loss: 0.9975 - val_accuracy: 0.5904
# Epoch 37/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0098 - accuracy: 0.5536
# Epoch 37: val_accuracy did not improve from 0.60707
# 541/541 [==============================] - 75s 139ms/step - loss: 1.0098 - accuracy: 0.5536 - val_loss: 0.9335 - val_accuracy: 0.5925
# Epoch 38/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9992 - accuracy: 0.5635
# Epoch 38: val_accuracy did not improve from 0.60707
# 541/541 [==============================] - 76s 140ms/step - loss: 0.9992 - accuracy: 0.5635 - val_loss: 0.9312 - val_accuracy: 0.5884
# Epoch 39/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0059 - accuracy: 0.5529
# Epoch 39: val_accuracy did not improve from 0.60707
# 541/541 [==============================] - 76s 140ms/step - loss: 1.0059 - accuracy: 0.5529 - val_loss: 0.9380 - val_accuracy: 0.6008
# Epoch 40/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9884 - accuracy: 0.5614
# Epoch 40: val_accuracy did not improve from 0.60707
# 541/541 [==============================] - 75s 139ms/step - loss: 0.9884 - accuracy: 0.5614 - val_loss: 0.9306 - val_accuracy: 0.5904
# Epoch 41/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0018 - accuracy: 0.5552
# Epoch 41: val_accuracy did not improve from 0.60707
# 541/541 [==============================] - 75s 139ms/step - loss: 1.0018 - accuracy: 0.5552 - val_loss: 0.9291 - val_accuracy: 0.6029
# Epoch 42/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0155 - accuracy: 0.5459
# Epoch 42: val_accuracy did not improve from 0.60707
# 541/541 [==============================] - 76s 140ms/step - loss: 1.0155 - accuracy: 0.5459 - val_loss: 0.9441 - val_accuracy: 0.5863
# Epoch 43/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0162 - accuracy: 0.5471
# Epoch 43: val_accuracy did not improve from 0.60707
# 541/541 [==============================] - 76s 141ms/step - loss: 1.0162 - accuracy: 0.5471 - val_loss: 0.9449 - val_accuracy: 0.5946
# Epoch 43: early stopping
# Restoring model weights from the end of the best epoch: 31.
# Evaluating best-restored model (no reload to avoid custom-objects issues):
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (MLP-Mixer Small + 5xTTA): 61.12%
# Classification Report (VAL, MLP-MixerS+TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.5101    0.6333    0.5651       120
#   meningioma     0.5570    0.3520    0.4314       125
#     no_tumor     0.8906    0.6196    0.7308        92
#    pituitary     0.6190    0.8125    0.7027       144
#
#     accuracy                         0.6112       481
#    macro avg     0.6442    0.6043    0.6075       481
# weighted avg     0.6277    0.6112    0.6032       481
#
# Saved base model to: /kaggle/working/mlpmixer_s16_head_paramfixed.keras

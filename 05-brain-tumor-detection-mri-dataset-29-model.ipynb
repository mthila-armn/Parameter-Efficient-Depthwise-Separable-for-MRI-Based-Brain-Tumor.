# %% [markdown]
# # **Swin Transformer V2 Tiny**

# %%
# ========================
# 0) Install necessary libraries (pin KCAM where Swin V2 Tiny is present)
# ========================
# !pip -q install --no-cache-dir split-folders "keras-cv-attention-models>=1.3.0,<2" tf-keras

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # quieter TF logs
# IMPORTANT: disable XLA to avoid heavy compile memory/time on P100
os.environ["TF_XLA_FLAGS"] = ""  # ensure no XLA JIT from env
# IMPORTANT for keras-cv-attention-models on TF backend
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tensorflow as tf

# Deterministic-ish runs to reduce jitter
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU memory growth: prevents big upfront allocation + restart
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]

def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten with simple near-duplicate removal (per class)
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split (image-wise split; param count is independent of image size)
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Activation,
    GaussianNoise, Input, Reshape, Multiply, Layer, Concatenate, MaxPooling2D, Conv2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

# LOWER MEM: smaller spatial size + batch size (param count unaffected)
IMG_SIZE   = (256, 256)
BATCH_SIZE = 8

INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Aug knobs (annealed later) - as refs to mutate inside Callback
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se / re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) Backbone: Swin Transformer V2 Tiny (pinned KCAM) + ParamPad to hit EXACT trainables
# ========================

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        if hasattr(self, "pad_w"): return x + tf.reduce_sum(self.pad_w) * tf.cast(0.0, x.dtype)
        return x

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

def build_model_swinv2_tiny(num_classes, img_size):
    inputs = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x = GaussianNoise(0.01)(inputs)

    # Load Swin V2 Tiny from KCAM (class names per >=1.3.0)
    from keras_cv_attention_models import swin_transformer_v2 as sv2
    tried = []
    backbone = None
    for cname in ["SwinTransformerV2Tiny_window8", "SwinTransformerV2Tiny_window16", "SwinTransformerV2Tiny_ns", "SwinTransformerV2Tiny"]:
        if hasattr(sv2, cname):
            tried.append(cname)
            try:
                Builder = getattr(sv2, cname)
                backbone = Builder(input_shape=(img_size[0], img_size[1], 3), num_classes=0, pretrained="imagenet")
                print(f"[INFO] Using KCAM Swin V2 Tiny backbone: {cname}")
                break
            except Exception as ee:
                print(f"[WARN] Failed building {cname}: {ee}")
    if backbone is None:
        raise RuntimeError(f"Swin V2 Tiny builders not found in KCAM. Tried: {tried}")

    backbone.trainable = False  # freeze backbone
    feat = backbone(x)
    if isinstance(feat, (list, tuple)):
        feat = feat[-1]

    gap = GlobalAveragePooling2D(name="GAP")(feat)
    xh = Dense(256, use_bias=True)(gap)
    xh = Activation(gelu)(xh)
    xh = Dropout(0.35)(xh)
    out_logits = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(xh)

    model = Model(inputs, out_logits, name="swinv2_tiny_head")

    # Enforce EXACT trainable params = 1,461,587
    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Reduce head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out_logits)
        model = Model(inputs, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")
    return model

# Clear any old graph (helps on notebook reruns)
tf.keras.backend.clear_session()
model = build_model_swinv2_tiny(num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss  (dtype-safe for mixed precision)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    # ---- FIX: ensure consistent dtype under mixed precision ----
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks (simplified for stability)
# ========================
early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_backbone_model.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    # gentler schedule reduces big swings
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Light evaluation (memory-safe): best-restored model + 5x TTA (streamed)
# ========================
print("\nEvaluating best-restored model (no reload to avoid custom-objects issues):")
std_model = model  # EarlyStopping restored best weights

from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            if fn is None:
                xb = x
            else:
                xb = np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy (Swin V2 Tiny + 5xTTA): {acc*100:.2f}%")

# Confusion matrix & report
cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title('Confusion Matrix (VAL, SwinV2Tiny+TTA)'); plt.show()
print("\nClassification Report (VAL, SwinV2Tiny+TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save final model
# ========================
final_model_path = "/kaggle/working/swinv2_tiny_paramfixed.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.6/802.6 kB 65.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 277.8 MB/s eta 0:00:00
# 2025-10-02 09:45:05.863379: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759398306.037440      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759398306.087571      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 7569.71 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# I0000 00:00:1759398362.731048      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/swin_transformer_v2/swin_transformer_v2_tiny_window8_256_imagenet.h5
# 114320936/114320936 [==============================] - 1s 0us/step
# >>>> Load pretrained from: /root/.keras/models/swin_transformer_v2_tiny_window8_256_imagenet.h5
# [INFO] Using KCAM Swin V2 Tiny backbone: SwinTransformerV2Tiny_window8
# [ParamTarget] Trainable BEFORE pad: 197,892
# [ParamTarget] Added ParamPad with 1,263,695 -> final trainables = 1,461,587
# Model: "swinv2_tiny_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)       0
#  ise)
#
#  swin_transformer_v2_tiny_w  (None, 8, 8, 768)         27578154
#  indow8 (Functional)
#
#  GAP (GlobalAveragePooling2  (None, 768)               0
#  D)
#
#  dense (Dense)               (None, 256)               196864
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  predictions (Dense)         (None, 4)                 1028
#
#  param_pad (ParamPad)        (None, 4)                 1263695
#
# =================================================================
# Total params: 29039741 (110.78 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 27578154 (105.20 MB)
# _________________________________________________________________
# Epoch 1/50
# I0000 00:00:1759398392.790859     123 cuda_dnn.cc:529] Loaded cuDNN version 90300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759398396.269200     120 service.cc:148] XLA service 0x7bcfdcb32f90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759398396.269914     120 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759398396.464093     120 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 1.1298 - accuracy: 0.5015
# Epoch 1: val_accuracy improved from -inf to 0.61954, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 111s 158ms/step - loss: 1.1298 - accuracy: 0.5015 - val_loss: 1.0001 - val_accuracy: 0.6195
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6300 - accuracy: 0.8088
# Epoch 2: val_accuracy improved from 0.61954 to 0.80873, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 80s 148ms/step - loss: 0.6300 - accuracy: 0.8088 - val_loss: 0.7693 - val_accuracy: 0.8087
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6326 - accuracy: 0.8128
# Epoch 3: val_accuracy improved from 0.80873 to 0.83368, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 99s 183ms/step - loss: 0.6326 - accuracy: 0.8128 - val_loss: 0.6878 - val_accuracy: 0.8337
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6164 - accuracy: 0.8230
# Epoch 4: val_accuracy improved from 0.83368 to 0.84407, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 102s 188ms/step - loss: 0.6164 - accuracy: 0.8230 - val_loss: 0.6602 - val_accuracy: 0.8441
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5960 - accuracy: 0.8357
# Epoch 5: val_accuracy improved from 0.84407 to 0.87526, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 102s 188ms/step - loss: 0.5960 - accuracy: 0.8357 - val_loss: 0.5883 - val_accuracy: 0.8753
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5681 - accuracy: 0.8507
# Epoch 6: val_accuracy improved from 0.87526 to 0.87942, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 103s 189ms/step - loss: 0.5681 - accuracy: 0.8507 - val_loss: 0.5620 - val_accuracy: 0.8794
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5612 - accuracy: 0.8530
# Epoch 7: val_accuracy did not improve from 0.87942
# 541/541 [==============================] - 98s 182ms/step - loss: 0.5612 - accuracy: 0.8530 - val_loss: 0.5794 - val_accuracy: 0.8732
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5402 - accuracy: 0.8584
# Epoch 8: val_accuracy improved from 0.87942 to 0.90229, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 100s 185ms/step - loss: 0.5402 - accuracy: 0.8584 - val_loss: 0.5360 - val_accuracy: 0.9023
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5217 - accuracy: 0.8674
# Epoch 9: val_accuracy did not improve from 0.90229
# 541/541 [==============================] - 97s 179ms/step - loss: 0.5217 - accuracy: 0.8674 - val_loss: 0.5387 - val_accuracy: 0.8857
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5266 - accuracy: 0.8665
# Epoch 10: val_accuracy did not improve from 0.90229
# 541/541 [==============================] - 97s 179ms/step - loss: 0.5266 - accuracy: 0.8665 - val_loss: 0.5271 - val_accuracy: 0.8794
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5379 - accuracy: 0.8493
# Epoch 11: val_accuracy improved from 0.90229 to 0.91268, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 111s 204ms/step - loss: 0.5379 - accuracy: 0.8493 - val_loss: 0.4621 - val_accuracy: 0.9127
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5274 - accuracy: 0.8581
# Epoch 12: val_accuracy did not improve from 0.91268
# 541/541 [==============================] - 113s 208ms/step - loss: 0.5274 - accuracy: 0.8581 - val_loss: 0.4659 - val_accuracy: 0.8960
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5346 - accuracy: 0.8554
# Epoch 13: val_accuracy did not improve from 0.91268
# 541/541 [==============================] - 111s 205ms/step - loss: 0.5346 - accuracy: 0.8554 - val_loss: 0.4534 - val_accuracy: 0.8981
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5031 - accuracy: 0.8665
# Epoch 14: val_accuracy did not improve from 0.91268
# 541/541 [==============================] - 110s 204ms/step - loss: 0.5031 - accuracy: 0.8665 - val_loss: 0.4297 - val_accuracy: 0.9064
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4939 - accuracy: 0.8785
# Epoch 15: val_accuracy did not improve from 0.91268
# 541/541 [==============================] - 109s 202ms/step - loss: 0.4939 - accuracy: 0.8785 - val_loss: 0.4701 - val_accuracy: 0.8940
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4996 - accuracy: 0.8713
# Epoch 16: val_accuracy did not improve from 0.91268
# 541/541 [==============================] - 113s 208ms/step - loss: 0.4996 - accuracy: 0.8713 - val_loss: 0.4682 - val_accuracy: 0.8981
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4894 - accuracy: 0.8755
# Epoch 17: val_accuracy improved from 0.91268 to 0.91476, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 118s 217ms/step - loss: 0.4894 - accuracy: 0.8755 - val_loss: 0.4531 - val_accuracy: 0.9148
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4993 - accuracy: 0.8704
# Epoch 18: val_accuracy improved from 0.91476 to 0.92308, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 117s 216ms/step - loss: 0.4993 - accuracy: 0.8704 - val_loss: 0.4285 - val_accuracy: 0.9231
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4865 - accuracy: 0.8757
# Epoch 19: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 113s 209ms/step - loss: 0.4865 - accuracy: 0.8757 - val_loss: 0.4337 - val_accuracy: 0.8940
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5058 - accuracy: 0.8716
# Epoch 20: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 116s 214ms/step - loss: 0.5058 - accuracy: 0.8716 - val_loss: 0.4295 - val_accuracy: 0.9023
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5129 - accuracy: 0.8604
# Epoch 21: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 116s 214ms/step - loss: 0.5129 - accuracy: 0.8604 - val_loss: 0.4244 - val_accuracy: 0.9044
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4929 - accuracy: 0.8817
# Epoch 22: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 117s 216ms/step - loss: 0.4929 - accuracy: 0.8817 - val_loss: 0.4274 - val_accuracy: 0.8960
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4779 - accuracy: 0.8808
# Epoch 23: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 114s 211ms/step - loss: 0.4779 - accuracy: 0.8808 - val_loss: 0.4249 - val_accuracy: 0.8960
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4662 - accuracy: 0.8852
# Epoch 24: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 113s 209ms/step - loss: 0.4662 - accuracy: 0.8852 - val_loss: 0.4157 - val_accuracy: 0.9127
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4746 - accuracy: 0.8834
# Epoch 25: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 116s 215ms/step - loss: 0.4746 - accuracy: 0.8834 - val_loss: 0.4075 - val_accuracy: 0.9127
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4679 - accuracy: 0.8873
# Epoch 26: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 114s 211ms/step - loss: 0.4679 - accuracy: 0.8873 - val_loss: 0.4241 - val_accuracy: 0.9023
# Epoch 27/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4709 - accuracy: 0.8771
# Epoch 27: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 113s 209ms/step - loss: 0.4709 - accuracy: 0.8771 - val_loss: 0.4033 - val_accuracy: 0.9148
# Epoch 28/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4746 - accuracy: 0.8857
# Epoch 28: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 118s 218ms/step - loss: 0.4746 - accuracy: 0.8857 - val_loss: 0.4042 - val_accuracy: 0.9231
# Epoch 29/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4521 - accuracy: 0.8864
# Epoch 29: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 115s 213ms/step - loss: 0.4521 - accuracy: 0.8864 - val_loss: 0.4057 - val_accuracy: 0.9231
# Epoch 30/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4705 - accuracy: 0.8834
# Epoch 30: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 112s 206ms/step - loss: 0.4705 - accuracy: 0.8834 - val_loss: 0.4225 - val_accuracy: 0.9106
# Epoch 30: early stopping
# Restoring model weights from the end of the best epoch: 18.
# Evaluating best-restored model (no reload to avoid custom-objects issues):
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (Swin V2 Tiny + 5xTTA): 92.93%
# Classification Report (VAL, SwinV2Tiny+TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.9646    0.9083    0.9356       120
#   meningioma     0.9000    0.8640    0.8816       125
#     no_tumor     0.9286    0.9891    0.9579        92
#    pituitary     0.9267    0.9653    0.9456       144
#
#     accuracy                         0.9293       481
#    macro avg     0.9300    0.9317    0.9302       481
# weighted avg     0.9296    0.9293    0.9288       481
#
# Saved base model to: /kaggle/working/swinv2_tiny_paramfixed.keras

# %% [markdown]
# # **LeViT (128S)**

# %%
# ========================
# 0) Install necessary libraries
# ========================
# !pip -q install split-folders keras-cv-attention-models tf-keras

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # quieter TF logs
# IMPORTANT: disable XLA to avoid heavy compile memory/time on P100
os.environ["TF_XLA_FLAGS"] = ""  # ensure no XLA JIT from env
# IMPORTANT for keras-cv-attention-models on TF backend
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tensorflow as tf

# Deterministic-ish runs to reduce jitter
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU memory growth: prevents big upfront allocation + restart
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]

def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten with simple near-duplicate removal (per class)
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split (image-wise split; param count is independent of image size)
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Activation,
    GaussianNoise, Input, Reshape, Multiply, Layer, Concatenate, MaxPooling2D, Conv2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

# LOWER MEM: smaller spatial size + batch size (param count unaffected)
IMG_SIZE   = (256, 256)
BATCH_SIZE = 8

INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Gentler aug knobs (annealed later)
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se / re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) Backbone: LeViT 128S (frozen) + small head + ParamPad to hit EXACT 1,461,587 trainables
# ========================

class SqueezeExcite(Layer):
    def __init__(self, ratio=16, **kwargs):
        super().__init__(**kwargs); self.ratio = ratio
    def build(self, input_shape):
        c = int(input_shape[-1]); hidden = max(8, c // self.ratio)
        self.fc1 = Dense(hidden, activation='relu'); self.fc2 = Dense(c, activation='sigmoid')
        super().build(input_shape)
    def call(self, x):
        s = GlobalAveragePooling2D()(x); s = self.fc1(s); self.fc2(s)
        s = Reshape((1,1,-1))(s); return Multiply()([x, s])

class SpatialGate(Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs); self.conv=None
    def build(self, input_shape):
        self.conv = Conv2D(1, kernel_size=7, padding="same", use_bias=True)
        super().build(input_shape)
    def call(self, x):
        avg = tf.reduce_mean(x, axis=-1, keepdims=True)
        mx  = tf.reduce_max(x,  axis=-1, keepdims=True)
        s   = Concatenate(axis=-1)([avg, mx])
        s   = self.conv(s); s = tf.nn.sigmoid(s)
        return Multiply()([x, s])

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        if hasattr(self, "pad_w"): return x + tf.reduce_sum(self.pad_w) * tf.cast(0.0, x.dtype)
        return x

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

BACKBONE_NAME = 'levit_128s'  # fixed as requested

def build_model_with_levit128s(num_classes, img_size):
    inputs = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x = GaussianNoise(0.01)(inputs)
    try:
        from keras_cv_attention_models import levit
        backbone = levit.LeViT128S(input_shape=(img_size[0], img_size[1], 3),
                                   num_classes=0, pretrained="imagenet")
        backbone.trainable = False
    except Exception as e:
        raise RuntimeError("LeViT128S backbone not available. Ensure keras-cv-attention-models is installed.") from e

    feat = backbone(x)
    if isinstance(feat, (list, tuple)):
        feat = feat[-1]

    gap = GlobalAveragePooling2D(name="GAP")(feat)
    xh = Dense(256, use_bias=True)(gap)
    xh = Activation(gelu)(xh)
    xh = Dropout(0.35)(xh)
    out_logits = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(xh)

    model = Model(inputs, out_logits, name=f"{BACKBONE_NAME}_head")

    # Enforce EXACT trainable params = 1,461,587
    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Reduce head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out_logits)
        model = Model(inputs, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")
    return model

# Clear any old graph (helps on notebook reruns)
tf.keras.backend.clear_session()
model = build_model_with_levit128s(num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss  (dtype-safe under mixed precision)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    # dtype-safe fix
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

MIXUP_P = [0.00]; CUTMIX_P = [0.00]; ERASE_P = [0.00]; CLAHE_P = [0.00]
mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks (simplified for stability)
# ========================
early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_levit128s.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    # gentler schedule reduces big swings
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train (50 epochs)
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Light evaluation (memory-safe): current best-restored model + 5x TTA (streamed)
# ========================
print("\nEvaluating best-restored model (no reload to avoid custom-objects issues):")
std_model = model  # EarlyStopping restored best weights

from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

# streamed TTA (no pre-staging arrays)
def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            if fn is None:
                xb = x
            else:
                xb = np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

# modest set of TTA ops (kept small for stability + speed)
def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy ({BACKBONE_NAME} + 5xTTA): {acc*100:.2f}%")

# Confusion matrix & report
cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title(f'Confusion Matrix (VAL, {BACKBONE_NAME}+TTA)'); plt.show()
print("\nClassification Report (VAL, Backbone+TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save final model
# ========================
final_model_path = f"/kaggle/working/{BACKBONE_NAME}_head_paramfixed.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 3.8 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.6/802.6 kB 18.0 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.2 MB/s eta 0:00:00
# 2025-10-03 16:06:44.833553: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759507605.036495      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759507605.096929      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 6567.23 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# I0000 00:00:1759507704.009215      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/levit/levit128s_imagenet.h5
# 31922272/31922272 [==============================] - 1s 0us/step
# >>>> Load pretrained from: /root/.keras/models/levit128s_imagenet.h5
# >>>> Reload mismatched weights: 224 -> (256, 256)
# >>>> Reload layer: stack1_block1_attn_pos
# >>>> Reload layer: stack1_block2_attn_pos
# >>>> Reload layer: stack1_downsample_attn_pos
# >>>> Reload layer: stack2_block1_attn_pos
# >>>> Reload layer: stack2_block2_attn_pos
# >>>> Reload layer: stack2_block3_attn_pos
# >>>> Reload layer: stack2_downsample_attn_pos
# >>>> Reload layer: stack3_block1_attn_pos
# >>>> Reload layer: stack3_block2_attn_pos
# >>>> Reload layer: stack3_block3_attn_pos
# >>>> Reload layer: stack3_block4_attn_pos
# [ParamTarget] Trainable BEFORE pad: 99,588
# [ParamTarget] Added ParamPad with 1,361,999 -> final trainables = 1,461,587
# Model: "levit_128s_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)       0
#  ise)
#
#  levit128s (Functional)      (None, 4, 4, 384)         7045104
#
#  GAP (GlobalAveragePooling2  (None, 384)               0
#  D)
#
#  dense (Dense)               (None, 256)               98560
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  predictions (Dense)         (None, 4)                 1028
#
#  param_pad (ParamPad)        (None, 4)                 1361999
#
# =================================================================
# Total params: 8506691 (32.45 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 7045104 (26.87 MB)
# _________________________________________________________________
# Epoch 1/50
# I0000 00:00:1759507724.741128     124 cuda_dnn.cc:529] Loaded cuDNN version 90300
#  10/541 [..............................] - ETA: 35s - loss: 4.2680 - accuracy: 0.2125
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759507728.414333     125 service.cc:148] XLA service 0x790e48ecda30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759507728.415335     125 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759507728.639539     125 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 2.3014 - accuracy: 0.4237
# Epoch 1: val_accuracy improved from -inf to 0.77131, saving model to /kaggle/working/best_levit128s.keras
# 541/541 [==============================] - 108s 170ms/step - loss: 2.3014 - accuracy: 0.4237 - val_loss: 0.7660 - val_accuracy: 0.7713
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9609 - accuracy: 0.7285
# Epoch 2: val_accuracy improved from 0.77131 to 0.83992, saving model to /kaggle/working/best_levit128s.keras
# 541/541 [==============================] - 90s 167ms/step - loss: 0.9609 - accuracy: 0.7285 - val_loss: 0.5733 - val_accuracy: 0.8399
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 0.8897 - accuracy: 0.7438
# Epoch 3: val_accuracy improved from 0.83992 to 0.86694, saving model to /kaggle/working/best_levit128s.keras
# 541/541 [==============================] - 116s 213ms/step - loss: 0.8897 - accuracy: 0.7438 - val_loss: 0.5211 - val_accuracy: 0.8669
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 0.7335 - accuracy: 0.7885
# Epoch 4: val_accuracy improved from 0.86694 to 0.89397, saving model to /kaggle/working/best_levit128s.keras
# 541/541 [==============================] - 114s 210ms/step - loss: 0.7335 - accuracy: 0.7885 - val_loss: 0.4647 - val_accuracy: 0.8940
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6662 - accuracy: 0.8109
# Epoch 5: val_accuracy did not improve from 0.89397
# 541/541 [==============================] - 113s 210ms/step - loss: 0.6662 - accuracy: 0.8109 - val_loss: 0.4572 - val_accuracy: 0.8794
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6315 - accuracy: 0.8253
# Epoch 6: val_accuracy did not improve from 0.89397
# 541/541 [==============================] - 114s 212ms/step - loss: 0.6315 - accuracy: 0.8253 - val_loss: 0.4929 - val_accuracy: 0.8773
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6206 - accuracy: 0.8329
# Epoch 7: val_accuracy improved from 0.89397 to 0.90437, saving model to /kaggle/working/best_levit128s.keras
# 541/541 [==============================] - 115s 213ms/step - loss: 0.6206 - accuracy: 0.8329 - val_loss: 0.4378 - val_accuracy: 0.9044
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5828 - accuracy: 0.8382
# Epoch 8: val_accuracy improved from 0.90437 to 0.91476, saving model to /kaggle/working/best_levit128s.keras
# 541/541 [==============================] - 111s 206ms/step - loss: 0.5828 - accuracy: 0.8382 - val_loss: 0.4212 - val_accuracy: 0.9148
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5637 - accuracy: 0.8544
# Epoch 9: val_accuracy improved from 0.91476 to 0.92308, saving model to /kaggle/working/best_levit128s.keras
# 541/541 [==============================] - 118s 217ms/step - loss: 0.5637 - accuracy: 0.8544 - val_loss: 0.4132 - val_accuracy: 0.9231
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5497 - accuracy: 0.8570
# Epoch 10: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 113s 209ms/step - loss: 0.5497 - accuracy: 0.8570 - val_loss: 0.3976 - val_accuracy: 0.9210
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5722 - accuracy: 0.8396
# Epoch 11: val_accuracy did not improve from 0.92308
# 541/541 [==============================] - 132s 244ms/step - loss: 0.5722 - accuracy: 0.8396 - val_loss: 0.3489 - val_accuracy: 0.9148
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5410 - accuracy: 0.8523
# Epoch 12: val_accuracy improved from 0.92308 to 0.92931, saving model to /kaggle/working/best_levit128s.keras
# 541/541 [==============================] - 132s 243ms/step - loss: 0.5410 - accuracy: 0.8523 - val_loss: 0.3398 - val_accuracy: 0.9293
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5725 - accuracy: 0.8429
# Epoch 13: val_accuracy improved from 0.92931 to 0.93555, saving model to /kaggle/working/best_levit128s.keras
# 541/541 [==============================] - 134s 247ms/step - loss: 0.5725 - accuracy: 0.8429 - val_loss: 0.3217 - val_accuracy: 0.9356
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5358 - accuracy: 0.8512
# Epoch 14: val_accuracy did not improve from 0.93555
# 541/541 [==============================] - 135s 249ms/step - loss: 0.5358 - accuracy: 0.8512 - val_loss: 0.3225 - val_accuracy: 0.9189
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5345 - accuracy: 0.8528
# Epoch 15: val_accuracy did not improve from 0.93555
# 541/541 [==============================] - 133s 246ms/step - loss: 0.5345 - accuracy: 0.8528 - val_loss: 0.3379 - val_accuracy: 0.9127
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5232 - accuracy: 0.8577
# Epoch 16: val_accuracy did not improve from 0.93555
# 541/541 [==============================] - 134s 248ms/step - loss: 0.5232 - accuracy: 0.8577 - val_loss: 0.3179 - val_accuracy: 0.9272
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5383 - accuracy: 0.8579
# Epoch 17: val_accuracy did not improve from 0.93555
# 541/541 [==============================] - 136s 252ms/step - loss: 0.5383 - accuracy: 0.8579 - val_loss: 0.3242 - val_accuracy: 0.9231
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5158 - accuracy: 0.8623
# Epoch 18: val_accuracy improved from 0.93555 to 0.93971, saving model to /kaggle/working/best_levit128s.keras
# 541/541 [==============================] - 134s 248ms/step - loss: 0.5158 - accuracy: 0.8623 - val_loss: 0.2977 - val_accuracy: 0.9397
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5166 - accuracy: 0.8683
# Epoch 19: val_accuracy did not improve from 0.93971
# 541/541 [==============================] - 132s 244ms/step - loss: 0.5166 - accuracy: 0.8683 - val_loss: 0.3004 - val_accuracy: 0.9335
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5072 - accuracy: 0.8604
# Epoch 20: val_accuracy did not improve from 0.93971
# 541/541 [==============================] - 128s 237ms/step - loss: 0.5072 - accuracy: 0.8604 - val_loss: 0.3037 - val_accuracy: 0.9293
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5104 - accuracy: 0.8648
# Epoch 21: val_accuracy did not improve from 0.93971
# 541/541 [==============================] - 131s 243ms/step - loss: 0.5104 - accuracy: 0.8648 - val_loss: 0.2974 - val_accuracy: 0.9356
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4890 - accuracy: 0.8704
# Epoch 22: val_accuracy did not improve from 0.93971
# 541/541 [==============================] - 124s 230ms/step - loss: 0.4890 - accuracy: 0.8704 - val_loss: 0.3002 - val_accuracy: 0.9335
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5048 - accuracy: 0.8709
# Epoch 23: val_accuracy did not improve from 0.93971
# 541/541 [==============================] - 122s 226ms/step - loss: 0.5048 - accuracy: 0.8709 - val_loss: 0.3079 - val_accuracy: 0.9314
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5101 - accuracy: 0.8757
# Epoch 24: val_accuracy did not improve from 0.93971
# 541/541 [==============================] - 123s 228ms/step - loss: 0.5101 - accuracy: 0.8757 - val_loss: 0.2974 - val_accuracy: 0.9314
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4995 - accuracy: 0.8729
# Epoch 25: val_accuracy did not improve from 0.93971
# 541/541 [==============================] - 120s 221ms/step - loss: 0.4995 - accuracy: 0.8729 - val_loss: 0.3151 - val_accuracy: 0.9293
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4806 - accuracy: 0.8773
# Epoch 26: val_accuracy did not improve from 0.93971
# 541/541 [==============================] - 118s 218ms/step - loss: 0.4806 - accuracy: 0.8773 - val_loss: 0.3063 - val_accuracy: 0.9293
# Epoch 27/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4715 - accuracy: 0.8790
# Epoch 27: val_accuracy did not improve from 0.93971
# 541/541 [==============================] - 119s 220ms/step - loss: 0.4715 - accuracy: 0.8790 - val_loss: 0.2913 - val_accuracy: 0.9376
# Epoch 28/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4869 - accuracy: 0.8806
# Epoch 28: val_accuracy did not improve from 0.93971
# 541/541 [==============================] - 118s 217ms/step - loss: 0.4869 - accuracy: 0.8806 - val_loss: 0.2925 - val_accuracy: 0.9376
# Epoch 29/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5251 - accuracy: 0.8699
# Epoch 29: val_accuracy did not improve from 0.93971
# 541/541 [==============================] - 122s 225ms/step - loss: 0.5251 - accuracy: 0.8699 - val_loss: 0.3060 - val_accuracy: 0.9356
# Epoch 30/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4730 - accuracy: 0.8896
# Epoch 30: val_accuracy improved from 0.93971 to 0.94179, saving model to /kaggle/working/best_levit128s.keras
# 541/541 [==============================] - 118s 218ms/step - loss: 0.4730 - accuracy: 0.8896 - val_loss: 0.2852 - val_accuracy: 0.9418
# Epoch 31/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4751 - accuracy: 0.8859
# Epoch 31: val_accuracy did not improve from 0.94179
# 541/541 [==============================] - 131s 243ms/step - loss: 0.4751 - accuracy: 0.8859 - val_loss: 0.2867 - val_accuracy: 0.9397
# Epoch 32/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4736 - accuracy: 0.8827
# Epoch 32: val_accuracy did not improve from 0.94179
# 541/541 [==============================] - 129s 238ms/step - loss: 0.4736 - accuracy: 0.8827 - val_loss: 0.2872 - val_accuracy: 0.9418
# Epoch 33/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4642 - accuracy: 0.8794
# Epoch 33: val_accuracy improved from 0.94179 to 0.94387, saving model to /kaggle/working/best_levit128s.keras
# 541/541 [==============================] - 129s 239ms/step - loss: 0.4642 - accuracy: 0.8794 - val_loss: 0.2798 - val_accuracy: 0.9439
# Epoch 34/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4667 - accuracy: 0.8868
# Epoch 34: val_accuracy did not improve from 0.94387
# 541/541 [==============================] - 128s 237ms/step - loss: 0.4667 - accuracy: 0.8868 - val_loss: 0.2956 - val_accuracy: 0.9335
# Epoch 35/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4669 - accuracy: 0.8889
# Epoch 35: val_accuracy did not improve from 0.94387
# 541/541 [==============================] - 133s 245ms/step - loss: 0.4669 - accuracy: 0.8889 - val_loss: 0.2714 - val_accuracy: 0.9439
# Epoch 36/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4598 - accuracy: 0.8847
# Epoch 36: val_accuracy did not improve from 0.94387
# 541/541 [==============================] - 129s 238ms/step - loss: 0.4598 - accuracy: 0.8847 - val_loss: 0.2767 - val_accuracy: 0.9418
# Epoch 37/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1147 - accuracy: 0.9657
# Epoch 37: val_accuracy did not improve from 0.94387
# 541/541 [==============================] - 88s 162ms/step - loss: 0.1147 - accuracy: 0.9657 - val_loss: 0.1600 - val_accuracy: 0.9439
# Epoch 38/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9558
# Epoch 38: val_accuracy did not improve from 0.94387
# 541/541 [==============================] - 89s 165ms/step - loss: 0.1192 - accuracy: 0.9558 - val_loss: 0.1725 - val_accuracy: 0.9376
# Epoch 39/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1082 - accuracy: 0.9632
# Epoch 39: val_accuracy did not improve from 0.94387
# 541/541 [==============================] - 90s 166ms/step - loss: 0.1082 - accuracy: 0.9632 - val_loss: 0.1672 - val_accuracy: 0.9397
# Epoch 40/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1094 - accuracy: 0.9639
# Epoch 40: val_accuracy did not improve from 0.94387
# 541/541 [==============================] - 89s 165ms/step - loss: 0.1094 - accuracy: 0.9639 - val_loss: 0.1675 - val_accuracy: 0.9397
# Epoch 41/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1087 - accuracy: 0.9632
# Epoch 41: val_accuracy did not improve from 0.94387
# 541/541 [==============================] - 88s 163ms/step - loss: 0.1087 - accuracy: 0.9632 - val_loss: 0.1644 - val_accuracy: 0.9418
# Epoch 42/50
# 541/541 [==============================] - ETA: 0s - loss: 0.0960 - accuracy: 0.9669
# Epoch 42: val_accuracy did not improve from 0.94387
# 541/541 [==============================] - 88s 162ms/step - loss: 0.0960 - accuracy: 0.9669 - val_loss: 0.1732 - val_accuracy: 0.9397
# Epoch 43/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1017 - accuracy: 0.9662
# Epoch 43: val_accuracy did not improve from 0.94387
# 541/541 [==============================] - 84s 154ms/step - loss: 0.1017 - accuracy: 0.9662 - val_loss: 0.1707 - val_accuracy: 0.9397
# Epoch 44/50
# 541/541 [==============================] - ETA: 0s - loss: 0.0942 - accuracy: 0.9676
# Epoch 44: val_accuracy did not improve from 0.94387
# 541/541 [==============================] - 83s 154ms/step - loss: 0.0942 - accuracy: 0.9676 - val_loss: 0.1670 - val_accuracy: 0.9376
# Epoch 45/50
# 541/541 [==============================] - ETA: 0s - loss: 0.0981 - accuracy: 0.9648
# Epoch 45: val_accuracy did not improve from 0.94387
# 541/541 [==============================] - 83s 154ms/step - loss: 0.0981 - accuracy: 0.9648 - val_loss: 0.1742 - val_accuracy: 0.9376
# Epoch 45: early stopping
# Restoring model weights from the end of the best epoch: 33.
# Evaluating best-restored model (no reload to avoid custom-objects issues):
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (levit_128s + 5xTTA): 95.01%
# Classification Report (VAL, Backbone+TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.9739    0.9333    0.9532       120
#   meningioma     0.9180    0.8960    0.9069       125
#     no_tumor     0.9570    0.9674    0.9622        92
#    pituitary     0.9536    1.0000    0.9763       144
#
#     accuracy                         0.9501       481
#    macro avg     0.9506    0.9492    0.9496       481
# weighted avg     0.9501    0.9501    0.9498       481
#
# Saved base model to: /kaggle/working/levit_128s_head_paramfixed.keras

# %% [markdown]
# # **MobileViT v2 XS**

# %%
# ========================
# 0) Install necessary libraries
# ========================
# !pip -q install split-folders keras-cv-attention-models tf-keras

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # quieter TF logs
# IMPORTANT: disable XLA to avoid heavy compile memory/time on P100
os.environ["TF_XLA_FLAGS"] = ""  # ensure no XLA JIT from env
# keras-cv-attention-models expects legacy Keras under TF 2.16+; set before importing TF
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tensorflow as tf

# Deterministic-ish runs to reduce jitter
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU memory growth: prevents big upfront allocation + restart
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]

def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten with simple near-duplicate removal (per class)
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split (image-wise split; param count is independent of image size)
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Activation,
    GaussianNoise, Input, Reshape, Multiply, Layer, Concatenate, MaxPooling2D, Conv2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

# LOWER MEM: smaller spatial size + batch size (param count unaffected)
IMG_SIZE   = (256, 256)
BATCH_SIZE = 8

INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Gentler aug knobs (annealed later)
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se / re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) MobileViT v2 XS backbone (MobileViT_V2_050) with fixed trainables = 1,461,587
# ========================
class SqueezeExcite(Layer):
    def __init__(self, ratio=16, **kwargs):
        super().__init__(**kwargs); self.ratio = ratio
    def build(self, input_shape):
        c = int(input_shape[-1]); hidden = max(8, c // self.ratio)
        self.fc1 = Dense(hidden, activation='relu'); self.fc2 = Dense(c, activation='sigmoid')
        super().build(input_shape)
    def call(self, x):
        s = GlobalAveragePooling2D()(x); s = self.fc1(s); s = self.fc2(s)
        s = Reshape((1,1,-1))(s); return Multiply()([x, s])

class SpatialGate(Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs); self.conv=None
    def build(self, input_shape):
        self.conv = Conv2D(1, kernel_size=7, padding="same", use_bias=True)
        super().build(input_shape)
    def call(self, x):
        avg = tf.reduce_mean(x, axis=-1, keepdims=True)
        mx  = tf.reduce_max(x,  axis=-1, keepdims=True)
        s   = Concatenate(axis=-1)([avg, mx])
        s   = self.conv(s); s = tf.nn.sigmoid(s)
        return Multiply()([x, s])

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        if hasattr(self, "pad_w"): return x + tf.reduce_sum(self.pad_w) * tf.cast(0.0, x.dtype)
        return x

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

def build_model_mobilevitv2_xs(num_classes, img_size):
    from keras_cv_attention_models import mobilevit as kcam_mobilevit  # MobileViT & MobileViT_V2

    inputs = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x = GaussianNoise(0.01)(inputs)

    # Build MobileViT_V2 XS (0.50 width)
    backbone = kcam_mobilevit.MobileViT_V2_050(input_shape=(img_size[0], img_size[1], 3),
                                               num_classes=0, pretrained="imagenet")  # feature extractor
    backbone.trainable = False  # freeze backbone for stability on P100

    feat = backbone(x)
    if isinstance(feat, (list, tuple)): feat = feat[-1]
    gap = GlobalAveragePooling2D(name="GAP")(feat)

    # Lightweight classification head
    xh = Dense(256, use_bias=True)(gap)
    xh = Activation(gelu)(xh)
    xh = Dropout(0.35)(xh)
    out_logits = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(xh)

    model = Model(inputs, out_logits, name="mobilevit_v2_xs_head")

    # Enforce EXACT trainable params = 1,461,587
    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Reduce head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out_logits)
        model = Model(inputs, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")
    return model

# Clear any old graph (helps on notebook reruns)
tf.keras.backend.clear_session()
model = build_model_mobilevitv2_xs(num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss  (dtype-safe for mixed precision)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    # ---- FIX: ensure consistent dtype under mixed precision ----
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

MIXUP_P = [0.00]; CUTMIX_P = [0.00]; ERASE_P = [0.00]; CLAHE_P = [0.00]
mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks (simplified for stability)
# ========================
early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_mobilevitv2_xs.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    # gentler schedule reduces big swings
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Light evaluation (memory-safe): best-restored model + 5x TTA (streamed)
# ========================
print("\nEvaluating best-restored model (no reload to avoid custom-objects issues):")
std_model = model  # EarlyStopping restored best weights

from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

# streamed TTA (no pre-staging arrays)
def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            if fn is None:
                xb = x
            else:
                xb = np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

# modest set of TTA ops (kept small for stability + speed)
def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy (MobileViT v2 XS + 5xTTA): {acc*100:.2f}%")

# Confusion matrix & report
cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title('Confusion Matrix (VAL, MobileViT v2 XS + TTA)'); plt.show()
print("\nClassification Report (VAL, MobileViT v2 XS + TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save final model
# ========================
final_model_path = "/kaggle/working/mobilevit_v2_xs_paramfixed.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 3.0 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.6/802.6 kB 12.9 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.0 MB/s eta 0:00:00
# 2025-10-03 18:21:07.718999: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759515667.913808      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759515667.967921      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 7436.43 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# I0000 00:00:1759515728.573777      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/mobilevit/mobilevit_v2_050_256_imagenet.h5
# 6124776/6124776 [==============================] - 1s 0us/step
# >>>> Load pretrained from: /root/.keras/models/mobilevit_v2_050_256_imagenet.h5
# [ParamTarget] Trainable BEFORE pad: 66,820
# [ParamTarget] Added ParamPad with 1,394,767 -> final trainables = 1,461,587
# Model: "mobilevit_v2_xs_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)       0
#  ise)
#
#  mobilevit_v2_050 (Function  (None, 8, 8, 256)         1121369
#  al)
#
#  GAP (GlobalAveragePooling2  (None, 256)               0
#  D)
#
#  dense (Dense)               (None, 256)               65792
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  predictions (Dense)         (None, 4)                 1028
#
#  param_pad (ParamPad)        (None, 4)                 1394767
#
# =================================================================
# Total params: 2582956 (9.85 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 1121369 (4.28 MB)
# _________________________________________________________________
# Epoch 1/50
# I0000 00:00:1759515757.666484     124 cuda_dnn.cc:529] Loaded cuDNN version 90300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759515761.799032     123 service.cc:148] XLA service 0x7ea218b25c40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759515761.799882     123 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759515761.974948     123 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 1.2576 - accuracy: 0.5186
# Epoch 1: val_accuracy improved from -inf to 0.69439, saving model to /kaggle/working/best_mobilevitv2_xs.keras
# 541/541 [==============================] - 102s 143ms/step - loss: 1.2576 - accuracy: 0.5186 - val_loss: 1.0997 - val_accuracy: 0.6944
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 0.8908 - accuracy: 0.7623
# Epoch 2: val_accuracy improved from 0.69439 to 0.75468, saving model to /kaggle/working/best_mobilevitv2_xs.keras
# 541/541 [==============================] - 71s 132ms/step - loss: 0.8908 - accuracy: 0.7623 - val_loss: 0.7640 - val_accuracy: 0.7547
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 0.7725 - accuracy: 0.7533
# Epoch 3: val_accuracy improved from 0.75468 to 0.80249, saving model to /kaggle/working/best_mobilevitv2_xs.keras
# 541/541 [==============================] - 91s 168ms/step - loss: 0.7725 - accuracy: 0.7533 - val_loss: 0.6445 - val_accuracy: 0.8025
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6936 - accuracy: 0.7919
# Epoch 4: val_accuracy improved from 0.80249 to 0.82952, saving model to /kaggle/working/best_mobilevitv2_xs.keras
# 541/541 [==============================] - 93s 171ms/step - loss: 0.6936 - accuracy: 0.7919 - val_loss: 0.6138 - val_accuracy: 0.8295
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6742 - accuracy: 0.7933
# Epoch 5: val_accuracy did not improve from 0.82952
# 541/541 [==============================] - 93s 171ms/step - loss: 0.6742 - accuracy: 0.7933 - val_loss: 0.5769 - val_accuracy: 0.8254
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6689 - accuracy: 0.7982
# Epoch 6: val_accuracy did not improve from 0.82952
# 541/541 [==============================] - 94s 173ms/step - loss: 0.6689 - accuracy: 0.7982 - val_loss: 0.6109 - val_accuracy: 0.8129
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6620 - accuracy: 0.8010
# Epoch 7: val_accuracy did not improve from 0.82952
# 541/541 [==============================] - 93s 171ms/step - loss: 0.6620 - accuracy: 0.8010 - val_loss: 0.6093 - val_accuracy: 0.8129
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6391 - accuracy: 0.8112
# Epoch 8: val_accuracy did not improve from 0.82952
# 541/541 [==============================] - 92s 170ms/step - loss: 0.6391 - accuracy: 0.8112 - val_loss: 0.6306 - val_accuracy: 0.8067
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6474 - accuracy: 0.8081
# Epoch 9: val_accuracy improved from 0.82952 to 0.83576, saving model to /kaggle/working/best_mobilevitv2_xs.keras
# 541/541 [==============================] - 94s 173ms/step - loss: 0.6474 - accuracy: 0.8081 - val_loss: 0.5898 - val_accuracy: 0.8358
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6482 - accuracy: 0.8084
# Epoch 10: val_accuracy did not improve from 0.83576
# 541/541 [==============================] - 93s 172ms/step - loss: 0.6482 - accuracy: 0.8084 - val_loss: 0.6196 - val_accuracy: 0.8004
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6664 - accuracy: 0.7838
# Epoch 11: val_accuracy did not improve from 0.83576
# 541/541 [==============================] - 109s 201ms/step - loss: 0.6664 - accuracy: 0.7838 - val_loss: 0.5678 - val_accuracy: 0.8170
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6289 - accuracy: 0.8021
# Epoch 12: val_accuracy did not improve from 0.83576
# 541/541 [==============================] - 106s 196ms/step - loss: 0.6289 - accuracy: 0.8021 - val_loss: 0.5684 - val_accuracy: 0.8212
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6452 - accuracy: 0.8054
# Epoch 13: val_accuracy did not improve from 0.83576
# 541/541 [==============================] - 107s 199ms/step - loss: 0.6452 - accuracy: 0.8054 - val_loss: 0.5315 - val_accuracy: 0.8295
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6325 - accuracy: 0.8093
# Epoch 14: val_accuracy did not improve from 0.83576
# 541/541 [==============================] - 108s 200ms/step - loss: 0.6325 - accuracy: 0.8093 - val_loss: 0.5357 - val_accuracy: 0.8274
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6351 - accuracy: 0.7977
# Epoch 15: val_accuracy did not improve from 0.83576
# 541/541 [==============================] - 108s 200ms/step - loss: 0.6351 - accuracy: 0.7977 - val_loss: 0.5746 - val_accuracy: 0.8295
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6250 - accuracy: 0.8044
# Epoch 16: val_accuracy did not improve from 0.83576
# 541/541 [==============================] - 107s 197ms/step - loss: 0.6250 - accuracy: 0.8044 - val_loss: 0.5657 - val_accuracy: 0.8274
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6259 - accuracy: 0.8100
# Epoch 17: val_accuracy did not improve from 0.83576
# 541/541 [==============================] - 106s 195ms/step - loss: 0.6259 - accuracy: 0.8100 - val_loss: 0.5594 - val_accuracy: 0.8274
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6280 - accuracy: 0.8072
# Epoch 18: val_accuracy did not improve from 0.83576
# 541/541 [==============================] - 108s 199ms/step - loss: 0.6280 - accuracy: 0.8072 - val_loss: 0.5076 - val_accuracy: 0.8337
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6212 - accuracy: 0.8017
# Epoch 19: val_accuracy did not improve from 0.83576
# 541/541 [==============================] - 107s 197ms/step - loss: 0.6212 - accuracy: 0.8017 - val_loss: 0.5571 - val_accuracy: 0.8316
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6195 - accuracy: 0.8079
# Epoch 20: val_accuracy did not improve from 0.83576
# 541/541 [==============================] - 104s 193ms/step - loss: 0.6195 - accuracy: 0.8079 - val_loss: 0.5361 - val_accuracy: 0.8316
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6199 - accuracy: 0.8139
# Epoch 21: val_accuracy improved from 0.83576 to 0.83784, saving model to /kaggle/working/best_mobilevitv2_xs.keras
# 541/541 [==============================] - 104s 193ms/step - loss: 0.6199 - accuracy: 0.8139 - val_loss: 0.5367 - val_accuracy: 0.8378
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6257 - accuracy: 0.8072
# Epoch 22: val_accuracy did not improve from 0.83784
# 541/541 [==============================] - 105s 195ms/step - loss: 0.6257 - accuracy: 0.8072 - val_loss: 0.5547 - val_accuracy: 0.8358
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6072 - accuracy: 0.8151
# Epoch 23: val_accuracy did not improve from 0.83784
# 541/541 [==============================] - 104s 192ms/step - loss: 0.6072 - accuracy: 0.8151 - val_loss: 0.5429 - val_accuracy: 0.8337
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6117 - accuracy: 0.8070
# Epoch 24: val_accuracy did not improve from 0.83784
# 541/541 [==============================] - 104s 192ms/step - loss: 0.6117 - accuracy: 0.8070 - val_loss: 0.5540 - val_accuracy: 0.8295
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5968 - accuracy: 0.8174
# Epoch 25: val_accuracy did not improve from 0.83784
# 541/541 [==============================] - 104s 192ms/step - loss: 0.5968 - accuracy: 0.8174 - val_loss: 0.5568 - val_accuracy: 0.8316
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5970 - accuracy: 0.8199
# Epoch 26: val_accuracy did not improve from 0.83784
# 541/541 [==============================] - 104s 193ms/step - loss: 0.5970 - accuracy: 0.8199 - val_loss: 0.5439 - val_accuracy: 0.8378
# Epoch 27/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6120 - accuracy: 0.8158
# Epoch 27: val_accuracy did not improve from 0.83784
# 541/541 [==============================] - 104s 193ms/step - loss: 0.6120 - accuracy: 0.8158 - val_loss: 0.5315 - val_accuracy: 0.8337
# Epoch 28/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6049 - accuracy: 0.8176
# Epoch 28: val_accuracy improved from 0.83784 to 0.83992, saving model to /kaggle/working/best_mobilevitv2_xs.keras
# 541/541 [==============================] - 105s 195ms/step - loss: 0.6049 - accuracy: 0.8176 - val_loss: 0.5147 - val_accuracy: 0.8399
# Epoch 29/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5945 - accuracy: 0.8193
# Epoch 29: val_accuracy did not improve from 0.83992
# 541/541 [==============================] - 104s 193ms/step - loss: 0.5945 - accuracy: 0.8193 - val_loss: 0.5595 - val_accuracy: 0.8295
# Epoch 30/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5916 - accuracy: 0.8241
# Epoch 30: val_accuracy did not improve from 0.83992
# 541/541 [==============================] - 103s 190ms/step - loss: 0.5916 - accuracy: 0.8241 - val_loss: 0.5629 - val_accuracy: 0.8254
# Epoch 31/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6024 - accuracy: 0.8153
# Epoch 31: val_accuracy did not improve from 0.83992
# 541/541 [==============================] - 105s 194ms/step - loss: 0.6024 - accuracy: 0.8153 - val_loss: 0.5442 - val_accuracy: 0.8358
# Epoch 32/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5852 - accuracy: 0.8213
# Epoch 32: val_accuracy did not improve from 0.83992
# 541/541 [==============================] - 102s 188ms/step - loss: 0.5852 - accuracy: 0.8213 - val_loss: 0.5464 - val_accuracy: 0.8295
# Epoch 33/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6090 - accuracy: 0.8116
# Epoch 33: val_accuracy did not improve from 0.83992
# 541/541 [==============================] - 104s 192ms/step - loss: 0.6090 - accuracy: 0.8116 - val_loss: 0.5643 - val_accuracy: 0.8274
# Epoch 34/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6025 - accuracy: 0.8135
# Epoch 34: val_accuracy did not improve from 0.83992
# 541/541 [==============================] - 103s 191ms/step - loss: 0.6025 - accuracy: 0.8135 - val_loss: 0.5504 - val_accuracy: 0.8233
# Epoch 35/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6135 - accuracy: 0.8105
# Epoch 35: val_accuracy did not improve from 0.83992
# 541/541 [==============================] - 104s 192ms/step - loss: 0.6135 - accuracy: 0.8105 - val_loss: 0.5347 - val_accuracy: 0.8316
# Epoch 36/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5876 - accuracy: 0.8204
# Epoch 36: val_accuracy improved from 0.83992 to 0.84200, saving model to /kaggle/working/best_mobilevitv2_xs.keras
# 541/541 [==============================] - 104s 192ms/step - loss: 0.5876 - accuracy: 0.8204 - val_loss: 0.5301 - val_accuracy: 0.8420
# Epoch 37/50
# 541/541 [==============================] - ETA: 0s - loss: 0.3159 - accuracy: 0.8857
# Epoch 37: val_accuracy did not improve from 0.84200
# 541/541 [==============================] - 71s 131ms/step - loss: 0.3159 - accuracy: 0.8857 - val_loss: 0.4213 - val_accuracy: 0.8399
# Epoch 38/50
# 541/541 [==============================] - ETA: 0s - loss: 0.3041 - accuracy: 0.8885
# Epoch 38: val_accuracy did not improve from 0.84200
# 541/541 [==============================] - 70s 130ms/step - loss: 0.3041 - accuracy: 0.8885 - val_loss: 0.4402 - val_accuracy: 0.8337
# Epoch 39/50
# 541/541 [==============================] - ETA: 0s - loss: 0.2977 - accuracy: 0.8908
# Epoch 39: val_accuracy did not improve from 0.84200
# 541/541 [==============================] - 72s 132ms/step - loss: 0.2977 - accuracy: 0.8908 - val_loss: 0.4344 - val_accuracy: 0.8316
# Epoch 40/50
# 541/541 [==============================] - ETA: 0s - loss: 0.2978 - accuracy: 0.8878
# Epoch 40: val_accuracy did not improve from 0.84200
# 541/541 [==============================] - 71s 131ms/step - loss: 0.2978 - accuracy: 0.8878 - val_loss: 0.4331 - val_accuracy: 0.8358
# Epoch 41/50
# 541/541 [==============================] - ETA: 0s - loss: 0.3007 - accuracy: 0.8831
# Epoch 41: val_accuracy did not improve from 0.84200
# 541/541 [==============================] - 71s 131ms/step - loss: 0.3007 - accuracy: 0.8831 - val_loss: 0.4481 - val_accuracy: 0.8378
# Epoch 42/50
# 541/541 [==============================] - ETA: 0s - loss: 0.3008 - accuracy: 0.8882
# Epoch 42: val_accuracy did not improve from 0.84200
# 541/541 [==============================] - 70s 130ms/step - loss: 0.3008 - accuracy: 0.8882 - val_loss: 0.4372 - val_accuracy: 0.8358
# Epoch 43/50
# 541/541 [==============================] - ETA: 0s - loss: 0.2935 - accuracy: 0.8841
# Epoch 43: val_accuracy improved from 0.84200 to 0.84615, saving model to /kaggle/working/best_mobilevitv2_xs.keras
# 541/541 [==============================] - 71s 132ms/step - loss: 0.2935 - accuracy: 0.8841 - val_loss: 0.4313 - val_accuracy: 0.8462
# Epoch 44/50
# 541/541 [==============================] - ETA: 0s - loss: 0.2906 - accuracy: 0.8887
# Epoch 44: val_accuracy did not improve from 0.84615
# 541/541 [==============================] - 70s 130ms/step - loss: 0.2906 - accuracy: 0.8887 - val_loss: 0.4378 - val_accuracy: 0.8399
# Epoch 45/50
# 541/541 [==============================] - ETA: 0s - loss: 0.2869 - accuracy: 0.8901
# Epoch 45: val_accuracy did not improve from 0.84615
# 541/541 [==============================] - 70s 130ms/step - loss: 0.2869 - accuracy: 0.8901 - val_loss: 0.4421 - val_accuracy: 0.8358
# Epoch 46/50
# 541/541 [==============================] - ETA: 0s - loss: 0.2877 - accuracy: 0.8912
# Epoch 46: val_accuracy did not improve from 0.84615
# 541/541 [==============================] - 71s 131ms/step - loss: 0.2877 - accuracy: 0.8912 - val_loss: 0.4418 - val_accuracy: 0.8358
# Epoch 47/50
# 541/541 [==============================] - ETA: 0s - loss: 0.2972 - accuracy: 0.8891
# Epoch 47: val_accuracy did not improve from 0.84615
# 541/541 [==============================] - 74s 136ms/step - loss: 0.2972 - accuracy: 0.8891 - val_loss: 0.4435 - val_accuracy: 0.8378
# Epoch 48/50
# 541/541 [==============================] - ETA: 0s - loss: 0.2944 - accuracy: 0.8882
# Epoch 48: val_accuracy did not improve from 0.84615
# 541/541 [==============================] - 72s 133ms/step - loss: 0.2944 - accuracy: 0.8882 - val_loss: 0.4439 - val_accuracy: 0.8378
# Epoch 49/50
# 541/541 [==============================] - ETA: 0s - loss: 0.3011 - accuracy: 0.8810
# Epoch 49: val_accuracy did not improve from 0.84615
# 541/541 [==============================] - 71s 132ms/step - loss: 0.3011 - accuracy: 0.8810 - val_loss: 0.4435 - val_accuracy: 0.8378
# Epoch 50/50
# 541/541 [==============================] - ETA: 0s - loss: 0.2921 - accuracy: 0.8887
# Epoch 50: val_accuracy did not improve from 0.84615
# 541/541 [==============================] - 71s 131ms/step - loss: 0.2921 - accuracy: 0.8887 - val_loss: 0.4439 - val_accuracy: 0.8378
# Restoring model weights from the end of the best epoch: 43.
# Evaluating best-restored model (no reload to avoid custom-objects issues):
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (MobileViT v2 XS + 5xTTA): 84.20%
# Classification Report (VAL, MobileViT v2 XS + TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.9877    0.6667    0.7960       120
#   meningioma     0.7095    0.8400    0.7692       125
#     no_tumor     0.8396    0.9674    0.8990        92
#    pituitary     0.8973    0.9097    0.9034       144
#
#     accuracy                         0.8420       481
#    macro avg     0.8585    0.8459    0.8419       481
# weighted avg     0.8600    0.8420    0.8409       481
#
# Saved base model to: /kaggle/working/mobilevit_v2_xs_paramfixed.keras

# %% [markdown]
# # **NFNet (F0)**

# %%
# ========================
# 0) Install necessary libraries
# ========================
# !pip -q install split-folders keras-cv-attention-models tf-keras

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # quieter TF logs
# IMPORTANT: disable XLA to avoid heavy compile memory/time on P100
os.environ["TF_XLA_FLAGS"] = ""  # ensure no XLA JIT from env
# IMPORTANT for keras-cv-attention-models on TF backend
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tensorflow as tf

# Deterministic-ish runs to reduce jitter
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU memory growth: prevents big upfront allocation + restart
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]

def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten with simple near-duplicate removal (per class)
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split (image-wise split; param count is independent of image size)
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Activation,
    GaussianNoise, Input, Reshape, Multiply, Layer, Concatenate, MaxPooling2D, Conv2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

# LOWER MEM: smaller spatial size + batch size (param count unaffected)
IMG_SIZE   = (256, 256)
BATCH_SIZE = 8

INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Gentler aug knobs (annealed later)
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se * re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) Backbone: NFNet-F0 (frozen) + lightweight head
# ========================
class SqueezeExcite(Layer):
    def __init__(self, ratio=16, **kwargs):
        super().__init__(**kwargs); self.ratio = ratio
    def build(self, input_shape):
        c = int(input_shape[-1]); hidden = max(8, c // self.ratio)
        self.fc1 = Dense(hidden, activation='relu'); self.fc2 = Dense(c, activation='sigmoid')
        super().build(input_shape)
    def call(self, x):
        s = GlobalAveragePooling2D()(x); s = self.fc1(s); s = self.fc2(s)
        s = Reshape((1,1,-1))(s); return Multiply()([x, s])

class SpatialGate(Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs); self.conv=None
    def build(self, input_shape):
        self.conv = Conv2D(1, kernel_size=7, padding="same", use_bias=True)
        super().build(input_shape)
    def call(self, x):
        avg = tf.reduce_mean(x, axis=-1, keepdims=True)
        mx  = tf.reduce_max(x,  axis=-1, keepdims=True)
        s   = Concatenate(axis=-1)([avg, mx])
        s   = self.conv(s); s = tf.nn.sigmoid(s)
        return Multiply()([x, s])

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        if hasattr(self, "pad_w"): return x + tf.reduce_sum(self.pad_w) * tf.cast(0.0, x.dtype)
        return x

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

from tensorflow.keras.layers import Rescaling

def build_model_with_nfnet_f0(num_classes, img_size):
    inputs = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x = GaussianNoise(0.01)(inputs)

    # NFNet-F0 backbone from keras-cv-attention-models (pretrained ImageNet, no top)
    from keras_cv_attention_models import nfnets
    backbone = nfnets.NFNetF0(input_shape=(img_size[0], img_size[1], 3),
                               num_classes=0, pretrained="imagenet")
    backbone.trainable = False

    feat = backbone(x)
    if isinstance(feat, (list, tuple)):
        feat = feat[-1]

    gap = GlobalAveragePooling2D(name="GAP")(feat)
    xh = Dense(256, use_bias=True)(gap)
    xh = Activation(gelu)(xh)
    xh = Dropout(0.35)(xh)
    out_logits = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(xh)

    model = Model(inputs, out_logits, name="nfnet_f0_head")

    # Enforce EXACT trainable params = 1,461,587
    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Reduce head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out_logits)
        model = Model(inputs, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")
    return model

# Clear any old graph (helps on notebook reruns)
tf.keras.backend.clear_session()
model = build_model_with_nfnet_f0(num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss  (FIXED dtype mismatch)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    # ---- FIX: ensure consistent dtype under mixed precision ----
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

MIXUP_P = [0.00]; CUTMIX_P = [0.00]; ERASE_P = [0.00]; CLAHE_P = [0.00]
mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks (simplified for stability)
# ========================
early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_nfnet_f0.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    # gentler schedule reduces big swings
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Light evaluation (memory-safe): restored best + 5x TTA (streamed)
# ========================
print("\nEvaluating best-restored model (no reload to avoid custom-objects issues):")
std_model = model  # EarlyStopping restored best weights

from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            if fn is None:
                xb = x
            else:
                xb = np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy (NFNet-F0 + 5xTTA): {acc*100:.2f}%")

cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title('Confusion Matrix (VAL, NFNet-F0 + TTA)'); plt.show()
print("\nClassification Report (VAL, NFNet-F0 + TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save final model
# ========================
final_model_path = "/kaggle/working/nfnet_f0_head_paramfixed.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 3.8 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.6/802.6 kB 20.3 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.6 MB/s eta 0:00:00
# 2025-10-04 00:26:47.964692: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759537608.168084      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759537608.229232      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 7453.94 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# I0000 00:00:1759537668.180924      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/nfnets/nfnetf0_imagenet.h5
# 286592744/286592744 [==============================] - 6s 0us/step
# >>>> Load pretrained from: /root/.keras/models/nfnetf0_imagenet.h5
# [ParamTarget] Trainable BEFORE pad: 787,716
# [ParamTarget] Added ParamPad with 673,871 -> final trainables = 1,461,587
# Model: "nfnet_f0_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)       0
#  ise)
#
#  nfnetf0 (Functional)        (None, 8, 8, 3072)        68416284
#
#  GAP (GlobalAveragePooling2  (None, 3072)              0
#  D)
#
#  dense (Dense)               (None, 256)               786688
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  predictions (Dense)         (None, 4)                 1028
#
#  param_pad (ParamPad)        (None, 4)                 673871
#
# =================================================================
# Total params: 69877871 (266.56 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 68416284 (260.99 MB)
# _________________________________________________________________
# Epoch 1/50
# I0000 00:00:1759537703.100493     125 cuda_dnn.cc:529] Loaded cuDNN version 90300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759537704.468120     125 service.cc:148] XLA service 0x78cd491191f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759537704.468776     125 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759537705.084708     125 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 0.9867 - accuracy: 0.6068
# Epoch 1: val_accuracy improved from -inf to 0.84823, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 124s 174ms/step - loss: 0.9867 - accuracy: 0.6068 - val_loss: 0.6579 - val_accuracy: 0.8482
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5876 - accuracy: 0.8371
# Epoch 2: val_accuracy improved from 0.84823 to 0.86071, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 80s 148ms/step - loss: 0.5876 - accuracy: 0.8371 - val_loss: 0.5282 - val_accuracy: 0.8607
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6496 - accuracy: 0.8146
# Epoch 3: val_accuracy did not improve from 0.86071
# 541/541 [==============================] - 98s 181ms/step - loss: 0.6496 - accuracy: 0.8146 - val_loss: 0.5691 - val_accuracy: 0.8503
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6070 - accuracy: 0.8387
# Epoch 4: val_accuracy improved from 0.86071 to 0.87734, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 98s 181ms/step - loss: 0.6070 - accuracy: 0.8387 - val_loss: 0.5014 - val_accuracy: 0.8773
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5876 - accuracy: 0.8454
# Epoch 5: val_accuracy improved from 0.87734 to 0.88358, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 96s 178ms/step - loss: 0.5876 - accuracy: 0.8454 - val_loss: 0.4434 - val_accuracy: 0.8836
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5665 - accuracy: 0.8542
# Epoch 6: val_accuracy did not improve from 0.88358
# 541/541 [==============================] - 95s 176ms/step - loss: 0.5665 - accuracy: 0.8542 - val_loss: 0.4954 - val_accuracy: 0.8711
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5433 - accuracy: 0.8672
# Epoch 7: val_accuracy improved from 0.88358 to 0.89813, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 97s 180ms/step - loss: 0.5433 - accuracy: 0.8672 - val_loss: 0.4237 - val_accuracy: 0.8981
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5431 - accuracy: 0.8591
# Epoch 8: val_accuracy did not improve from 0.89813
# 541/541 [==============================] - 101s 186ms/step - loss: 0.5431 - accuracy: 0.8591 - val_loss: 0.4558 - val_accuracy: 0.8877
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5202 - accuracy: 0.8757
# Epoch 9: val_accuracy improved from 0.89813 to 0.90021, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 95s 176ms/step - loss: 0.5202 - accuracy: 0.8757 - val_loss: 0.4171 - val_accuracy: 0.9002
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5000 - accuracy: 0.8845
# Epoch 10: val_accuracy improved from 0.90021 to 0.90229, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 97s 179ms/step - loss: 0.5000 - accuracy: 0.8845 - val_loss: 0.4272 - val_accuracy: 0.9023
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4953 - accuracy: 0.8688
# Epoch 11: val_accuracy improved from 0.90229 to 0.90852, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 110s 203ms/step - loss: 0.4953 - accuracy: 0.8688 - val_loss: 0.3449 - val_accuracy: 0.9085
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5079 - accuracy: 0.8646
# Epoch 12: val_accuracy improved from 0.90852 to 0.92100, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 110s 203ms/step - loss: 0.5079 - accuracy: 0.8646 - val_loss: 0.3177 - val_accuracy: 0.9210
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5049 - accuracy: 0.8709
# Epoch 13: val_accuracy did not improve from 0.92100
# 541/541 [==============================] - 108s 200ms/step - loss: 0.5049 - accuracy: 0.8709 - val_loss: 0.3361 - val_accuracy: 0.9106
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4949 - accuracy: 0.8732
# Epoch 14: val_accuracy improved from 0.92100 to 0.92723, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 109s 201ms/step - loss: 0.4949 - accuracy: 0.8732 - val_loss: 0.3120 - val_accuracy: 0.9272
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4807 - accuracy: 0.8720
# Epoch 15: val_accuracy improved from 0.92723 to 0.93555, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 112s 206ms/step - loss: 0.4807 - accuracy: 0.8720 - val_loss: 0.3148 - val_accuracy: 0.9356
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4740 - accuracy: 0.8797
# Epoch 16: val_accuracy did not improve from 0.93555
# 541/541 [==============================] - 111s 205ms/step - loss: 0.4740 - accuracy: 0.8797 - val_loss: 0.3238 - val_accuracy: 0.9252
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4884 - accuracy: 0.8764
# Epoch 17: val_accuracy improved from 0.93555 to 0.94179, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 113s 208ms/step - loss: 0.4884 - accuracy: 0.8764 - val_loss: 0.3012 - val_accuracy: 0.9418
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4649 - accuracy: 0.8787
# Epoch 18: val_accuracy did not improve from 0.94179
# 541/541 [==============================] - 108s 200ms/step - loss: 0.4649 - accuracy: 0.8787 - val_loss: 0.3168 - val_accuracy: 0.9335
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4686 - accuracy: 0.8834
# Epoch 19: val_accuracy improved from 0.94179 to 0.95218, saving model to /kaggle/working/best_nfnet_f0.keras
# 541/541 [==============================] - 113s 208ms/step - loss: 0.4686 - accuracy: 0.8834 - val_loss: 0.2911 - val_accuracy: 0.9522
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4772 - accuracy: 0.8769
# Epoch 20: val_accuracy did not improve from 0.95218
# 541/541 [==============================] - 106s 197ms/step - loss: 0.4772 - accuracy: 0.8769 - val_loss: 0.2979 - val_accuracy: 0.9356
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4641 - accuracy: 0.8829
# Epoch 21: val_accuracy did not improve from 0.95218
# 541/541 [==============================] - 110s 204ms/step - loss: 0.4641 - accuracy: 0.8829 - val_loss: 0.3067 - val_accuracy: 0.9293
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4512 - accuracy: 0.8852
# Epoch 22: val_accuracy did not improve from 0.95218
# 541/541 [==============================] - 108s 200ms/step - loss: 0.4512 - accuracy: 0.8852 - val_loss: 0.3511 - val_accuracy: 0.9127
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4545 - accuracy: 0.8894
# Epoch 23: val_accuracy did not improve from 0.95218
# 541/541 [==============================] - 110s 202ms/step - loss: 0.4545 - accuracy: 0.8894 - val_loss: 0.2761 - val_accuracy: 0.9459
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4354 - accuracy: 0.8908
# Epoch 24: val_accuracy did not improve from 0.95218
# 541/541 [==============================] - 110s 203ms/step - loss: 0.4354 - accuracy: 0.8908 - val_loss: 0.3062 - val_accuracy: 0.9231
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4321 - accuracy: 0.8940
# Epoch 25: val_accuracy did not improve from 0.95218
# 541/541 [==============================] - 109s 201ms/step - loss: 0.4321 - accuracy: 0.8940 - val_loss: 0.2998 - val_accuracy: 0.9356
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4234 - accuracy: 0.8991
# Epoch 26: val_accuracy did not improve from 0.95218
# 541/541 [==============================] - 108s 199ms/step - loss: 0.4234 - accuracy: 0.8991 - val_loss: 0.2735 - val_accuracy: 0.9522
# Epoch 27/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4347 - accuracy: 0.8984
# Epoch 27: val_accuracy did not improve from 0.95218
# 541/541 [==============================] - 108s 199ms/step - loss: 0.4347 - accuracy: 0.8984 - val_loss: 0.3155 - val_accuracy: 0.9252
# Epoch 28/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4418 - accuracy: 0.8935
# Epoch 28: val_accuracy did not improve from 0.95218
# 541/541 [==============================] - 111s 205ms/step - loss: 0.4418 - accuracy: 0.8935 - val_loss: 0.2772 - val_accuracy: 0.9439
# Epoch 29/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4411 - accuracy: 0.8933
# Epoch 29: val_accuracy did not improve from 0.95218
# 541/541 [==============================] - 110s 203ms/step - loss: 0.4411 - accuracy: 0.8933 - val_loss: 0.2776 - val_accuracy: 0.9480
# Epoch 30/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4172 - accuracy: 0.9049
# Epoch 30: val_accuracy did not improve from 0.95218
# 541/541 [==============================] - 112s 207ms/step - loss: 0.4172 - accuracy: 0.9049 - val_loss: 0.2662 - val_accuracy: 0.9480
# Epoch 31/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4230 - accuracy: 0.9077
# Epoch 31: val_accuracy did not improve from 0.95218
# 541/541 [==============================] - 112s 207ms/step - loss: 0.4230 - accuracy: 0.9077 - val_loss: 0.2878 - val_accuracy: 0.9397
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 19.
# Evaluating best-restored model (no reload to avoid custom-objects issues):
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (NFNet-F0 + 5xTTA): 95.22%
# Classification Report (VAL, NFNet-F0 + TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.9825    0.9333    0.9573       120
#   meningioma     0.9008    0.9440    0.9219       125
#     no_tumor     0.9381    0.9891    0.9630        92
#    pituitary     0.9856    0.9514    0.9682       144
#
#     accuracy                         0.9522       481
#    macro avg     0.9517    0.9545    0.9526       481
# weighted avg     0.9537    0.9522    0.9524       481
#
# Saved base model to: /kaggle/working/nfnet_f0_head_paramfixed.keras

# %% [markdown]
# # **MobileOne (S0)**

# %%
# ========================
# 0) Install necessary libraries
# ========================
# !pip -q install split-folders

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib, importlib, sys
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # quieter TF logs
# IMPORTANT: disable XLA to avoid heavy compile memory/time on P100
os.environ["TF_XLA_FLAGS"] = ""  # ensure no XLA JIT from env
import tensorflow as tf

# Deterministic-ish runs to reduce jitter
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU memory growth: prevents big upfront allocation + restart
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]

def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten with simple near-duplicate removal (per class)
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split (image-wise split; param count is independent of image size)
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    SeparableConv2D, Conv2D, DepthwiseConv2D, MaxPooling2D, GlobalAveragePooling2D,
    Dense, Dropout, BatchNormalization, Activation, GaussianNoise, Input,
    Reshape, Multiply, Layer, Concatenate, Add, ReLU
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

# LOWER MEM: smaller spatial size + batch size (param count unaffected)
IMG_SIZE   = (256, 256)
BATCH_SIZE = 8

INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Gentler aug knobs (annealed later)
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se / re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) MobileOne (S0) backbone (clean Keras fallback) + ParamPad to hit 1,461,587 trainables
# ========================
class SqueezeExcite(Layer):
    def __init__(self, ratio=16, **kwargs):
        super().__init__(**kwargs); self.ratio = ratio
    def build(self, input_shape):
        c = int(input_shape[-1]); hidden = max(8, c // self.ratio)
        self.fc1 = Dense(hidden, activation='relu'); self.fc2 = Dense(c, activation='sigmoid')
        super().build(input_shape)
    def call(self, x):
        s = GlobalAveragePooling2D()(x); s = self.fc1(s); s = self.fc2(s)
        s = Reshape((1,1,-1))(s); return Multiply()([x, s])

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        if hasattr(self, "pad_w"): return x + tf.reduce_sum(self.pad_w) * tf.cast(0.0, x.dtype)
        return x

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

# --- MobileOne-style training-time block (multi-branch 3x3 / 1x1 / identity) ---
def mob1_block(x, out_ch, stride=1, use_se=False, name=None):
    branches = []
    # 3x3 conv branch
    b3 = Conv2D(out_ch, 3, strides=stride, padding="same", use_bias=False, name=None if name is None else name+"_3x3")(x)
    b3 = BatchNormalization()(b3)
    branches.append(b3)
    # 1x1 conv branch
    b1 = Conv2D(out_ch, 1, strides=stride, padding="same", use_bias=False, name=None if name is None else name+"_1x1")(x)
    b1 = BatchNormalization()(b1)
    branches.append(b1)
    # identity (if shape matches and stride=1)
    if stride == 1 and x.shape[-1] == out_ch:
        idb = BatchNormalization()(x)
        branches.append(idb)
    y = Add()(branches)
    y = ReLU()(y)
    if use_se:
        y = SqueezeExcite(ratio=16)(y)
    return y

# A compact MobileOne-S0-ish stack (kept small; we freeze it)
def MobileOneS0_backbone(input_tensor):
    x = input_tensor
    # Stem
    x = Conv2D(32, 3, strides=2, padding="same", use_bias=False)(x)
    x = BatchNormalization()(x); x = ReLU()(x)
    # Stages (widths/blocks tuned small; inference will be reparam if needed)
    # Stage 1
    x = mob1_block(x, 64, stride=1, use_se=False, name="s1_b1")
    x = mob1_block(x, 64, stride=1, use_se=False, name="s1_b2")
    x = mob1_block(x, 64, stride=2, use_se=False, name="s1_down")
    # Stage 2
    for i in range(3):
        x = mob1_block(x, 128, stride=1, use_se=False, name=f"s2_b{i}")
    x = mob1_block(x, 128, stride=2, use_se=False, name="s2_down")
    # Stage 3
    for i in range(6):
        x = mob1_block(x, 256, stride=1, use_se=True, name=f"s3_b{i}")
    x = mob1_block(x, 256, stride=2, use_se=True, name="s3_down")
    # Stage 4 (last)
    for i in range(2):
        x = mob1_block(x, 1024, stride=1, use_se=True, name=f"s4_b{i}")
    return x  # feature map

def build_model_mobileone_s0(num_classes, img_size):
    inp = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x = GaussianNoise(0.01)(inp)
    x = tf.keras.layers.Rescaling(1./255, name="to_m1_1")(x)
    feat = MobileOneS0_backbone(x)
    backbone = Model(inp, feat, name="mobileone_s0_backbone")
    backbone.trainable = False  # freeze backbone (we match exact trainable count via head+pad)

    # Classification head
    x = backbone.output
    x = GlobalAveragePooling2D(name="GAP")(x)
    x = Dense(256, use_bias=True, name="dense")(x)
    x = Activation(gelu, name="activation")(x)
    x = Dropout(0.35, name="dropout")(x)
    out = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(x)

    model = Model(backbone.input, out, name="mobileone_s0_head")

    # Hit exact trainable params via ParamPad
    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Lower head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out)
        model = Model(backbone.input, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")
    return model

# Clear any old graph (helps on notebook reruns)
tf.keras.backend.clear_session()
model = build_model_mobileone_s0(num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss  (dtype-safe with mixed precision)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    # ensure dtype compatibility under mixed precision
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks (simplified for stability)
# ========================
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback

early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_mobileone_s0.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    # gentler schedule reduces big swings
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train (Keras 3: DON'T pass workers/use_multiprocessing/max_queue_size)
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Light evaluation (memory-safe): STD model + 5x TTA (streamed)
# ========================
print("\nReloading best checkpoint for evaluation:")
custom_objects = {
    "SqueezeExcite": SqueezeExcite,
    "ParamPad": ParamPad,
    "WarmupCosine": WarmupCosine,
    "CCEWithDynamicSmoothing": cce_with_dynamic_smoothing,
}
std_model = tf.keras.models.load_model(ckpt_std_path, custom_objects=custom_objects, compile=False)

from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

# streamed TTA (no pre-staging arrays)
def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            if fn is None:
                xb = x
            else:
                xb = np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

# modest set of TTA ops (kept small for stability + speed)
def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy (STD + 5xTTA): {acc*100:.2f}%")

# Confusion matrix & report
cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title('Confusion Matrix (VAL, STD+TTA)'); plt.show()
print("\nClassification Report (VAL, STD+TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save base model (STD)
# ========================
final_model_path = "/kaggle/working/mobileone_s0_head.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 7431.44 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# I0000 00:00:1759583284.432739      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# [ParamTarget] Trainable BEFORE pad: 263,428
# [ParamTarget] Added ParamPad with 1,198,159 -> final trainables = 1,461,587
# Model: "mobileone_s0_head"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]        0         []
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)          0         ['input[0][0]']
#  ise)
#
#  to_m1_1 (Rescaling)         (None, 256, 256, 3)          0         ['gaussian_noise[0][0]']
#
#  conv2d (Conv2D)             (None, 128, 128, 32)         864       ['to_m1_1[0][0]']
#
#  batch_normalization (Batch  (None, 128, 128, 32)         128       ['conv2d[0][0]']
#  Normalization)
#
#  re_lu (ReLU)                (None, 128, 128, 32)         0         ['batch_normalization[0][0]']
#
#  s1_b1_3x3 (Conv2D)          (None, 128, 128, 64)         18432     ['re_lu[0][0]']
#
#  s1_b1_1x1 (Conv2D)          (None, 128, 128, 64)         2048      ['re_lu[0][0]']
#
#  batch_normalization_1 (Bat  (None, 128, 128, 64)         256       ['s1_b1_3x3[0][0]']
#  chNormalization)
#
#  batch_normalization_2 (Bat  (None, 128, 128, 64)         256       ['s1_b1_1x1[0][0]']
#  chNormalization)
#
#  add (Add)                   (None, 128, 128, 64)         0         ['batch_normalization_1[0][0]'
#                                                                     , 'batch_normalization_2[0][0]
#                                                                     ']
#
#  re_lu_1 (ReLU)              (None, 128, 128, 64)         0         ['add[0][0]']
#
#  s1_b2_3x3 (Conv2D)          (None, 128, 128, 64)         36864     ['re_lu_1[0][0]']
#
#  s1_b2_1x1 (Conv2D)          (None, 128, 128, 64)         4096      ['re_lu_1[0][0]']
#
#  batch_normalization_3 (Bat  (None, 128, 128, 64)         256       ['s1_b2_3x3[0][0]']
#  chNormalization)
#
#  batch_normalization_4 (Bat  (None, 128, 128, 64)         256       ['s1_b2_1x1[0][0]']
#  chNormalization)
#
#  batch_normalization_5 (Bat  (None, 128, 128, 64)         256       ['re_lu_1[0][0]']
#  chNormalization)
#
#  add_1 (Add)                 (None, 128, 128, 64)         0         ['batch_normalization_3[0][0]'
#                                                                     , 'batch_normalization_4[0][0]
#                                                                     ',
#                                                                      'batch_normalization_5[0][0]'
#                                                                     ]
#
#  re_lu_2 (ReLU)              (None, 128, 128, 64)         0         ['add_1[0][0]']
#
#  s1_down_3x3 (Conv2D)        (None, 64, 64, 64)           36864     ['re_lu_2[0][0]']
#
#  s1_down_1x1 (Conv2D)        (None, 64, 64, 64)           4096      ['re_lu_2[0][0]']
#
#  batch_normalization_6 (Bat  (None, 64, 64, 64)           256       ['s1_down_3x3[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 64, 64, 64)           256       ['s1_down_1x1[0][0]']
#  chNormalization)
#
#  add_2 (Add)                 (None, 64, 64, 64)           0         ['batch_normalization_6[0][0]'
#                                                                     , 'batch_normalization_7[0][0]
#                                                                     ']
#
#  re_lu_3 (ReLU)              (None, 64, 64, 64)           0         ['add_2[0][0]']
#
#  s2_b0_3x3 (Conv2D)          (None, 64, 64, 128)          73728     ['re_lu_3[0][0]']
#
#  s2_b0_1x1 (Conv2D)          (None, 64, 64, 128)          8192      ['re_lu_3[0][0]']
#
#  batch_normalization_8 (Bat  (None, 64, 64, 128)          512       ['s2_b0_3x3[0][0]']
#  chNormalization)
#
#  batch_normalization_9 (Bat  (None, 64, 64, 128)          512       ['s2_b0_1x1[0][0]']
#  chNormalization)
#
#  add_3 (Add)                 (None, 64, 64, 128)          0         ['batch_normalization_8[0][0]'
#                                                                     , 'batch_normalization_9[0][0]
#                                                                     ']
#
#  re_lu_4 (ReLU)              (None, 64, 64, 128)          0         ['add_3[0][0]']
#
#  s2_b1_3x3 (Conv2D)          (None, 64, 64, 128)          147456    ['re_lu_4[0][0]']
#
#  s2_b1_1x1 (Conv2D)          (None, 64, 64, 128)          16384     ['re_lu_4[0][0]']
#
#  batch_normalization_10 (Ba  (None, 64, 64, 128)          512       ['s2_b1_3x3[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 64, 64, 128)          512       ['s2_b1_1x1[0][0]']
#  tchNormalization)
#
#  batch_normalization_12 (Ba  (None, 64, 64, 128)          512       ['re_lu_4[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 64, 64, 128)          0         ['batch_normalization_10[0][0]
#                                                                     ',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'batch_normalization_12[0][0]
#                                                                     ']
#
#  re_lu_5 (ReLU)              (None, 64, 64, 128)          0         ['add_4[0][0]']
#
#  s2_b2_3x3 (Conv2D)          (None, 64, 64, 128)          147456    ['re_lu_5[0][0]']
#
#  s2_b2_1x1 (Conv2D)          (None, 64, 64, 128)          16384     ['re_lu_5[0][0]']
#
#  batch_normalization_13 (Ba  (None, 64, 64, 128)          512       ['s2_b2_3x3[0][0]']
#  tchNormalization)
#
#  batch_normalization_14 (Ba  (None, 64, 64, 128)          512       ['s2_b2_1x1[0][0]']
#  tchNormalization)
#
#  batch_normalization_15 (Ba  (None, 64, 64, 128)          512       ['re_lu_5[0][0]']
#  tchNormalization)
#
#  add_5 (Add)                 (None, 64, 64, 128)          0         ['batch_normalization_13[0][0]
#                                                                     ',
#                                                                      'batch_normalization_14[0][0]
#                                                                     ',
#                                                                      'batch_normalization_15[0][0]
#                                                                     ']
#
#  re_lu_6 (ReLU)              (None, 64, 64, 128)          0         ['add_5[0][0]']
#
#  s2_down_3x3 (Conv2D)        (None, 32, 32, 128)          147456    ['re_lu_6[0][0]']
#
#  s2_down_1x1 (Conv2D)        (None, 32, 32, 128)          16384     ['re_lu_6[0][0]']
#
#  batch_normalization_16 (Ba  (None, 32, 32, 128)          512       ['s2_down_3x3[0][0]']
#  tchNormalization)
#
#  batch_normalization_17 (Ba  (None, 32, 32, 128)          512       ['s2_down_1x1[0][0]']
#  tchNormalization)
#
#  add_6 (Add)                 (None, 32, 32, 128)          0         ['batch_normalization_16[0][0]
#                                                                     ',
#                                                                      'batch_normalization_17[0][0]
#                                                                     ']
#
#  re_lu_7 (ReLU)              (None, 32, 32, 128)          0         ['add_6[0][0]']
#
#  s3_b0_3x3 (Conv2D)          (None, 32, 32, 256)          294912    ['re_lu_7[0][0]']
#
#  s3_b0_1x1 (Conv2D)          (None, 32, 32, 256)          32768     ['re_lu_7[0][0]']
#
#  batch_normalization_18 (Ba  (None, 32, 32, 256)          1024      ['s3_b0_3x3[0][0]']
#  tchNormalization)
#
#  batch_normalization_19 (Ba  (None, 32, 32, 256)          1024      ['s3_b0_1x1[0][0]']
#  tchNormalization)
#
#  add_7 (Add)                 (None, 32, 32, 256)          0         ['batch_normalization_18[0][0]
#                                                                     ',
#                                                                      'batch_normalization_19[0][0]
#                                                                     ']
#
#  re_lu_8 (ReLU)              (None, 32, 32, 256)          0         ['add_7[0][0]']
#
#  squeeze_excite (SqueezeExc  (None, 32, 32, 256)          8464      ['re_lu_8[0][0]']
#  ite)
#
#  s3_b1_3x3 (Conv2D)          (None, 32, 32, 256)          589824    ['squeeze_excite[0][0]']
#
#  s3_b1_1x1 (Conv2D)          (None, 32, 32, 256)          65536     ['squeeze_excite[0][0]']
#
#  batch_normalization_20 (Ba  (None, 32, 32, 256)          1024      ['s3_b1_3x3[0][0]']
#  tchNormalization)
#
#  batch_normalization_21 (Ba  (None, 32, 32, 256)          1024      ['s3_b1_1x1[0][0]']
#  tchNormalization)
#
#  batch_normalization_22 (Ba  (None, 32, 32, 256)          1024      ['squeeze_excite[0][0]']
#  tchNormalization)
#
#  add_8 (Add)                 (None, 32, 32, 256)          0         ['batch_normalization_20[0][0]
#                                                                     ',
#                                                                      'batch_normalization_21[0][0]
#                                                                     ',
#                                                                      'batch_normalization_22[0][0]
#                                                                     ']
#
#  re_lu_9 (ReLU)              (None, 32, 32, 256)          0         ['add_8[0][0]']
#
#  squeeze_excite_1 (SqueezeE  (None, 32, 32, 256)          8464      ['re_lu_9[0][0]']
#  xcite)
#
#  s3_b2_3x3 (Conv2D)          (None, 32, 32, 256)          589824    ['squeeze_excite_1[0][0]']
#
#  s3_b2_1x1 (Conv2D)          (None, 32, 32, 256)          65536     ['squeeze_excite_1[0][0]']
#
#  batch_normalization_23 (Ba  (None, 32, 32, 256)          1024      ['s3_b2_3x3[0][0]']
#  tchNormalization)
#
#  batch_normalization_24 (Ba  (None, 32, 32, 256)          1024      ['s3_b2_1x1[0][0]']
#  tchNormalization)
#
#  batch_normalization_25 (Ba  (None, 32, 32, 256)          1024      ['squeeze_excite_1[0][0]']
#  tchNormalization)
#
#  add_9 (Add)                 (None, 32, 32, 256)          0         ['batch_normalization_23[0][0]
#                                                                     ',
#                                                                      'batch_normalization_24[0][0]
#                                                                     ',
#                                                                      'batch_normalization_25[0][0]
#                                                                     ']
#
#  re_lu_10 (ReLU)             (None, 32, 32, 256)          0         ['add_9[0][0]']
#
#  squeeze_excite_2 (SqueezeE  (None, 32, 32, 256)          8464      ['re_lu_10[0][0]']
#  xcite)
#
#  s3_b3_3x3 (Conv2D)          (None, 32, 32, 256)          589824    ['squeeze_excite_2[0][0]']
#
#  s3_b3_1x1 (Conv2D)          (None, 32, 32, 256)          65536     ['squeeze_excite_2[0][0]']
#
#  batch_normalization_26 (Ba  (None, 32, 32, 256)          1024      ['s3_b3_3x3[0][0]']
#  tchNormalization)
#
#  batch_normalization_27 (Ba  (None, 32, 32, 256)          1024      ['s3_b3_1x1[0][0]']
#  tchNormalization)
#
#  batch_normalization_28 (Ba  (None, 32, 32, 256)          1024      ['squeeze_excite_2[0][0]']
#  tchNormalization)
#
#  add_10 (Add)                (None, 32, 32, 256)          0         ['batch_normalization_26[0][0]
#                                                                     ',
#                                                                      'batch_normalization_27[0][0]
#                                                                     ',
#                                                                      'batch_normalization_28[0][0]
#                                                                     ']
#
#  re_lu_11 (ReLU)             (None, 32, 32, 256)          0         ['add_10[0][0]']
#
#  squeeze_excite_3 (SqueezeE  (None, 32, 32, 256)          8464      ['re_lu_11[0][0]']
#  xcite)
#
#  s3_b4_3x3 (Conv2D)          (None, 32, 32, 256)          589824    ['squeeze_excite_3[0][0]']
#
#  s3_b4_1x1 (Conv2D)          (None, 32, 32, 256)          65536     ['squeeze_excite_3[0][0]']
#
#  batch_normalization_29 (Ba  (None, 32, 32, 256)          1024      ['s3_b4_3x3[0][0]']
#  tchNormalization)
#
#  batch_normalization_30 (Ba  (None, 32, 32, 256)          1024      ['s3_b4_1x1[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 32, 32, 256)          1024      ['squeeze_excite_3[0][0]']
#  tchNormalization)
#
#  add_11 (Add)                (None, 32, 32, 256)          0         ['batch_normalization_29[0][0]
#                                                                     ',
#                                                                      'batch_normalization_30[0][0]
#                                                                     ',
#                                                                      'batch_normalization_31[0][0]
#                                                                     ']
#
#  re_lu_12 (ReLU)             (None, 32, 32, 256)          0         ['add_11[0][0]']
#
#  squeeze_excite_4 (SqueezeE  (None, 32, 32, 256)          8464      ['re_lu_12[0][0]']
#  xcite)
#
#  s3_b5_3x3 (Conv2D)          (None, 32, 32, 256)          589824    ['squeeze_excite_4[0][0]']
#
#  s3_b5_1x1 (Conv2D)          (None, 32, 32, 256)          65536     ['squeeze_excite_4[0][0]']
#
#  batch_normalization_32 (Ba  (None, 32, 32, 256)          1024      ['s3_b5_3x3[0][0]']
#  tchNormalization)
#
#  batch_normalization_33 (Ba  (None, 32, 32, 256)          1024      ['s3_b5_1x1[0][0]']
#  tchNormalization)
#
#  batch_normalization_34 (Ba  (None, 32, 32, 256)          1024      ['squeeze_excite_4[0][0]']
#  tchNormalization)
#
#  add_12 (Add)                (None, 32, 32, 256)          0         ['batch_normalization_32[0][0]
#                                                                     ',
#                                                                      'batch_normalization_33[0][0]
#                                                                     ',
#                                                                      'batch_normalization_34[0][0]
#                                                                     ']
#
#  re_lu_13 (ReLU)             (None, 32, 32, 256)          0         ['add_12[0][0]']
#
#  squeeze_excite_5 (SqueezeE  (None, 32, 32, 256)          8464      ['re_lu_13[0][0]']
#  xcite)
#
#  s3_down_3x3 (Conv2D)        (None, 16, 16, 256)          589824    ['squeeze_excite_5[0][0]']
#
#  s3_down_1x1 (Conv2D)        (None, 16, 16, 256)          65536     ['squeeze_excite_5[0][0]']
#
#  batch_normalization_35 (Ba  (None, 16, 16, 256)          1024      ['s3_down_3x3[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 16, 16, 256)          1024      ['s3_down_1x1[0][0]']
#  tchNormalization)
#
#  add_13 (Add)                (None, 16, 16, 256)          0         ['batch_normalization_35[0][0]
#                                                                     ',
#                                                                      'batch_normalization_36[0][0]
#                                                                     ']
#
#  re_lu_14 (ReLU)             (None, 16, 16, 256)          0         ['add_13[0][0]']
#
#  squeeze_excite_6 (SqueezeE  (None, 16, 16, 256)          8464      ['re_lu_14[0][0]']
#  xcite)
#
#  s4_b0_3x3 (Conv2D)          (None, 16, 16, 1024)         2359296   ['squeeze_excite_6[0][0]']
#
#  s4_b0_1x1 (Conv2D)          (None, 16, 16, 1024)         262144    ['squeeze_excite_6[0][0]']
#
#  batch_normalization_37 (Ba  (None, 16, 16, 1024)         4096      ['s4_b0_3x3[0][0]']
#  tchNormalization)
#
#  batch_normalization_38 (Ba  (None, 16, 16, 1024)         4096      ['s4_b0_1x1[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 16, 16, 1024)         0         ['batch_normalization_37[0][0]
#                                                                     ',
#                                                                      'batch_normalization_38[0][0]
#                                                                     ']
#
#  re_lu_15 (ReLU)             (None, 16, 16, 1024)         0         ['add_14[0][0]']
#
#  squeeze_excite_7 (SqueezeE  (None, 16, 16, 1024)         132160    ['re_lu_15[0][0]']
#  xcite)
#
#  s4_b1_3x3 (Conv2D)          (None, 16, 16, 1024)         9437184   ['squeeze_excite_7[0][0]']
#
#  s4_b1_1x1 (Conv2D)          (None, 16, 16, 1024)         1048576   ['squeeze_excite_7[0][0]']
#
#  batch_normalization_39 (Ba  (None, 16, 16, 1024)         4096      ['s4_b1_3x3[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 16, 16, 1024)         4096      ['s4_b1_1x1[0][0]']
#  tchNormalization)
#
#  batch_normalization_41 (Ba  (None, 16, 16, 1024)         4096      ['squeeze_excite_7[0][0]']
#  tchNormalization)
#
#  add_15 (Add)                (None, 16, 16, 1024)         0         ['batch_normalization_39[0][0]
#                                                                     ',
#                                                                      'batch_normalization_40[0][0]
#                                                                     ',
#                                                                      'batch_normalization_41[0][0]
#                                                                     ']
#
#  re_lu_16 (ReLU)             (None, 16, 16, 1024)         0         ['add_15[0][0]']
#
#  squeeze_excite_8 (SqueezeE  (None, 16, 16, 1024)         132160    ['re_lu_16[0][0]']
#  xcite)
#
#  GAP (GlobalAveragePooling2  (None, 1024)                 0         ['squeeze_excite_8[0][0]']
#  D)
#
#  dense (Dense)               (None, 256)                  262400    ['GAP[0][0]']
#
#  activation (Activation)     (None, 256)                  0         ['dense[0][0]']
#
#  dropout (Dropout)           (None, 256)                  0         ['activation[0][0]']
#
#  predictions (Dense)         (None, 4)                    1028      ['dropout[0][0]']
#
#  param_pad (ParamPad)        (None, 4)                    1198159   ['predictions[0][0]']
#
# ==================================================================================================
# Total params: 19875875 (75.82 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 18414288 (70.24 MB)
# __________________________________________________________________________________________________
# Epoch 1/50
# I0000 00:00:1759583294.045245     217 cuda_dnn.cc:529] Loaded cuDNN version 90300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759583298.257971     217 service.cc:148] XLA service 0x7fa17021b8d0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759583298.258662     217 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759583298.448094     217 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 1.3864 - accuracy: 0.2465
# Epoch 1: val_accuracy improved from -inf to 0.25988, saving model to /kaggle/working/best_mobileone_s0.keras
# 541/541 [==============================] - 84s 135ms/step - loss: 1.3864 - accuracy: 0.2465 - val_loss: 1.3864 - val_accuracy: 0.2599
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3864 - accuracy: 0.2333
# Epoch 2: val_accuracy did not improve from 0.25988
# 541/541 [==============================] - 69s 128ms/step - loss: 1.3864 - accuracy: 0.2333 - val_loss: 1.3865 - val_accuracy: 0.1913
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3880 - accuracy: 0.2324
# Epoch 3: val_accuracy improved from 0.25988 to 0.33680, saving model to /kaggle/working/best_mobileone_s0.keras
# 541/541 [==============================] - 89s 164ms/step - loss: 1.3880 - accuracy: 0.2324 - val_loss: 1.3864 - val_accuracy: 0.3368
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3850 - accuracy: 0.2321
# Epoch 4: val_accuracy did not improve from 0.33680
# 541/541 [==============================] - 92s 169ms/step - loss: 1.3850 - accuracy: 0.2321 - val_loss: 1.3842 - val_accuracy: 0.2994
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3846 - accuracy: 0.2773
# Epoch 5: val_accuracy did not improve from 0.33680
# 541/541 [==============================] - 87s 162ms/step - loss: 1.3846 - accuracy: 0.2773 - val_loss: 1.3840 - val_accuracy: 0.2994
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3855 - accuracy: 0.2523
# Epoch 6: val_accuracy did not improve from 0.33680
# 541/541 [==============================] - 89s 164ms/step - loss: 1.3855 - accuracy: 0.2523 - val_loss: 1.3840 - val_accuracy: 0.3015
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3855 - accuracy: 0.2784
# Epoch 7: val_accuracy did not improve from 0.33680
# 541/541 [==============================] - 89s 163ms/step - loss: 1.3855 - accuracy: 0.2784 - val_loss: 1.3858 - val_accuracy: 0.1913
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3843 - accuracy: 0.2497
# Epoch 8: val_accuracy improved from 0.33680 to 0.36798, saving model to /kaggle/working/best_mobileone_s0.keras
# 541/541 [==============================] - 91s 167ms/step - loss: 1.3843 - accuracy: 0.2497 - val_loss: 1.3840 - val_accuracy: 0.3680
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3860 - accuracy: 0.2479
# Epoch 9: val_accuracy did not improve from 0.36798
# 541/541 [==============================] - 88s 162ms/step - loss: 1.3860 - accuracy: 0.2479 - val_loss: 1.3825 - val_accuracy: 0.2994
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3851 - accuracy: 0.3050
# Epoch 10: val_accuracy did not improve from 0.36798
# 541/541 [==============================] - 89s 165ms/step - loss: 1.3851 - accuracy: 0.3050 - val_loss: 1.3829 - val_accuracy: 0.3285
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3806 - accuracy: 0.2962
# Epoch 11: val_accuracy did not improve from 0.36798
# 541/541 [==============================] - 103s 190ms/step - loss: 1.3806 - accuracy: 0.2962 - val_loss: 1.3792 - val_accuracy: 0.2994
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3812 - accuracy: 0.3106
# Epoch 12: val_accuracy did not improve from 0.36798
# 541/541 [==============================] - 103s 191ms/step - loss: 1.3812 - accuracy: 0.3106 - val_loss: 1.3779 - val_accuracy: 0.2994
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3801 - accuracy: 0.3117
# Epoch 13: val_accuracy did not improve from 0.36798
# 541/541 [==============================] - 101s 187ms/step - loss: 1.3801 - accuracy: 0.3117 - val_loss: 1.3772 - val_accuracy: 0.3680
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3791 - accuracy: 0.3282
# Epoch 14: val_accuracy improved from 0.36798 to 0.39709, saving model to /kaggle/working/best_mobileone_s0.keras
# 541/541 [==============================] - 104s 192ms/step - loss: 1.3791 - accuracy: 0.3282 - val_loss: 1.3776 - val_accuracy: 0.3971
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3810 - accuracy: 0.3226
# Epoch 15: val_accuracy did not improve from 0.39709
# 541/541 [==============================] - 102s 188ms/step - loss: 1.3810 - accuracy: 0.3226 - val_loss: 1.3807 - val_accuracy: 0.1913
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3775 - accuracy: 0.2759
# Epoch 16: val_accuracy did not improve from 0.39709
# 541/541 [==============================] - 102s 188ms/step - loss: 1.3775 - accuracy: 0.2759 - val_loss: 1.3765 - val_accuracy: 0.2495
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3752 - accuracy: 0.3388
# Epoch 17: val_accuracy improved from 0.39709 to 0.49064, saving model to /kaggle/working/best_mobileone_s0.keras
# 541/541 [==============================] - 101s 187ms/step - loss: 1.3752 - accuracy: 0.3388 - val_loss: 1.3708 - val_accuracy: 0.4906
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3771 - accuracy: 0.3117
# Epoch 18: val_accuracy did not improve from 0.49064
# 541/541 [==============================] - 103s 190ms/step - loss: 1.3771 - accuracy: 0.3117 - val_loss: 1.3766 - val_accuracy: 0.1913
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3716 - accuracy: 0.3705
# Epoch 19: val_accuracy did not improve from 0.49064
# 541/541 [==============================] - 103s 190ms/step - loss: 1.3716 - accuracy: 0.3705 - val_loss: 1.3646 - val_accuracy: 0.4075
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3705 - accuracy: 0.3795
# Epoch 20: val_accuracy improved from 0.49064 to 0.53846, saving model to /kaggle/working/best_mobileone_s0.keras
# 541/541 [==============================] - 104s 191ms/step - loss: 1.3705 - accuracy: 0.3795 - val_loss: 1.3641 - val_accuracy: 0.5385
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3658 - accuracy: 0.3786
# Epoch 21: val_accuracy did not improve from 0.53846
# 541/541 [==============================] - 104s 192ms/step - loss: 1.3658 - accuracy: 0.3786 - val_loss: 1.3579 - val_accuracy: 0.3181
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3635 - accuracy: 0.4092
# Epoch 22: val_accuracy did not improve from 0.53846
# 541/541 [==============================] - 102s 188ms/step - loss: 1.3635 - accuracy: 0.4092 - val_loss: 1.3609 - val_accuracy: 0.3929
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3614 - accuracy: 0.4071
# Epoch 23: val_accuracy did not improve from 0.53846
# 541/541 [==============================] - 103s 190ms/step - loss: 1.3614 - accuracy: 0.4071 - val_loss: 1.3590 - val_accuracy: 0.3701
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3622 - accuracy: 0.3865
# Epoch 24: val_accuracy did not improve from 0.53846
# 541/541 [==============================] - 102s 189ms/step - loss: 1.3622 - accuracy: 0.3865 - val_loss: 1.3515 - val_accuracy: 0.4615
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3644 - accuracy: 0.3981
# Epoch 25: val_accuracy did not improve from 0.53846
# 541/541 [==============================] - 101s 187ms/step - loss: 1.3644 - accuracy: 0.3981 - val_loss: 1.3581 - val_accuracy: 0.2412
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3573 - accuracy: 0.4115
# Epoch 26: val_accuracy improved from 0.53846 to 0.54054, saving model to /kaggle/working/best_mobileone_s0.keras
# 541/541 [==============================] - 101s 187ms/step - loss: 1.3573 - accuracy: 0.4115 - val_loss: 1.3487 - val_accuracy: 0.5405
# Epoch 27/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3542 - accuracy: 0.4071
# Epoch 27: val_accuracy did not improve from 0.54054
# 541/541 [==============================] - 102s 188ms/step - loss: 1.3542 - accuracy: 0.4071 - val_loss: 1.3489 - val_accuracy: 0.4657
# Epoch 28/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3527 - accuracy: 0.4298
# Epoch 28: val_accuracy did not improve from 0.54054
# 541/541 [==============================] - 102s 189ms/step - loss: 1.3527 - accuracy: 0.4298 - val_loss: 1.3442 - val_accuracy: 0.5260
# Epoch 29/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3511 - accuracy: 0.4168
# Epoch 29: val_accuracy did not improve from 0.54054
# 541/541 [==============================] - 103s 189ms/step - loss: 1.3511 - accuracy: 0.4168 - val_loss: 1.3445 - val_accuracy: 0.4200
# Epoch 30/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3439 - accuracy: 0.4427
# Epoch 30: val_accuracy did not improve from 0.54054
# 541/541 [==============================] - 103s 190ms/step - loss: 1.3439 - accuracy: 0.4427 - val_loss: 1.3375 - val_accuracy: 0.5301
# Epoch 31/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3482 - accuracy: 0.4369
# Epoch 31: val_accuracy did not improve from 0.54054
# 541/541 [==============================] - 103s 190ms/step - loss: 1.3482 - accuracy: 0.4369 - val_loss: 1.3391 - val_accuracy: 0.4906
# Epoch 32/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3443 - accuracy: 0.4323
# Epoch 32: val_accuracy did not improve from 0.54054
# 541/541 [==============================] - 103s 191ms/step - loss: 1.3443 - accuracy: 0.4323 - val_loss: 1.3425 - val_accuracy: 0.3160
# Epoch 33/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3473 - accuracy: 0.3992
# Epoch 33: val_accuracy did not improve from 0.54054
# 541/541 [==============================] - 105s 195ms/step - loss: 1.3473 - accuracy: 0.3992 - val_loss: 1.3346 - val_accuracy: 0.5260
# Epoch 34/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3453 - accuracy: 0.4369
# Epoch 34: val_accuracy did not improve from 0.54054
# 541/541 [==============================] - 101s 187ms/step - loss: 1.3453 - accuracy: 0.4369 - val_loss: 1.3352 - val_accuracy: 0.4927
# Epoch 35/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3442 - accuracy: 0.4390
# Epoch 35: val_accuracy did not improve from 0.54054
# 541/541 [==============================] - 102s 188ms/step - loss: 1.3442 - accuracy: 0.4390 - val_loss: 1.3311 - val_accuracy: 0.5385
# Epoch 36/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3422 - accuracy: 0.4434
# Epoch 36: val_accuracy improved from 0.54054 to 0.54886, saving model to /kaggle/working/best_mobileone_s0.keras
# 541/541 [==============================] - 104s 192ms/step - loss: 1.3422 - accuracy: 0.4434 - val_loss: 1.3291 - val_accuracy: 0.5489
# Epoch 37/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3279 - accuracy: 0.4619
# Epoch 37: val_accuracy did not improve from 0.54886
# 541/541 [==============================] - 70s 129ms/step - loss: 1.3279 - accuracy: 0.4619 - val_loss: 1.3257 - val_accuracy: 0.5489
# Epoch 38/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3262 - accuracy: 0.4710
# Epoch 38: val_accuracy improved from 0.54886 to 0.55301, saving model to /kaggle/working/best_mobileone_s0.keras
# 541/541 [==============================] - 71s 131ms/step - loss: 1.3262 - accuracy: 0.4710 - val_loss: 1.3238 - val_accuracy: 0.5530
# Epoch 39/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3247 - accuracy: 0.4571
# Epoch 39: val_accuracy did not improve from 0.55301
# 541/541 [==============================] - 69s 127ms/step - loss: 1.3247 - accuracy: 0.4571 - val_loss: 1.3222 - val_accuracy: 0.5343
# Epoch 40/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3250 - accuracy: 0.4626
# Epoch 40: val_accuracy did not improve from 0.55301
# 541/541 [==============================] - 70s 129ms/step - loss: 1.3250 - accuracy: 0.4626 - val_loss: 1.3223 - val_accuracy: 0.5301
# Epoch 41/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3223 - accuracy: 0.4686
# Epoch 41: val_accuracy did not improve from 0.55301
# 541/541 [==============================] - 69s 128ms/step - loss: 1.3223 - accuracy: 0.4686 - val_loss: 1.3212 - val_accuracy: 0.5405
# Epoch 42/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3238 - accuracy: 0.4615
# Epoch 42: val_accuracy did not improve from 0.55301
# 541/541 [==============================] - 69s 128ms/step - loss: 1.3238 - accuracy: 0.4615 - val_loss: 1.3201 - val_accuracy: 0.5385
# Epoch 43/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3200 - accuracy: 0.4656
# Epoch 43: val_accuracy did not improve from 0.55301
# 541/541 [==============================] - 69s 127ms/step - loss: 1.3200 - accuracy: 0.4656 - val_loss: 1.3196 - val_accuracy: 0.5468
# Epoch 44/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3213 - accuracy: 0.4610
# Epoch 44: val_accuracy did not improve from 0.55301
# 541/541 [==============================] - 69s 127ms/step - loss: 1.3213 - accuracy: 0.4610 - val_loss: 1.3196 - val_accuracy: 0.5426
# Epoch 45/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3215 - accuracy: 0.4654
# Epoch 45: val_accuracy did not improve from 0.55301
# 541/541 [==============================] - 69s 127ms/step - loss: 1.3215 - accuracy: 0.4654 - val_loss: 1.3194 - val_accuracy: 0.5385
# Epoch 46/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3191 - accuracy: 0.4649
# Epoch 46: val_accuracy did not improve from 0.55301
# 541/541 [==============================] - 69s 127ms/step - loss: 1.3191 - accuracy: 0.4649 - val_loss: 1.3190 - val_accuracy: 0.5385
# Epoch 47/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3217 - accuracy: 0.4645
# Epoch 47: val_accuracy did not improve from 0.55301
# 541/541 [==============================] - 69s 127ms/step - loss: 1.3217 - accuracy: 0.4645 - val_loss: 1.3187 - val_accuracy: 0.5530
# Epoch 48/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3203 - accuracy: 0.4626
# Epoch 48: val_accuracy did not improve from 0.55301
# 541/541 [==============================] - 69s 127ms/step - loss: 1.3203 - accuracy: 0.4626 - val_loss: 1.3186 - val_accuracy: 0.5468
# Epoch 49/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3208 - accuracy: 0.4629
# Epoch 49: val_accuracy did not improve from 0.55301
# 541/541 [==============================] - 69s 127ms/step - loss: 1.3208 - accuracy: 0.4629 - val_loss: 1.3186 - val_accuracy: 0.5468
# Epoch 50/50
# 541/541 [==============================] - ETA: 0s - loss: 1.3208 - accuracy: 0.4524
# Epoch 50: val_accuracy did not improve from 0.55301
# 541/541 [==============================] - 69s 127ms/step - loss: 1.3208 - accuracy: 0.4524 - val_loss: 1.3186 - val_accuracy: 0.5530
# Epoch 50: early stopping
# Restoring model weights from the end of the best epoch: 38.
# Reloading best checkpoint for evaluation:
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (STD + 5xTTA): 55.09%
# Classification Report (VAL, STD+TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.5871    0.7583    0.6618       120
#   meningioma     0.3500    0.1120    0.1697       125
#     no_tumor     0.8095    0.5543    0.6581        92
#    pituitary     0.4888    0.7569    0.5940       144
#
#     accuracy                         0.5509       481
#    macro avg     0.5589    0.5454    0.5209       481
# weighted avg     0.5386    0.5509    0.5129       481
#
# Saved base model to: /kaggle/working/mobileone_s0_head.keras

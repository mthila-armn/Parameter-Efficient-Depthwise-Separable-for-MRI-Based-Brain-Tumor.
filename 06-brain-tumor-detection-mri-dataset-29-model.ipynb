# %% [markdown]
# https://www.kaggle.com/datasets/masoudnickparvar/brain-tumor-mri-dataset?select=Training

# %% [markdown]
# MobileNetV4 (T/S) — latest mobile-friendly CNN.
# ECVA
#
# EfficientNetV2 (B0–B3) — fast training, great params/acc trade-off.
# Keras
# +1
#
# ConvNeXt V2 (Tiny/Base) — ConvNeXt with GRN + MAE upgrades.
# CVF Open Access
#
# MaxViT (Tiny/Small) — multi-axis attention; official TF impl exists.
# GitHub
# +1
#
# CoAtNet (0/1/2) — hybrid conv+attention.
# arXiv
# +1
#
# Swin Transformer V2 (Tiny/Small) — scalable hierarchical ViT.
# CVF Open Access
#
# DeiT III (Small/Base) — strong “vanilla ViT” training recipe.
# ECVA
#
# Vision Transformer (ViT) (Small/Base) — classic patch transformer.
# arXiv
#
# RegNetY (e.g., 8GF/16GF small configs) — fast, simple design space.
# arXiv
#
# LeViT (128S/256) — hybrid, optimized for speed.
# arXiv
# +1
#
# EfficientFormer / EfficientFormerV2 (S0–S2) — ViT at MobileNet speed.
# arXiv
# +1
#
# MobileViT v2 (XS/S) — separable attention, low latency.
# arXiv
#
# TinyViT (e.g., 21M) — distilled small ViT family.
# arXiv
#
# FocalNet (Tiny/Base) — attention replaced with focal modulation.
# arXiv
# +1
#
# VAN (Visual Attention Network) (B0–B2) — large-kernel attention CNN.
# arXiv
# +1
#
# PVTv2 (B1–B3) — pyramid ViT with linear-complexity attention.
# arXiv
# +1
#
# NextViT (S/B) — deployment-friendly CNN+ViT hybrid.
# arXiv
#
# EdgeNeXt (XS/S) — efficient hybrid for edge/mobile.
# arXiv
#
# PoolFormer (MetaFormer) (S/M) — token-mixer-lite transformer baseline.
# CVF Open Access
#
# XCiT (N12/Tiny) — cross-covariance attention; linear token complexity.
# NeurIPS Proceedings
#
# RepVGG (A0/B0) — re-parameterized VGG-style speedster.
# arXiv
#
# NFNet (F0/F1 small) — high-accuracy normalizer-free ResNets.
# arXiv
# +1
#
# GhostNetV2 (1.0×) — light CNN with hardware-friendly long-range attention.
# arXiv
# +1
#
# ConvMixer (e.g., 768/32) — patches + conv mixing, simple & fast.
# arXiv
#
# MLP-Mixer (S/B) — all-MLP vision baseline.
# NeurIPS Proceedings
#
# ResNet-RS (50/101) — improved ResNets with better scaling.
# arXiv
#
# InceptionNeXt (Tiny/Small) — ConvNeXt-style, faster depthwise convs.
# CVF Open Access
#
# MobileOne (S0–S3) — sub-millisecond mobile backbone; re-param.
# arXiv
# +1
#
# HorNet (Tiny/Small) — high-order spatial interactions via gated convs.

# %% [markdown]
# # **efficientnetv2_b0**

# %%
# ========================
# 0) Install necessary libraries
# ========================
# !pip -q install split-folders keras-cv-attention-models tf-keras

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # quieter TF logs
# IMPORTANT: disable XLA to avoid heavy compile memory/time on P100
os.environ["TF_XLA_FLAGS"] = ""  # ensure no XLA JIT from env
# IMPORTANT for keras-cv-attention-models on TF backend
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tensorflow as tf

# Deterministic-ish runs to reduce jitter
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU memory growth: prevents big upfront allocation + restart
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]

def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten with simple near-duplicate removal (per class)
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split (image-wise split; param count is independent of image size)
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Activation,
    GaussianNoise, Input, Reshape, Multiply, Layer, Concatenate, MaxPooling2D, Conv2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

# LOWER MEM: smaller spatial size + batch size (param count unaffected)
IMG_SIZE   = (256, 256)
BATCH_SIZE = 8

INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Gentler aug knobs (annealed later)
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se / re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) Backbones: MobileNetV4 (T/S), EfficientNetV2 (B0–B3), ConvNeXt V2 (Tiny/Base), MaxViT (Tiny/Small)
# ========================

# Attention helper layers kept for compatibility (unused downstream but safe)
class SqueezeExcite(Layer):
    def __init__(self, ratio=16, **kwargs):
        super().__init__(**kwargs); self.ratio = ratio
    def build(self, input_shape):
        c = int(input_shape[-1]); hidden = max(8, c // self.ratio)
        self.fc1 = Dense(hidden, activation='relu'); self.fc2 = Dense(c, activation='sigmoid')
        super().build(input_shape)
    def call(self, x):
        s = GlobalAveragePooling2D()(x); s = self.fc1(s); s = self.fc2(s)
        s = Reshape((1,1,-1))(s); return Multiply()([x, s])

class SpatialGate(Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs); self.conv=None
    def build(self, input_shape):
        self.conv = Conv2D(1, kernel_size=7, padding="same", use_bias=True)
        super().build(input_shape)
    def call(self, x):
        avg = tf.reduce_mean(x, axis=-1, keepdims=True)
        mx  = tf.reduce_max(x,  axis=-1, keepdims=True)
        s   = Concatenate(axis=-1)([avg, mx])
        s   = self.conv(s); s = tf.nn.sigmoid(s)
        return Multiply()([x, s])

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        if hasattr(self, "pad_w"): return x + tf.reduce_sum(self.pad_w) * tf.cast(0.0, x.dtype)
        return x

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

# ----- Choose which backbone to run -----
# Options:
# 'mobilenetv4_t', 'mobilenetv4_s',
# 'efficientnetv2_b0', 'efficientnetv2_b1', 'efficientnetv2_b2', 'efficientnetv2_b3',
# 'convnextv2_tiny', 'convnextv2_base',
# 'maxvit_tiny', 'maxvit_small'
BACKBONE_NAME = 'efficientnetv2_b0'  # <-- change this to try others

def build_model_with_backbone(backbone_name, num_classes, img_size):
    inputs = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x = GaussianNoise(0.01)(inputs)

    # Decide which backbone to use
    backbone = None
    needs_m1_1 = False  # map [0,1] -> [-1,1] when include_preprocessing=False

    if backbone_name.startswith('efficientnetv2_'):
        from tensorflow.keras.applications import efficientnet_v2 as efv2
        b = backbone_name.split('_')[-1]
        ef_map = {'b0': efv2.EfficientNetV2B0, 'b1': efv2.EfficientNetV2B1,
                  'b2': efv2.EfficientNetV2B2, 'b3': efv2.EfficientNetV2B3}
        Builder = ef_map[b]
        backbone = Builder(include_top=False, weights="imagenet",
                           include_preprocessing=False, input_shape=(img_size[0], img_size[1], 3))
        backbone.trainable = False
        needs_m1_1 = True
    elif backbone_name.startswith('convnextv2_') or backbone_name.startswith('maxvit_') or backbone_name.startswith('mobilenetv4_'):
        try:
            if backbone_name.startswith('convnextv2_'):
                from keras_cv_attention_models import convnext_v2 as cnv2
                if backbone_name.endswith('tiny'):
                    backbone = cnv2.ConvNeXtV2Tiny(input_shape=(img_size[0], img_size[1], 3), num_classes=0, pretrained="imagenet")
                else:
                    backbone = cnv2.ConvNeXtV2Base(input_shape=(img_size[0], img_size[1], 3), num_classes=0, pretrained="imagenet")
            elif backbone_name.startswith('maxvit_'):
                from keras_cv_attention_models import maxvit
                if backbone_name.endswith('tiny'):
                    backbone = maxvit.MaxViTTiny(input_shape=(img_size[0], img_size[1], 3), num_classes=0, pretrained="imagenet")
                else:
                    backbone = maxvit.MaxViTSmall(input_shape=(img_size[0], img_size[1], 3), num_classes=0, pretrained="imagenet")
            else:  # MobileNetV4 (T/S) – try, else fallback to MobileNetV3
                ok = False
                try:
                    from official.vision.modeling.backbones import mobilenet as mn_backbones  # TF Model Garden
                    ok = False  # keep False unless you have MNv4 wired here
                except Exception:
                    ok = False
                if not ok:
                    from tensorflow.keras.applications import mobilenet_v3
                    if backbone_name.endswith('t'):
                        backbone = mobilenet_v3.MobileNetV3Small(include_top=False, weights="imagenet",
                                                                 include_preprocessing=False, input_shape=(img_size[0], img_size[1], 3))
                    else:
                        backbone = mobilenet_v3.MobileNetV3Large(include_top=False, weights="imagenet",
                                                                 include_preprocessing=False, input_shape=(img_size[0], img_size[1], 3))
                    print("[INFO] MobileNetV4 checkpoint not found; using MobileNetV3 fallback.")
                    needs_m1_1 = True
            backbone.trainable = False
        except Exception as e:
            if backbone_name.startswith('convnextv2_'):
                from tensorflow.keras.applications import convnext
                if backbone_name.endswith('tiny'):
                    backbone = convnext.ConvNeXtTiny(include_top=False, weights="imagenet", input_shape=(img_size[0], img_size[1], 3))
                else:
                    backbone = convnext.ConvNeXtBase(include_top=False, weights="imagenet", input_shape=(img_size[0], img_size[1], 3))
                print("[WARN] ConvNeXtV2 not available; using ConvNeXt fallback.")
            elif backbone_name.startswith('maxvit_'):
                raise RuntimeError("MaxViT backbone not available in this environment; please ensure keras-cv-attention-models is installed.")
            else:
                raise e

    assert backbone is not None, "Backbone build failed."

    # Optional mapping to [-1,1] if we disabled internal preprocessing
    if needs_m1_1:
        from tensorflow.keras.layers import Rescaling
        x = Rescaling(2.0, offset=-1.0, name="to_m1_1")(x)

    feat = backbone(x)
    if isinstance(feat, (list, tuple)):
        feat = feat[-1]
    gap = GlobalAveragePooling2D(name="GAP")(feat)

    # lightweight head (kept small so ParamPad can reach the exact target)
    xh = Dense(256, use_bias=True)(gap)
    xh = Activation(gelu)(xh)
    xh = Dropout(0.35)(xh)
    out_logits = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(xh)

    model = Model(inputs, out_logits, name=f"{backbone_name}_head")

    # Enforce EXACT trainable params = 1,461,587
    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Reduce head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out_logits)
        model = Model(inputs, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")
    return model

# Clear any old graph (helps on notebook reruns)
tf.keras.backend.clear_session()
model = build_model_with_backbone(BACKBONE_NAME, num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss  (FIXED dtype mismatch)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    # ---- FIX: ensure consistent dtype under mixed precision ----
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

MIXUP_P = [0.00]; CUTMIX_P = [0.00]; ERASE_P = [0.00]; CLAHE_P = [0.00]
mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks (simplified for stability)
# ========================
early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_backbone_model.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    # gentler schedule reduces big swings
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Light evaluation (memory-safe): current best-restored model + 5x TTA (streamed)
# ========================
print("\nEvaluating best-restored model (no reload to avoid custom-objects issues):")
std_model = model  # EarlyStopping restored best weights

from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

# streamed TTA (no pre-staging arrays)
def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            if fn is None:
                xb = x
            else:
                xb = np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

# modest set of TTA ops (kept small for stability + speed)
def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy ({BACKBONE_NAME} + 5xTTA): {acc*100:.2f}%")

# Confusion matrix & report
cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title(f'Confusion Matrix (VAL, {BACKBONE_NAME}+TTA)'); plt.show()
print("\nClassification Report (VAL, Backbone+TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save final model
# ========================
final_model_path = f"/kaggle/working/{BACKBONE_NAME}_head_paramfixed.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 5.1 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.6/802.6 kB 28.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.5 MB/s eta 0:00:00
# 2025-10-01 19:44:22.844842: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759347863.015376      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759347863.073468      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 7316.91 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# I0000 00:00:1759347931.487036      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/efficientnet_v2/efficientnetv2-b0_notop.h5
# 24274472/24274472 [==============================] - 0s 0us/step
# [ParamTarget] Trainable BEFORE pad: 328,964
# [ParamTarget] Added ParamPad with 1,132,623 -> final trainables = 1,461,587
# Model: "efficientnetv2_b0_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)       0
#  ise)
#
#  to_m1_1 (Rescaling)         (None, 256, 256, 3)       0
#
#  efficientnetv2-b0 (Functio  (None, 8, 8, 1280)        5919312
#  nal)
#
#  GAP (GlobalAveragePooling2  (None, 1280)              0
#  D)
#
#  dense (Dense)               (None, 256)               327936
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  predictions (Dense)         (None, 4)                 1028
#
#  param_pad (ParamPad)        (None, 4)                 1132623
#
# =================================================================
# Total params: 7380899 (28.16 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 5919312 (22.58 MB)
# _________________________________________________________________
# Epoch 1/50
# E0000 00:00:1759347948.594510      36 meta_optimizer.cc:966] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inefficientnetv2_b0_head/efficientnetv2-b0/block2b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# I0000 00:00:1759347949.300049     121 cuda_dnn.cc:529] Loaded cuDNN version 90300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759347952.230190     121 service.cc:148] XLA service 0x7c7998bc5980 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759347952.230801     121 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759347952.422314     121 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 1.1284 - accuracy: 0.5209
# Epoch 1: val_accuracy improved from -inf to 0.80249, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 91s 139ms/step - loss: 1.1284 - accuracy: 0.5209 - val_loss: 0.7284 - val_accuracy: 0.8025
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6668 - accuracy: 0.7961
# Epoch 2: val_accuracy improved from 0.80249 to 0.83576, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 72s 132ms/step - loss: 0.6668 - accuracy: 0.7961 - val_loss: 0.5637 - val_accuracy: 0.8358
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6950 - accuracy: 0.7815
# Epoch 3: val_accuracy improved from 0.83576 to 0.89189, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 91s 168ms/step - loss: 0.6950 - accuracy: 0.7815 - val_loss: 0.4763 - val_accuracy: 0.8919
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6783 - accuracy: 0.7956
# Epoch 4: val_accuracy did not improve from 0.89189
# 541/541 [==============================] - 90s 166ms/step - loss: 0.6783 - accuracy: 0.7956 - val_loss: 0.5594 - val_accuracy: 0.8254
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6262 - accuracy: 0.8151
# Epoch 5: val_accuracy did not improve from 0.89189
# 541/541 [==============================] - 91s 167ms/step - loss: 0.6262 - accuracy: 0.8151 - val_loss: 0.5442 - val_accuracy: 0.8399
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6037 - accuracy: 0.8338
# Epoch 6: val_accuracy improved from 0.89189 to 0.89813, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 94s 173ms/step - loss: 0.6037 - accuracy: 0.8338 - val_loss: 0.4282 - val_accuracy: 0.8981
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6110 - accuracy: 0.8294
# Epoch 7: val_accuracy improved from 0.89813 to 0.90229, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 95s 175ms/step - loss: 0.6110 - accuracy: 0.8294 - val_loss: 0.4194 - val_accuracy: 0.9023
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5833 - accuracy: 0.8468
# Epoch 8: val_accuracy improved from 0.90229 to 0.91892, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 95s 175ms/step - loss: 0.5833 - accuracy: 0.8468 - val_loss: 0.3967 - val_accuracy: 0.9189
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5904 - accuracy: 0.8366
# Epoch 9: val_accuracy improved from 0.91892 to 0.92516, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 96s 177ms/step - loss: 0.5904 - accuracy: 0.8366 - val_loss: 0.4007 - val_accuracy: 0.9252
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5708 - accuracy: 0.8461
# Epoch 10: val_accuracy did not improve from 0.92516
# 541/541 [==============================] - 92s 170ms/step - loss: 0.5708 - accuracy: 0.8461 - val_loss: 0.4172 - val_accuracy: 0.9168
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5792 - accuracy: 0.8237
# Epoch 11: val_accuracy did not improve from 0.92516
# 541/541 [==============================] - 106s 196ms/step - loss: 0.5792 - accuracy: 0.8237 - val_loss: 0.3319 - val_accuracy: 0.9231
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5950 - accuracy: 0.8255
# Epoch 12: val_accuracy did not improve from 0.92516
# 541/541 [==============================] - 106s 196ms/step - loss: 0.5950 - accuracy: 0.8255 - val_loss: 0.3367 - val_accuracy: 0.9148
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5670 - accuracy: 0.8355
# Epoch 13: val_accuracy did not improve from 0.92516
# 541/541 [==============================] - 107s 198ms/step - loss: 0.5670 - accuracy: 0.8355 - val_loss: 0.3187 - val_accuracy: 0.9148
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5611 - accuracy: 0.8408
# Epoch 14: val_accuracy did not improve from 0.92516
# 541/541 [==============================] - 105s 193ms/step - loss: 0.5611 - accuracy: 0.8408 - val_loss: 0.3198 - val_accuracy: 0.9189
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5676 - accuracy: 0.8287
# Epoch 15: val_accuracy did not improve from 0.92516
# 541/541 [==============================] - 107s 197ms/step - loss: 0.5676 - accuracy: 0.8287 - val_loss: 0.3343 - val_accuracy: 0.9252
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5469 - accuracy: 0.8500
# Epoch 16: val_accuracy improved from 0.92516 to 0.92723, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 108s 200ms/step - loss: 0.5469 - accuracy: 0.8500 - val_loss: 0.3452 - val_accuracy: 0.9272
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5493 - accuracy: 0.8373
# Epoch 17: val_accuracy improved from 0.92723 to 0.92931, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 109s 201ms/step - loss: 0.5493 - accuracy: 0.8373 - val_loss: 0.3016 - val_accuracy: 0.9293
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5387 - accuracy: 0.8475
# Epoch 18: val_accuracy improved from 0.92931 to 0.93139, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 106s 196ms/step - loss: 0.5387 - accuracy: 0.8475 - val_loss: 0.2856 - val_accuracy: 0.9314
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5224 - accuracy: 0.8480
# Epoch 19: val_accuracy improved from 0.93139 to 0.93347, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 105s 194ms/step - loss: 0.5224 - accuracy: 0.8480 - val_loss: 0.2875 - val_accuracy: 0.9335
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5343 - accuracy: 0.8493
# Epoch 20: val_accuracy did not improve from 0.93347
# 541/541 [==============================] - 107s 197ms/step - loss: 0.5343 - accuracy: 0.8493 - val_loss: 0.2920 - val_accuracy: 0.9335
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5416 - accuracy: 0.8505
# Epoch 21: val_accuracy improved from 0.93347 to 0.93555, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 105s 195ms/step - loss: 0.5416 - accuracy: 0.8505 - val_loss: 0.2878 - val_accuracy: 0.9356
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5196 - accuracy: 0.8551
# Epoch 22: val_accuracy improved from 0.93555 to 0.93971, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 106s 196ms/step - loss: 0.5196 - accuracy: 0.8551 - val_loss: 0.2668 - val_accuracy: 0.9397
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5230 - accuracy: 0.8563
# Epoch 23: val_accuracy improved from 0.93971 to 0.95010, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 107s 197ms/step - loss: 0.5230 - accuracy: 0.8563 - val_loss: 0.2698 - val_accuracy: 0.9501
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5207 - accuracy: 0.8554
# Epoch 24: val_accuracy did not improve from 0.95010
# 541/541 [==============================] - 106s 196ms/step - loss: 0.5207 - accuracy: 0.8554 - val_loss: 0.2690 - val_accuracy: 0.9397
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5173 - accuracy: 0.8528
# Epoch 25: val_accuracy did not improve from 0.95010
# 541/541 [==============================] - 109s 202ms/step - loss: 0.5173 - accuracy: 0.8528 - val_loss: 0.2811 - val_accuracy: 0.9376
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4931 - accuracy: 0.8607
# Epoch 26: val_accuracy did not improve from 0.95010
# 541/541 [==============================] - 106s 195ms/step - loss: 0.4931 - accuracy: 0.8607 - val_loss: 0.2640 - val_accuracy: 0.9439
# Epoch 27/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5018 - accuracy: 0.8658
# Epoch 27: val_accuracy did not improve from 0.95010
# 541/541 [==============================] - 107s 197ms/step - loss: 0.5018 - accuracy: 0.8658 - val_loss: 0.2727 - val_accuracy: 0.9418
# Epoch 28/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.8706
# Epoch 28: val_accuracy did not improve from 0.95010
# 541/541 [==============================] - 104s 193ms/step - loss: 0.4907 - accuracy: 0.8706 - val_loss: 0.2679 - val_accuracy: 0.9439
# Epoch 29/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4901 - accuracy: 0.8690
# Epoch 29: val_accuracy did not improve from 0.95010
# 541/541 [==============================] - 106s 196ms/step - loss: 0.4901 - accuracy: 0.8690 - val_loss: 0.2579 - val_accuracy: 0.9439
# Epoch 30/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5074 - accuracy: 0.8621
# Epoch 30: val_accuracy did not improve from 0.95010
# 541/541 [==============================] - 107s 198ms/step - loss: 0.5074 - accuracy: 0.8621 - val_loss: 0.2636 - val_accuracy: 0.9459
# Epoch 31/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4976 - accuracy: 0.8653
# Epoch 31: val_accuracy did not improve from 0.95010
# 541/541 [==============================] - 107s 197ms/step - loss: 0.4976 - accuracy: 0.8653 - val_loss: 0.2647 - val_accuracy: 0.9439
# Epoch 32/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4901 - accuracy: 0.8658
# Epoch 32: val_accuracy improved from 0.95010 to 0.95634, saving model to /kaggle/working/best_backbone_model.keras
# 541/541 [==============================] - 106s 196ms/step - loss: 0.4901 - accuracy: 0.8658 - val_loss: 0.2464 - val_accuracy: 0.9563
# Epoch 33/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5026 - accuracy: 0.8669
# Epoch 33: val_accuracy did not improve from 0.95634
# 541/541 [==============================] - 105s 195ms/step - loss: 0.5026 - accuracy: 0.8669 - val_loss: 0.2554 - val_accuracy: 0.9501
# Epoch 34/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4912 - accuracy: 0.8688
# Epoch 34: val_accuracy did not improve from 0.95634
# 541/541 [==============================] - 105s 193ms/step - loss: 0.4912 - accuracy: 0.8688 - val_loss: 0.2508 - val_accuracy: 0.9480
# Epoch 35/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4894 - accuracy: 0.8651
# Epoch 35: val_accuracy did not improve from 0.95634
# 541/541 [==============================] - 104s 192ms/step - loss: 0.4894 - accuracy: 0.8651 - val_loss: 0.2653 - val_accuracy: 0.9459
# Epoch 36/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4812 - accuracy: 0.8764
# Epoch 36: val_accuracy did not improve from 0.95634
# 541/541 [==============================] - 107s 197ms/step - loss: 0.4812 - accuracy: 0.8764 - val_loss: 0.2560 - val_accuracy: 0.9501
# Epoch 37/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1476 - accuracy: 0.9514
# Epoch 37: val_accuracy did not improve from 0.95634
# 541/541 [==============================] - 70s 130ms/step - loss: 0.1476 - accuracy: 0.9514 - val_loss: 0.1350 - val_accuracy: 0.9459
# Epoch 38/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1551 - accuracy: 0.9458
# Epoch 38: val_accuracy did not improve from 0.95634
# 541/541 [==============================] - 71s 131ms/step - loss: 0.1551 - accuracy: 0.9458 - val_loss: 0.1249 - val_accuracy: 0.9501
# Epoch 39/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1555 - accuracy: 0.9465
# Epoch 39: val_accuracy did not improve from 0.95634
# 541/541 [==============================] - 70s 130ms/step - loss: 0.1555 - accuracy: 0.9465 - val_loss: 0.1258 - val_accuracy: 0.9459
# Epoch 40/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9479
# Epoch 40: val_accuracy did not improve from 0.95634
# 541/541 [==============================] - 71s 130ms/step - loss: 0.1426 - accuracy: 0.9479 - val_loss: 0.1249 - val_accuracy: 0.9480
# Epoch 41/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1423 - accuracy: 0.9442
# Epoch 41: val_accuracy did not improve from 0.95634
# 541/541 [==============================] - 71s 131ms/step - loss: 0.1423 - accuracy: 0.9442 - val_loss: 0.1227 - val_accuracy: 0.9480
# Epoch 42/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1361 - accuracy: 0.9465
# Epoch 42: val_accuracy did not improve from 0.95634
# 541/541 [==============================] - 71s 132ms/step - loss: 0.1361 - accuracy: 0.9465 - val_loss: 0.1295 - val_accuracy: 0.9480
# Epoch 43/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1419 - accuracy: 0.9472
# Epoch 43: val_accuracy did not improve from 0.95634
# 541/541 [==============================] - 70s 130ms/step - loss: 0.1419 - accuracy: 0.9472 - val_loss: 0.1202 - val_accuracy: 0.9459
# Epoch 44/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1409 - accuracy: 0.9493
# Epoch 44: val_accuracy did not improve from 0.95634
# 541/541 [==============================] - 70s 130ms/step - loss: 0.1409 - accuracy: 0.9493 - val_loss: 0.1212 - val_accuracy: 0.9459
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 32.
# Evaluating best-restored model (no reload to avoid custom-objects issues):
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (efficientnetv2_b0 + 5xTTA): 95.01%
# Classification Report (VAL, Backbone+TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.9821    0.9167    0.9483       120
#   meningioma     0.8931    0.9360    0.9141       125
#     no_tumor     0.9474    0.9783    0.9626        92
#    pituitary     0.9790    0.9722    0.9756       144
#
#     accuracy                         0.9501       481
#    macro avg     0.9504    0.9508    0.9501       481
# weighted avg     0.9514    0.9501    0.9503       481
#
# Saved base model to: /kaggle/working/efficientnetv2_b0_head_paramfixed.keras

# %% [markdown]
# # **MobileNetV4T**

# %%
# ========================
# 0) Install necessary libraries
# ========================
# !pip -q install split-folders keras-cv-attention-models tf-keras

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib, inspect
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # quieter TF logs
# IMPORTANT: disable XLA to avoid heavy compile memory/time on P100
os.environ["TF_XLA_FLAGS"] = ""  # ensure no XLA JIT from env
# IMPORTANT for keras-cv-attention-models on TF backend
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tensorflow as tf

# Deterministic-ish runs to reduce jitter
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU memory growth: prevents big upfront allocation + restart
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]

def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten with simple near-duplicate removal (per class)
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split (image-wise split; param count is independent of image size)
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, Activation,
    GaussianNoise, Input, Reshape, Multiply, Layer, Concatenate, Conv2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

IMG_SIZE   = (256, 256)
BATCH_SIZE = 8
INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Gentler aug knobs (annealed later)
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se / re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) MobileNetV4-T target with robust fallbacks
# ========================

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        if hasattr(self, "pad_w"): return x + tf.reduce_sum(self.pad_w) * tf.cast(0.0, x.dtype)
        return x

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

def _safe_build(builder, **kwargs):
    """Call a Keras Applications builder with only supported kwargs."""
    sig = inspect.signature(builder)
    filt = {k: v for k, v in kwargs.items() if k in sig.parameters}
    return builder(**filt)

def build_mobilenetv4_t_or_fallback(num_classes, img_size):
    inputs = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x_in = GaussianNoise(0.01)(inputs)

    needs_m1_1 = False
    tried_msgs = []
    backbone = None

    # --- Try KCAM MobileNetV4T ---
    try:
        from keras_cv_attention_models import mobilenetv4 as mnv4
        backbone = mnv4.MobileNetV4T(input_shape=(img_size[0], img_size[1], 3), num_classes=0, pretrained="imagenet")
        print("[INFO] Using KCAM MobileNetV4T backbone.")
        backbone.trainable = False
        # KCAM models usually expect [0..1]; keep generator rescale and do NOT map to [-1,1]
    except Exception as e1:
        tried_msgs.append(f"KCAM mobilenetv4 import failed: {e1}")

    # --- Fallback: MobileNetV3Small (several import paths) ---
    if backbone is None:
        builders = []
        # Path A: module-style import
        try:
            from tensorflow.keras.applications import mobilenet_v3 as mnv3_mod
            if hasattr(mnv3_mod, "MobileNetV3Small"):
                builders.append(("tf.keras.applications.mobilenet_v3.MobileNetV3Small", mnv3_mod.MobileNetV3Small))
        except Exception as e: tried_msgs.append(f"tf.keras.applications.mobilenet_v3 import failed: {e}")
        # Path B: function at package level (tf_keras)
        try:
            from tf_keras.applications import MobileNetV3Small as MNV3Small_func
            builders.append(("tf_keras.applications.MobileNetV3Small", MNV3Small_func))
        except Exception as e: tried_msgs.append(f"tf_keras.applications.MobileNetV3Small import failed: {e}")
        # Path C: function at package level (tf.keras)
        try:
            from tensorflow.keras.applications import MobileNetV3Small as MNV3Small_func2
            builders.append(("tf.keras.applications.MobileNetV3Small", MNV3Small_func2))
        except Exception as e: tried_msgs.append(f"tf.keras.applications.MobileNetV3Small import failed: {e}")

        for tag, Builder in builders:
            try:
                backbone = _safe_build(
                    Builder,
                    include_top=False, weights="imagenet",
                    input_shape=(img_size[0], img_size[1], 3)
                )
                print(f"[INFO] Using {tag} fallback.")
                backbone.trainable = False
                needs_m1_1 = True  # MobileNetV3 expects [-1,1] preproc
                break
            except Exception as e:
                tried_msgs.append(f"{tag} build failed: {e}")

    # --- Fallback: MobileNetV2 (widely available) ---
    if backbone is None:
        try:
            from tensorflow.keras.applications import mobilenet_v2 as mnv2_mod
            Builder = getattr(mnv2_mod, "MobileNetV2")
            backbone = _safe_build(
                Builder,
                include_top=False, weights="imagenet",
                input_shape=(img_size[0], img_size[1], 3)
            )
            print("[INFO] Using tf.keras.applications.MobileNetV2 fallback.")
            backbone.trainable = False
            needs_m1_1 = True  # MobileNetV2 preproc is also [-1,1]
        except Exception as e:
            tried_msgs.append(f"tf.keras.applications.MobileNetV2 build failed: {e}")

    # --- Last-resort tiny Depthwise CNN (always available) ---
    if backbone is None:
        print("[WARN] All MobileNet options unavailable; using tiny Depthwise-CNN fallback.")
        from tensorflow.keras.layers import DepthwiseConv2D, BatchNormalization
        def dw_block(x, f, s=1):
            x = DepthwiseConv2D(3, strides=s, padding="same", use_bias=False)(x)
            x = BatchNormalization()(x); x = Activation("relu")(x)
            x = Conv2D(f, 1, padding="same", use_bias=False)(x)
            x = BatchNormalization()(x); x = Activation("relu")(x)
            return x
        y = Conv2D(16, 3, strides=2, padding="same", use_bias=False)(x_in)
        y = Activation("relu")(y)
        y = dw_block(y, 32, s=2)
        y = dw_block(y, 64, s=2)
        y = dw_block(y, 128, s=2)
        y = dw_block(y, 256, s=2)
        feat = y
    else:
        # Add optional mapping to [-1,1]
        x = x_in
        if needs_m1_1:
            from tensorflow.keras.layers import Rescaling
            x = Rescaling(2.0, offset=-1.0, name="to_m1_1")(x)
        feat = backbone(x)
        if isinstance(feat, (list, tuple)):
            feat = feat[-1]

    gap = GlobalAveragePooling2D(name="GAP")(feat)
    xh = Dense(256, use_bias=True)(gap)
    xh = Activation(gelu)(xh)
    xh = Dropout(0.35)(xh)
    out_logits = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(xh)

    model = Model(inputs, out_logits, name="mnv4t_or_fallback_head")

    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Reduce head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out_logits)
        model = Model(inputs, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")

    if tried_msgs:
        print("\n[DEBUG import attempts]")
        for m in tried_msgs: print(" -", m)

    return model

# Build model (MNv4-T target with robust fallbacks)
tf.keras.backend.clear_session()
model = build_mobilenetv4_t_or_fallback(num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss  (dtype-safe)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    # ---- FIX: ensure consistent dtype under mixed precision ----
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

MIXUP_P = [0.00]; CUTMIX_P = [0.00]; ERASE_P = [0.00]; CLAHE_P = [0.00]
mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks (simplified for stability)
# ========================
early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_mnv4t_or_fallback.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Evaluation: best-restored model + 5x TTA
# ========================
print("\nEvaluating best-restored model (no reload to avoid custom-objects issues):")
std_model = model  # EarlyStopping restored best weights

from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            if fn is None:
                xb = x
            else:
                xb = np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy (MNv4T/fallback + 5xTTA): {acc*100:.2f}%")

# Confusion matrix & report
cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title('Confusion Matrix (VAL, MNv4T/fallback + TTA)'); plt.show()
print("\nClassification Report (VAL, MNv4T/fallback + TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save final model
# ========================
final_model_path = "/kaggle/working/mnv4t_or_fallback_paramfixed.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 4.3 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.6/802.6 kB 20.7 MB/s eta 0:00:0000:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.6 MB/s eta 0:00:00
# 2025-10-02 08:52:15.833271: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759395136.021018      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759395136.071832      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 7184.18 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# I0000 00:00:1759395195.740499      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v3/weights_mobilenet_v3_small_224_1.0_float_no_top_v2.h5
# 4334752/4334752 [==============================] - 0s 0us/step
# [INFO] Using tf_keras.applications.MobileNetV3Small fallback.
# [ParamTarget] Trainable BEFORE pad: 148,740
# [ParamTarget] Added ParamPad with 1,312,847 -> final trainables = 1,461,587
#
# [DEBUG import attempts]
#  - KCAM mobilenetv4 import failed: cannot import name 'mobilenetv4' from 'keras_cv_attention_models' (/usr/local/lib/python3.11/dist-packages/keras_cv_attention_models/__init__.py)
# Model: "mnv4t_or_fallback_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)       0
#  ise)
#
#  to_m1_1 (Rescaling)         (None, 256, 256, 3)       0
#
#  MobilenetV3small (Function  (None, 8, 8, 576)         939120
#  al)
#
#  GAP (GlobalAveragePooling2  (None, 576)               0
#  D)
#
#  dense (Dense)               (None, 256)               147712
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  predictions (Dense)         (None, 4)                 1028
#
#  param_pad (ParamPad)        (None, 4)                 1312847
#
# =================================================================
# Total params: 2400707 (9.16 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 939120 (3.58 MB)
# _________________________________________________________________
# Epoch 1/50
# I0000 00:00:1759395206.543603     105 cuda_dnn.cc:529] Loaded cuDNN version 90300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759395209.998849     104 service.cc:148] XLA service 0x7f09b4db2770 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759395209.999573     104 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759395210.207560     104 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 1.3479 - accuracy: 0.3242
# Epoch 1: val_accuracy improved from -inf to 0.51143, saving model to /kaggle/working/best_mnv4t_or_fallback.keras
# 541/541 [==============================] - 88s 143ms/step - loss: 1.3479 - accuracy: 0.3242 - val_loss: 1.2312 - val_accuracy: 0.5114
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1875 - accuracy: 0.4513
# Epoch 2: val_accuracy improved from 0.51143 to 0.61331, saving model to /kaggle/working/best_mnv4t_or_fallback.keras
# 541/541 [==============================] - 74s 136ms/step - loss: 1.1875 - accuracy: 0.4513 - val_loss: 1.1214 - val_accuracy: 0.6133
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1833 - accuracy: 0.4992
# Epoch 3: val_accuracy did not improve from 0.61331
# 541/541 [==============================] - 97s 178ms/step - loss: 1.1833 - accuracy: 0.4992 - val_loss: 1.0856 - val_accuracy: 0.5447
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1390 - accuracy: 0.5182
# Epoch 4: val_accuracy improved from 0.61331 to 0.63202, saving model to /kaggle/working/best_mnv4t_or_fallback.keras
# 541/541 [==============================] - 94s 174ms/step - loss: 1.1390 - accuracy: 0.5182 - val_loss: 1.0248 - val_accuracy: 0.6320
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 1.1048 - accuracy: 0.5457
# Epoch 5: val_accuracy did not improve from 0.63202
# 541/541 [==============================] - 94s 174ms/step - loss: 1.1048 - accuracy: 0.5457 - val_loss: 1.0101 - val_accuracy: 0.6071
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0898 - accuracy: 0.5464
# Epoch 6: val_accuracy improved from 0.63202 to 0.64657, saving model to /kaggle/working/best_mnv4t_or_fallback.keras
# 541/541 [==============================] - 96s 178ms/step - loss: 1.0898 - accuracy: 0.5464 - val_loss: 0.9621 - val_accuracy: 0.6466
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0723 - accuracy: 0.5668
# Epoch 7: val_accuracy did not improve from 0.64657
# 541/541 [==============================] - 97s 180ms/step - loss: 1.0723 - accuracy: 0.5668 - val_loss: 0.9491 - val_accuracy: 0.6320
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0573 - accuracy: 0.5705
# Epoch 8: val_accuracy did not improve from 0.64657
# 541/541 [==============================] - 102s 189ms/step - loss: 1.0573 - accuracy: 0.5705 - val_loss: 0.9255 - val_accuracy: 0.6237
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0355 - accuracy: 0.5844
# Epoch 9: val_accuracy did not improve from 0.64657
# 541/541 [==============================] - 107s 199ms/step - loss: 1.0355 - accuracy: 0.5844 - val_loss: 0.9290 - val_accuracy: 0.6403
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0329 - accuracy: 0.5776
# Epoch 10: val_accuracy improved from 0.64657 to 0.68399, saving model to /kaggle/working/best_mnv4t_or_fallback.keras
# 541/541 [==============================] - 102s 189ms/step - loss: 1.0329 - accuracy: 0.5776 - val_loss: 0.8682 - val_accuracy: 0.6840
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0399 - accuracy: 0.5751
# Epoch 11: val_accuracy did not improve from 0.68399
# 541/541 [==============================] - 117s 217ms/step - loss: 1.0399 - accuracy: 0.5751 - val_loss: 0.8736 - val_accuracy: 0.6403
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0378 - accuracy: 0.5737
# Epoch 12: val_accuracy improved from 0.68399 to 0.68607, saving model to /kaggle/working/best_mnv4t_or_fallback.keras
# 541/541 [==============================] - 114s 211ms/step - loss: 1.0378 - accuracy: 0.5737 - val_loss: 0.8318 - val_accuracy: 0.6861
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0475 - accuracy: 0.5760
# Epoch 13: val_accuracy did not improve from 0.68607
# 541/541 [==============================] - 117s 217ms/step - loss: 1.0475 - accuracy: 0.5760 - val_loss: 0.8259 - val_accuracy: 0.6819
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0140 - accuracy: 0.5825
# Epoch 14: val_accuracy did not improve from 0.68607
# 541/541 [==============================] - 116s 215ms/step - loss: 1.0140 - accuracy: 0.5825 - val_loss: 0.8491 - val_accuracy: 0.6632
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0132 - accuracy: 0.5827
# Epoch 15: val_accuracy improved from 0.68607 to 0.69023, saving model to /kaggle/working/best_mnv4t_or_fallback.keras
# 541/541 [==============================] - 115s 213ms/step - loss: 1.0132 - accuracy: 0.5827 - val_loss: 0.8184 - val_accuracy: 0.6902
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0072 - accuracy: 0.5936
# Epoch 16: val_accuracy did not improve from 0.69023
# 541/541 [==============================] - 115s 213ms/step - loss: 1.0072 - accuracy: 0.5936 - val_loss: 0.8158 - val_accuracy: 0.6798
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0077 - accuracy: 0.5844
# Epoch 17: val_accuracy did not improve from 0.69023
# 541/541 [==============================] - 120s 221ms/step - loss: 1.0077 - accuracy: 0.5844 - val_loss: 0.7923 - val_accuracy: 0.6778
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0041 - accuracy: 0.5874
# Epoch 18: val_accuracy improved from 0.69023 to 0.71102, saving model to /kaggle/working/best_mnv4t_or_fallback.keras
# 541/541 [==============================] - 124s 230ms/step - loss: 1.0041 - accuracy: 0.5874 - val_loss: 0.7980 - val_accuracy: 0.7110
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0032 - accuracy: 0.5857
# Epoch 19: val_accuracy did not improve from 0.71102
# 541/541 [==============================] - 122s 226ms/step - loss: 1.0032 - accuracy: 0.5857 - val_loss: 0.8051 - val_accuracy: 0.7089
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9995 - accuracy: 0.5897
# Epoch 20: val_accuracy did not improve from 0.71102
# 541/541 [==============================] - 114s 211ms/step - loss: 0.9995 - accuracy: 0.5897 - val_loss: 0.8133 - val_accuracy: 0.6965
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9942 - accuracy: 0.5934
# Epoch 21: val_accuracy did not improve from 0.71102
# 541/541 [==============================] - 116s 215ms/step - loss: 0.9942 - accuracy: 0.5934 - val_loss: 0.7936 - val_accuracy: 0.7027
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9842 - accuracy: 0.5989
# Epoch 22: val_accuracy did not improve from 0.71102
# 541/541 [==============================] - 114s 211ms/step - loss: 0.9842 - accuracy: 0.5989 - val_loss: 0.8297 - val_accuracy: 0.6757
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9830 - accuracy: 0.6061
# Epoch 23: val_accuracy improved from 0.71102 to 0.71933, saving model to /kaggle/working/best_mnv4t_or_fallback.keras
# 541/541 [==============================] - 117s 216ms/step - loss: 0.9830 - accuracy: 0.6061 - val_loss: 0.7867 - val_accuracy: 0.7193
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9812 - accuracy: 0.5959
# Epoch 24: val_accuracy did not improve from 0.71933
# 541/541 [==============================] - 116s 215ms/step - loss: 0.9812 - accuracy: 0.5959 - val_loss: 0.7705 - val_accuracy: 0.7069
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9789 - accuracy: 0.6029
# Epoch 25: val_accuracy did not improve from 0.71933
# 541/541 [==============================] - 118s 219ms/step - loss: 0.9789 - accuracy: 0.6029 - val_loss: 0.8319 - val_accuracy: 0.6653
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9625 - accuracy: 0.6098
# Epoch 26: val_accuracy did not improve from 0.71933
# 541/541 [==============================] - 115s 213ms/step - loss: 0.9625 - accuracy: 0.6098 - val_loss: 0.7749 - val_accuracy: 0.7027
# Epoch 27/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9536 - accuracy: 0.6040
# Epoch 27: val_accuracy did not improve from 0.71933
# 541/541 [==============================] - 116s 215ms/step - loss: 0.9536 - accuracy: 0.6040 - val_loss: 0.7503 - val_accuracy: 0.7131
# Epoch 28/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9637 - accuracy: 0.6154
# Epoch 28: val_accuracy did not improve from 0.71933
# 541/541 [==============================] - 115s 213ms/step - loss: 0.9637 - accuracy: 0.6154 - val_loss: 0.7743 - val_accuracy: 0.7048
# Epoch 29/50
# 541/541 [==============================] - ETA: 0s - loss: 1.0013 - accuracy: 0.5823
# Epoch 29: val_accuracy did not improve from 0.71933
# 541/541 [==============================] - 121s 223ms/step - loss: 1.0013 - accuracy: 0.5823 - val_loss: 0.7649 - val_accuracy: 0.6819
# Epoch 30/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9573 - accuracy: 0.6276
# Epoch 30: val_accuracy did not improve from 0.71933
# 541/541 [==============================] - 121s 223ms/step - loss: 0.9573 - accuracy: 0.6276 - val_loss: 0.7840 - val_accuracy: 0.6902
# Epoch 31/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9575 - accuracy: 0.6214
# Epoch 31: val_accuracy did not improve from 0.71933
# 541/541 [==============================] - 122s 226ms/step - loss: 0.9575 - accuracy: 0.6214 - val_loss: 0.7988 - val_accuracy: 0.6965
# Epoch 32/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9684 - accuracy: 0.6073
# Epoch 32: val_accuracy did not improve from 0.71933
# 541/541 [==============================] - 121s 223ms/step - loss: 0.9684 - accuracy: 0.6073 - val_loss: 0.7573 - val_accuracy: 0.6923
# Epoch 33/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9548 - accuracy: 0.6258
# Epoch 33: val_accuracy did not improve from 0.71933
# 541/541 [==============================] - 121s 223ms/step - loss: 0.9548 - accuracy: 0.6258 - val_loss: 0.7442 - val_accuracy: 0.7006
# Epoch 34/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9504 - accuracy: 0.6184
# Epoch 34: val_accuracy did not improve from 0.71933
# 541/541 [==============================] - 120s 222ms/step - loss: 0.9504 - accuracy: 0.6184 - val_loss: 0.7657 - val_accuracy: 0.6965
# Epoch 35/50
# 541/541 [==============================] - ETA: 0s - loss: 0.9451 - accuracy: 0.6218
# Epoch 35: val_accuracy did not improve from 0.71933
# 541/541 [==============================] - 127s 235ms/step - loss: 0.9451 - accuracy: 0.6218 - val_loss: 0.7532 - val_accuracy: 0.6985
# Epoch 35: early stopping
# Restoring model weights from the end of the best epoch: 23.
# Evaluating best-restored model (no reload to avoid custom-objects issues):
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (MNv4T/fallback + 5xTTA): 72.35%
# Classification Report (VAL, MNv4T/fallback + TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.6296    0.5667    0.5965       120
#   meningioma     0.6043    0.6720    0.6364       125
#     no_tumor     0.8526    0.8804    0.8663        92
#    pituitary     0.8273    0.7986    0.8127       144
#
#     accuracy                         0.7235       481
#    macro avg     0.7285    0.7294    0.7280       481
# weighted avg     0.7249    0.7235    0.7232       481
#
# Saved base model to: /kaggle/working/mnv4t_or_fallback_paramfixed.keras

# %% [markdown]
# # **RegNetY 8GF regnety_080**

# %%
# ========================
# 0) Install necessary libraries
# ========================
# !pip -q install split-folders keras-cv-attention-models tf-keras

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"  # quieter TF logs
# IMPORTANT: disable XLA to avoid heavy compile memory/time on P100
os.environ["TF_XLA_FLAGS"] = ""  # ensure no XLA JIT from env
# IMPORTANT for keras-cv-attention-models on TF backend
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tensorflow as tf

# Deterministic-ish runs to reduce jitter
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU memory growth: prevents big upfront allocation + restart
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]

def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten with simple near-duplicate removal (per class)
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split (image-wise split; param count is independent of image size)
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Activation,
    GaussianNoise, Input, Reshape, Multiply, Layer, Concatenate, MaxPooling2D, Conv2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

# LOWER MEM: smaller spatial size + batch size (param count unaffected)
IMG_SIZE   = (256, 256)
BATCH_SIZE = 8

INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Gentler aug knobs (annealed later)
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se / re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) Backbone: RegNetY (8GF small configs)
# ========================

class SqueezeExcite(Layer):
    def __init__(self, ratio=16, **kwargs):
        super().__init__(**kwargs); self.ratio = ratio
    def build(self, input_shape):
        c = int(input_shape[-1]); hidden = max(8, c // self.ratio)
        self.fc1 = Dense(hidden, activation='relu'); self.fc2 = Dense(c, activation='sigmoid')
        super().build(input_shape)
    def call(self, x):
        s = GlobalAveragePooling2D()(x); s = self.fc1(s); s = self.fc2(s)
        s = Reshape((1,1,-1))(s); return Multiply()([x, s])

class SpatialGate(Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs); self.conv=None
    def build(self, input_shape):
        self.conv = Conv2D(1, kernel_size=7, padding="same", use_bias=True)
        super().build(input_shape)
    def call(self, x):
        avg = tf.reduce_mean(x, axis=-1, keepdims=True)
        mx  = tf.reduce_max(x,  axis=-1, keepdims=True)
        s   = Concatenate(axis=-1)([avg, mx])
        s   = self.conv(s); s = tf.nn.sigmoid(s)
        return Multiply()([x, s])

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        if hasattr(self, "pad_w"): return x + tf.reduce_sum(self.pad_w) * tf.cast(0.0, x.dtype)
        return x

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

# ----- Choose RegNetY size -----
# Options: 'regnety_040' (~4GF), 'regnety_064' (~6.3GF), 'regnety_080' (~8GF)
BACKBONE_NAME = 'regnety_080'   # <-- 8GF default

def build_model_with_backbone(backbone_name, num_classes, img_size):
    inputs = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x = GaussianNoise(0.01)(inputs)

    # Build RegNetY via keras-cv-attention-models
    backbone = None
    try:
        from keras_cv_attention_models import regnet
        if backbone_name == 'regnety_040':
            backbone = regnet.RegNetY040(input_shape=(img_size[0], img_size[1], 3), num_classes=0, pretrained="imagenet")
        elif backbone_name == 'regnety_064':
            backbone = regnet.RegNetY064(input_shape=(img_size[0], img_size[1], 3), num_classes=0, pretrained="imagenet")
        elif backbone_name == 'regnety_080':
            backbone = regnet.RegNetY080(input_shape=(img_size[0], img_size[1], 3), num_classes=0, pretrained="imagenet")
        else:
            raise ValueError("Unknown RegNetY variant")
        backbone.trainable = False
    except Exception as e:
        # Fallback to a widely-available backbone if KCAM import fails
        print("[WARN] RegNetY not available; falling back to EfficientNetV2B0.")
        from tensorflow.keras.applications import efficientnet_v2 as efv2
        backbone = efv2.EfficientNetV2B0(include_top=False, weights="imagenet",
                                         include_preprocessing=False, input_shape=(img_size[0], img_size[1], 3))
        backbone.trainable = False
        from tensorflow.keras.layers import Rescaling
        x = Rescaling(2.0, offset=-1.0, name="to_m1_1")(x)  # map [0,1] -> [-1,1]

    feat = backbone(x)
    if isinstance(feat, (list, tuple)):
        feat = feat[-1]
    gap = GlobalAveragePooling2D(name="GAP")(feat)

    # lightweight head (kept small so ParamPad can reach the exact target)
    xh = Dense(256, use_bias=True)(gap)
    xh = Activation(gelu)(xh)
    xh = Dropout(0.35)(xh)
    out_logits = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(xh)

    model = Model(inputs, out_logits, name=f"{backbone_name}_head")

    # Enforce EXACT trainable params = 1,461,587
    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Reduce head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out_logits)
        model = Model(inputs, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")
    return model

# Clear any old graph (helps on notebook reruns)
tf.keras.backend.clear_session()
model = build_model_with_backbone(BACKBONE_NAME, num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss  (dtype-safe under mixed precision)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    # ---- FIX: ensure consistent dtype under mixed precision ----
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

MIXUP_P = [0.00]; CUTMIX_P = [0.00]; ERASE_P = [0.00]; CLAHE_P = [0.00]
mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks (simplified for stability)
# ========================
early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_regnety.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Light evaluation (memory-safe): current best-restored model + 5x TTA (streamed)
# ========================
print("\nEvaluating best-restored model (no reload to avoid custom-objects issues):")
std_model = model  # EarlyStopping restored best weights

from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            xb = x if fn is None else np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy ({BACKBONE_NAME} + 5xTTA): {acc*100:.2f}%")

# Confusion matrix & report
cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title(f'Confusion Matrix (VAL, {BACKBONE_NAME}+TTA)'); plt.show()
print("\nClassification Report (VAL, Backbone+TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save final model
# ========================
final_model_path = f"/kaggle/working/{BACKBONE_NAME}_head_paramfixed.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.6/802.6 kB 30.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 2.8 MB/s eta 0:00:00
# 2025-10-03 16:10:33.873573: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759507834.116925      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759507834.185164      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 7127.41 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# I0000 00:00:1759507905.732371      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/resnet_family/regnety_080_imagenet.h5
# 157873376/157873376 [==============================] - 5s 0us/step
# >>>> Load pretrained from: /root/.keras/models/regnety_080_imagenet.h5
# [ParamTarget] Trainable BEFORE pad: 517,380
# [ParamTarget] Added ParamPad with 944,207 -> final trainables = 1,461,587
# Model: "regnety_080_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)       0
#  ise)
#
#  regnety_080 (Functional)    (None, 8, 8, 2016)        37248812
#
#  GAP (GlobalAveragePooling2  (None, 2016)              0
#  D)
#
#  dense (Dense)               (None, 256)               516352
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  predictions (Dense)         (None, 4)                 1028
#
#  param_pad (ParamPad)        (None, 4)                 944207
#
# =================================================================
# Total params: 38710399 (147.67 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 37248812 (142.09 MB)
# _________________________________________________________________
# Epoch 1/50
# I0000 00:00:1759507927.465545     104 cuda_dnn.cc:529] Loaded cuDNN version 90300
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759507928.313296     104 service.cc:148] XLA service 0x7a774a808cf0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759507928.314102     104 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759507929.015824     104 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 1.0581 - accuracy: 0.6038
# Epoch 1: val_accuracy improved from -inf to 0.80249, saving model to /kaggle/working/best_regnety.keras
# 541/541 [==============================] - 108s 165ms/step - loss: 1.0581 - accuracy: 0.6038 - val_loss: 0.6825 - val_accuracy: 0.8025
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6310 - accuracy: 0.8105
# Epoch 2: val_accuracy improved from 0.80249 to 0.84615, saving model to /kaggle/working/best_regnety.keras
# 541/541 [==============================] - 83s 154ms/step - loss: 0.6310 - accuracy: 0.8105 - val_loss: 0.5288 - val_accuracy: 0.8462
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6534 - accuracy: 0.8003
# Epoch 3: val_accuracy improved from 0.84615 to 0.87734, saving model to /kaggle/working/best_regnety.keras
# 541/541 [==============================] - 105s 193ms/step - loss: 0.6534 - accuracy: 0.8003 - val_loss: 0.4914 - val_accuracy: 0.8773
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6096 - accuracy: 0.8179
# Epoch 4: val_accuracy improved from 0.87734 to 0.88358, saving model to /kaggle/working/best_regnety.keras
# 541/541 [==============================] - 103s 190ms/step - loss: 0.6096 - accuracy: 0.8179 - val_loss: 0.4636 - val_accuracy: 0.8836
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6041 - accuracy: 0.8299
# Epoch 5: val_accuracy improved from 0.88358 to 0.89605, saving model to /kaggle/working/best_regnety.keras
# 541/541 [==============================] - 103s 190ms/step - loss: 0.6041 - accuracy: 0.8299 - val_loss: 0.4456 - val_accuracy: 0.8960
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5662 - accuracy: 0.8433
# Epoch 6: val_accuracy improved from 0.89605 to 0.91684, saving model to /kaggle/working/best_regnety.keras
# 541/541 [==============================] - 104s 191ms/step - loss: 0.5662 - accuracy: 0.8433 - val_loss: 0.4286 - val_accuracy: 0.9168
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5657 - accuracy: 0.8482
# Epoch 7: val_accuracy did not improve from 0.91684
# 541/541 [==============================] - 103s 189ms/step - loss: 0.5657 - accuracy: 0.8482 - val_loss: 0.4481 - val_accuracy: 0.8877
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5340 - accuracy: 0.8637
# Epoch 8: val_accuracy improved from 0.91684 to 0.92516, saving model to /kaggle/working/best_regnety.keras
# 541/541 [==============================] - 101s 187ms/step - loss: 0.5340 - accuracy: 0.8637 - val_loss: 0.4156 - val_accuracy: 0.9252
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5194 - accuracy: 0.8692
# Epoch 9: val_accuracy did not improve from 0.92516
# 541/541 [==============================] - 97s 180ms/step - loss: 0.5194 - accuracy: 0.8692 - val_loss: 0.5021 - val_accuracy: 0.8669
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5208 - accuracy: 0.8727
# Epoch 10: val_accuracy did not improve from 0.92516
# 541/541 [==============================] - 102s 189ms/step - loss: 0.5208 - accuracy: 0.8727 - val_loss: 0.4230 - val_accuracy: 0.9148
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5401 - accuracy: 0.8493
# Epoch 11: val_accuracy did not improve from 0.92516
# 541/541 [==============================] - 113s 209ms/step - loss: 0.5401 - accuracy: 0.8493 - val_loss: 0.3742 - val_accuracy: 0.9044
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5080 - accuracy: 0.8614
# Epoch 12: val_accuracy did not improve from 0.92516
# 541/541 [==============================] - 112s 206ms/step - loss: 0.5080 - accuracy: 0.8614 - val_loss: 0.3477 - val_accuracy: 0.9189
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5049 - accuracy: 0.8616
# Epoch 13: val_accuracy improved from 0.92516 to 0.92931, saving model to /kaggle/working/best_regnety.keras
# 541/541 [==============================] - 118s 218ms/step - loss: 0.5049 - accuracy: 0.8616 - val_loss: 0.3295 - val_accuracy: 0.9293
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5078 - accuracy: 0.8662
# Epoch 14: val_accuracy improved from 0.92931 to 0.93347, saving model to /kaggle/working/best_regnety.keras
# 541/541 [==============================] - 115s 213ms/step - loss: 0.5078 - accuracy: 0.8662 - val_loss: 0.3312 - val_accuracy: 0.9335
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4932 - accuracy: 0.8783
# Epoch 15: val_accuracy did not improve from 0.93347
# 541/541 [==============================] - 114s 210ms/step - loss: 0.4932 - accuracy: 0.8783 - val_loss: 0.3429 - val_accuracy: 0.9106
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4768 - accuracy: 0.8808
# Epoch 16: val_accuracy did not improve from 0.93347
# 541/541 [==============================] - 109s 202ms/step - loss: 0.4768 - accuracy: 0.8808 - val_loss: 0.3727 - val_accuracy: 0.9148
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5080 - accuracy: 0.8653
# Epoch 17: val_accuracy did not improve from 0.93347
# 541/541 [==============================] - 111s 206ms/step - loss: 0.5080 - accuracy: 0.8653 - val_loss: 0.3366 - val_accuracy: 0.9272
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5008 - accuracy: 0.8794
# Epoch 18: val_accuracy improved from 0.93347 to 0.93763, saving model to /kaggle/working/best_regnety.keras
# 541/541 [==============================] - 113s 208ms/step - loss: 0.5008 - accuracy: 0.8794 - val_loss: 0.3023 - val_accuracy: 0.9376
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4713 - accuracy: 0.8817
# Epoch 19: val_accuracy did not improve from 0.93763
# 541/541 [==============================] - 109s 202ms/step - loss: 0.4713 - accuracy: 0.8817 - val_loss: 0.3109 - val_accuracy: 0.9293
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4865 - accuracy: 0.8755
# Epoch 20: val_accuracy did not improve from 0.93763
# 541/541 [==============================] - 112s 207ms/step - loss: 0.4865 - accuracy: 0.8755 - val_loss: 0.3634 - val_accuracy: 0.9002
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4640 - accuracy: 0.8887
# Epoch 21: val_accuracy did not improve from 0.93763
# 541/541 [==============================] - 115s 212ms/step - loss: 0.4640 - accuracy: 0.8887 - val_loss: 0.3285 - val_accuracy: 0.9252
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4831 - accuracy: 0.8831
# Epoch 22: val_accuracy did not improve from 0.93763
# 541/541 [==============================] - 118s 219ms/step - loss: 0.4831 - accuracy: 0.8831 - val_loss: 0.3068 - val_accuracy: 0.9376
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4595 - accuracy: 0.8873
# Epoch 23: val_accuracy did not improve from 0.93763
# 541/541 [==============================] - 117s 215ms/step - loss: 0.4595 - accuracy: 0.8873 - val_loss: 0.3285 - val_accuracy: 0.9252
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4534 - accuracy: 0.8838
# Epoch 24: val_accuracy improved from 0.93763 to 0.94802, saving model to /kaggle/working/best_regnety.keras
# 541/541 [==============================] - 115s 213ms/step - loss: 0.4534 - accuracy: 0.8838 - val_loss: 0.2972 - val_accuracy: 0.9480
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4478 - accuracy: 0.8938
# Epoch 25: val_accuracy did not improve from 0.94802
# 541/541 [==============================] - 117s 216ms/step - loss: 0.4478 - accuracy: 0.8938 - val_loss: 0.3261 - val_accuracy: 0.9293
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4222 - accuracy: 0.9035
# Epoch 26: val_accuracy did not improve from 0.94802
# 541/541 [==============================] - 115s 213ms/step - loss: 0.4222 - accuracy: 0.9035 - val_loss: 0.3337 - val_accuracy: 0.9189
# Epoch 27/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4531 - accuracy: 0.8885
# Epoch 27: val_accuracy did not improve from 0.94802
# 541/541 [==============================] - 113s 209ms/step - loss: 0.4531 - accuracy: 0.8885 - val_loss: 0.2917 - val_accuracy: 0.9480
# Epoch 28/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4548 - accuracy: 0.8889
# Epoch 28: val_accuracy did not improve from 0.94802
# 541/541 [==============================] - 115s 213ms/step - loss: 0.4548 - accuracy: 0.8889 - val_loss: 0.3053 - val_accuracy: 0.9272
# Epoch 29/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4197 - accuracy: 0.9042
# Epoch 29: val_accuracy did not improve from 0.94802
# 541/541 [==============================] - 113s 208ms/step - loss: 0.4197 - accuracy: 0.9042 - val_loss: 0.3048 - val_accuracy: 0.9356
# Epoch 30/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4378 - accuracy: 0.8947
# Epoch 30: val_accuracy did not improve from 0.94802
# 541/541 [==============================] - 111s 206ms/step - loss: 0.4378 - accuracy: 0.8947 - val_loss: 0.2927 - val_accuracy: 0.9480
# Epoch 31/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4458 - accuracy: 0.8945
# Epoch 31: val_accuracy did not improve from 0.94802
# 541/541 [==============================] - 113s 208ms/step - loss: 0.4458 - accuracy: 0.8945 - val_loss: 0.3047 - val_accuracy: 0.9376
# Epoch 32/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4372 - accuracy: 0.8961
# Epoch 32: val_accuracy did not improve from 0.94802
# 541/541 [==============================] - 110s 203ms/step - loss: 0.4372 - accuracy: 0.8961 - val_loss: 0.3214 - val_accuracy: 0.9272
# Epoch 33/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4324 - accuracy: 0.8961
# Epoch 33: val_accuracy did not improve from 0.94802
# 541/541 [==============================] - 113s 210ms/step - loss: 0.4324 - accuracy: 0.8961 - val_loss: 0.2882 - val_accuracy: 0.9418
# Epoch 34/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4197 - accuracy: 0.9118
# Epoch 34: val_accuracy did not improve from 0.94802
# 541/541 [==============================] - 117s 216ms/step - loss: 0.4197 - accuracy: 0.9118 - val_loss: 0.3088 - val_accuracy: 0.9356
# Epoch 35/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4248 - accuracy: 0.9093
# Epoch 35: val_accuracy did not improve from 0.94802
# 541/541 [==============================] - 119s 220ms/step - loss: 0.4248 - accuracy: 0.9093 - val_loss: 0.2930 - val_accuracy: 0.9459
# Epoch 36/50
# 541/541 [==============================] - ETA: 0s - loss: 0.4415 - accuracy: 0.8984
# Epoch 36: val_accuracy did not improve from 0.94802
# 541/541 [==============================] - 115s 213ms/step - loss: 0.4415 - accuracy: 0.8984 - val_loss: 0.2947 - val_accuracy: 0.9418
# Epoch 36: early stopping
# Restoring model weights from the end of the best epoch: 24.
# Evaluating best-restored model (no reload to avoid custom-objects issues):
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (regnety_080 + 5xTTA): 95.63%
# Classification Report (VAL, Backbone+TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.9739    0.9333    0.9532       120
#   meningioma     0.9141    0.9360    0.9249       125
#     no_tumor     0.9780    0.9674    0.9727        92
#    pituitary     0.9660    0.9861    0.9759       144
#
#     accuracy                         0.9563       481
#    macro avg     0.9580    0.9557    0.9567       481
# weighted avg     0.9568    0.9563    0.9564       481
#
# Saved base model to: /kaggle/working/regnety_080_head_paramfixed.keras

# %% [markdown]
# # **HorNet (Tiny)**

# %%
# ========================
# 0) Install necessary libraries
# ========================
# !pip -q install split-folders keras-cv-attention-models tf-keras

# ========================
# 1) Imports, seeds, TF runtime setup
# ========================
import os, shutil, random, time, math, itertools, hashlib
os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"      # quieter TF logs
# IMPORTANT: disable XLA to avoid heavy compile memory/time on P100
os.environ["TF_XLA_FLAGS"] = ""               # ensure no XLA JIT from env
# IMPORTANT for keras-cv-attention-models on TF backend / mixed Keras stacks
os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tensorflow as tf

# Deterministic-ish runs to reduce jitter
SEED = 42
random.seed(SEED)
import numpy as np
np.random.seed(SEED)
tf.random.set_seed(SEED)

# GPU memory growth: prevents big upfront allocation + restart
gpus = tf.config.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus: tf.config.experimental.set_memory_growth(gpu, True)
    except Exception as e:
        print("Memory growth setting failed:", e)

import cv2
import matplotlib.pyplot as plt
from pathlib import Path
import splitfolders
from collections import defaultdict

# ========================
# 2) Locate data, flatten, split
# ========================
CANDIDATES = [
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Training"),
    Path("/kaggle/input/brain-tumor-mri-dataset/Brain Tumor MRI Dataset"),
    Path("/kaggle/input/brain-tumor-mri-dataset"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/ct-kidney-dataset-normal-cyst-tumor-and-stone/CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone"),
    Path("/kaggle/input/skin-cancer-disease-dataset/Skin Disease Classification Dataset/New folder"),
    Path("/kaggle/input/skin-disease-123456/New folder"),
]

def looks_like_class_root(p: Path) -> bool:
    if not p.exists() or not p.is_dir(): return False
    subdirs = [d for d in p.iterdir() if d.is_dir()]
    return len(subdirs) >= 2

SRC = None
for p in CANDIDATES:
    if looks_like_class_root(p):
        SRC = p; break

if SRC is None:
    for p in Path("/kaggle/input").rglob("New folder"):
        if looks_like_class_root(p):
            SRC = p; break

if SRC is None:
    for patt in ["CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone", "CT_KIDNEY_DATASET", "ct_kidney"]:
        for p in Path("/kaggle/input").rglob(patt):
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

if SRC is None:
    brain_patterns = [
        "Brain Tumor MRI Dataset", "brain-tumor-mri-dataset",
        "brain_tumor_mri_dataset", "brain-tumor-mri", "Brain-Tumor-MRI-Dataset"
    ]
    for patt in brain_patterns:
        for p in Path("/kaggle/input").rglob(patt):
            if (p / "Training").exists():
                tr = p / "Training"
                subs = [d for d in tr.iterdir() if d.is_dir()]
                if len(subs) >= 2:
                    SRC = tr; break
            if looks_like_class_root(p):
                SRC = p; break
        if SRC is not None: break

assert SRC is not None and SRC.exists(), "Couldn't find the dataset root."

FLAT = Path("/kaggle/working/_flat_classes")
OUT  = Path("/kaggle/working/skin_split")
IMG_EXT = {".jpg", ".jpeg", ".png", ".bmp", ".tif", ".tiff", ".gif"}

print("Class root:", SRC)
print("Top-level classes:")
classes_src = [p for p in SRC.iterdir() if p.is_dir()]
for c in sorted(classes_src): print(" -", c.name)

# Brain Tumor MRI special handling
def _norm(s: str) -> str:
    return s.lower().replace('-', '_').replace(' ', '_')

def is_bt_class_name(name: str) -> bool:
    s = _norm(name)
    return s in {"glioma", "meningioma", "pituitary", "no_tumor",
                 "glioma_tumor", "meningioma_tumor", "pituitary_tumor",
                 "notumor", "no", "no_tumour"}

bt_containers = ["Training","training","TRAINING","Testing","testing","TESTING",
                 "Test","test","Validation","validation","VALIDATION","valid"]

bt_class_dirs = []
for cont in bt_containers:
    p = SRC / cont
    if p.exists() and p.is_dir():
        for d in p.iterdir():
            if d.is_dir() and (is_bt_class_name(d.name) or any(f.is_file() and f.suffix.lower() in IMG_EXT for f in d.rglob("*"))):
                bt_class_dirs.append(d)

if not bt_class_dirs and any(is_bt_class_name(d.name) for d in classes_src):
    bt_class_dirs = [d for d in classes_src if d.is_dir() and is_bt_class_name(d.name)]

if bt_class_dirs:
    print("\n[Brain Tumor MRI] Using these class folders:")
    for d in sorted(bt_class_dirs): print(" -", d.as_posix())
    classes_src = bt_class_dirs

# Flatten with simple near-duplicate removal (per class)
if FLAT.exists(): shutil.rmtree(FLAT)
FLAT.mkdir(parents=True, exist_ok=True)

def ahash(img_path, size=8):
    img = cv2.imread(str(img_path), cv2.IMREAD_GRAYSCALE)
    if img is None: return None
    img = cv2.resize(img, (size, size))
    avg = img.mean()
    bits = (img > avg).astype(np.uint8).flatten()
    return hashlib.sha1(bits.tobytes()).hexdigest()

seen_hashes = defaultdict(set)
write_counters = defaultdict(int)
total = 0
for cls_dir in sorted(classes_src):
    cls_name = cls_dir.name
    n = _norm(cls_name)
    if n in {"glioma_tumor","glioma"}: cls_name = "glioma"
    elif n in {"meningioma_tumor","meningioma"}: cls_name = "meningioma"
    elif n in {"pituitary_tumor","pituitary"}: cls_name = "pituitary"
    elif n in {"notumor","no","no_tumour","no_tumor"}: cls_name = "no_tumor"

    dst = FLAT / cls_name
    dst.mkdir(parents=True, exist_ok=True)

    local_count = 0; dup_skips = 0
    for f in cls_dir.rglob("*"):
        if f.is_file() and f.suffix.lower() in IMG_EXT:
            h = ahash(f)
            if h is not None and h in seen_hashes[cls_name]:
                dup_skips += 1; continue
            if h is not None: seen_hashes[cls_name].add(h)
            write_counters[cls_name] += 1
            local_count += 1
            out_path = dst / f"{cls_name}__{write_counters[cls_name]:06d}{f.suffix.lower()}"
            shutil.copy2(str(f), str(out_path))
    print(f"Collected {local_count:5d} (skipped dup {dup_skips:4d}) from {cls_dir.name} → '{cls_name}'")
    total += local_count

print("\nFinal per-class image counts:")
for d in sorted(FLAT.iterdir()):
    if d.is_dir():
        n = sum(1 for _ in d.iterdir() if _.is_file())
        print(f" - {d.name}: {n}")
print(f"\nTotal images collected: {total}")
assert total > 0, "No images found."

# Split (image-wise split; param count is independent of image size)
if OUT.exists(): shutil.rmtree(OUT)
OUT.mkdir(parents=True, exist_ok=True)
splitfolders.ratio(str(FLAT), str(OUT), seed=SEED, ratio=(.9, .1), group_prefix=None, move=False)

train_dir = OUT / "train"
val_dir   = OUT / "val"
print(f"\nSanity: train files = {sum(1 for _ in train_dir.rglob('*') if _.is_file())}")
print(f"Sanity: val   files = {sum(1 for _ in val_dir.rglob('*')   if _.is_file())}")

# ========================
# 3) Quick grid of samples
# ========================
classes = sorted([d.name for d in train_dir.iterdir() if d.is_dir()])
rows, cols = 2, max(1, len(classes))
rng = random.Random(SEED)
fig, axes = plt.subplots(rows, cols, figsize=(max(cols, 2)*3.0, rows*3.0), squeeze=False, constrained_layout=True)
fig.suptitle("LABELS OF EACH IMAGE", fontsize=14)
for c_idx, cls in enumerate(classes):
    cls_path = train_dir / cls
    files = [f for f in cls_path.rglob("*") if f.is_file() and f.suffix.lower() in IMG_EXT]
    picks = rng.sample(files, min(2, len(files))) if files else []
    if len(picks) == 1: picks = [picks[0], picks[0]]
    axes[0, c_idx].set_title(cls, fontsize=11)
    for r_idx in range(rows):
        ax = axes[r_idx, c_idx]
        ax.set_xticks([]); ax.set_yticks([]); ax.grid(False)
        if r_idx < len(picks):
            img = cv2.imread(str(picks[r_idx]))
            if img is not None:
                img = cv2.resize(img, (224, 224))
                ax.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            else:
                ax.axis("off")
        else:
            ax.axis("off")
plt.show()

print("\nTrain dir for next cell:", train_dir)
print("Val   dir for next cell:", val_dir)

# ========================
# 4) Training setup
# ========================
import seaborn as sns
from collections import Counter
from sklearn.metrics import confusion_matrix, classification_report
from tensorflow.keras.models import Model
from tensorflow.keras.layers import (
    GlobalAveragePooling2D, Dense, Dropout, BatchNormalization, Activation,
    GaussianNoise, Input, Reshape, Multiply, Layer, Concatenate, MaxPooling2D, Conv2D
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, Callback
from tensorflow.keras.activations import gelu

# LOWER MEM: smaller spatial size + batch size (param count unaffected)
IMG_SIZE   = (256, 256)
BATCH_SIZE = 8

INIT_LR    = 3e-4
WEIGHT_DECAY = 1e-4
LABEL_SMOOTH = 0.05
EPOCHS     = 50
USE_MIXED_PRECISION = True
if USE_MIXED_PRECISION:
    from tensorflow.keras import mixed_precision
    mixed_precision.set_global_policy("mixed_float16")

# Gentler aug knobs (annealed later)
ERASE_P = [0.00]; CLAHE_P = [0.00]; MIXUP_P = [0.00]; CUTMIX_P = [0.00]

def apply_clahe_rgb(x_float01):
    img8 = (np.clip(x_float01, 0, 1) * 255.0).astype(np.uint8)
    lab = cv2.cvtColor(img8, cv2.COLOR_RGB2LAB)
    L, A, B = cv2.split(lab)
    L = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8)).apply(L)
    rgb = cv2.cvtColor(cv2.merge([L, A, B]), cv2.COLOR_LAB2RGB)
    return rgb.astype(np.float32) / 255.0

def random_erasing(x, p=0.12, s=(0.02, 0.10), r=(0.3, 3.3)):
    if np.random.rand() > p: return x
    h, w, c = x.shape
    Se = np.random.uniform(s[0], s[1]) * h * w
    re = np.random.uniform(r[0], r[1])
    He = max(1, int(np.sqrt(Se * re))); We = max(1, int(np.sqrt(Se / re)))
    xe = np.random.randint(0, max(1, h - He + 1))
    ye = np.random.randint(0, max(1, w - We + 1))
    x[xe:xe+He, ye:ye+We, :] = np.random.uniform(0, 1, size=(He, We, c))
    return x

def training_preprocess(x):
    if np.random.rand() < CLAHE_P[0]: x = apply_clahe_rgb(x)
    if ERASE_P[0] > 0: x = random_erasing(x, p=ERASE_P[0])
    return x

train_datagen = ImageDataGenerator(
    rescale=1./255, zoom_range=0.20, horizontal_flip=True,
    rotation_range=10, width_shift_range=0.08, height_shift_range=0.08,
    shear_range=6, brightness_range=(0.92, 1.10), fill_mode='nearest',
    preprocessing_function=training_preprocess
)
val_datagen_plain = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_directory(
    directory=str(train_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=True
)
val_gen = val_datagen_plain.flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)

num_classes = train_gen.num_classes
class_indices = train_gen.class_indices
print("Classes:", class_indices)

counts = Counter(train_gen.classes)
total_imgs = sum(counts.values())
class_weight = {i: total_imgs / (num_classes * counts[i]) for i in range(num_classes)}
print("Class counts:", dict(counts))
print("Class weights:", class_weight)

# ========================
# 5) HorNet (Tiny) backbone + exact-param head
# ========================
class SqueezeExcite(Layer):
    def __init__(self, ratio=16, **kwargs):
        super().__init__(**kwargs); self.ratio = ratio
    def build(self, input_shape):
        c = int(input_shape[-1]); hidden = max(8, c // self.ratio)
        self.fc1 = Dense(hidden, activation='relu'); self.fc2 = Dense(c, activation='sigmoid')
        super().build(input_shape)
    def call(self, x):
        s = GlobalAveragePooling2D()(x); s = self.fc1(s); s = self.fc2(s)
        s = Reshape((1,1,-1))(s); return Multiply()([x, s])

class SpatialGate(Layer):
    def __init__(self, **kwargs):
        super().__init__(**kwargs); self.conv=None
    def build(self, input_shape):
        self.conv = Conv2D(1, kernel_size=7, padding="same", use_bias=True)
        super().build(input_shape)
    def call(self, x):
        avg = tf.reduce_mean(x, axis=-1, keepdims=True)
        mx  = tf.reduce_max(x,  axis=-1, keepdims=True)
        s   = Concatenate(axis=-1)([avg, mx])
        s   = self.conv(s); s = tf.nn.sigmoid(s)
        return Multiply()([x, s])

class ParamPad(Layer):
    def __init__(self, n_params=0, **kwargs):
        super().__init__(**kwargs); self.n_params = int(n_params)
    def build(self, input_shape):
        if self.n_params > 0:
            self.pad_w = self.add_weight(
                name="param_pad", shape=(self.n_params,),
                initializer="zeros", trainable=True, dtype=self.dtype
            )
        super().build(input_shape)
    def call(self, x):
        if hasattr(self, "pad_w"): return x + tf.reduce_sum(self.pad_w) * tf.cast(0.0, x.dtype)
        return x

def _trainable_params_count(model):
    return int(np.sum([np.prod(w.shape) for w in model.trainable_weights]))
def _desired_param_count(): return int("1461587")

def build_model_with_hornet_tiny(num_classes, img_size):
    inputs = Input(shape=(img_size[0], img_size[1], 3), name="input")
    x = GaussianNoise(0.01)(inputs)
    # HorNet Tiny from keras-cv-attention-models
    try:
        from keras_cv_attention_models import hornet
        backbone = hornet.HorNetTiny(input_shape=(img_size[0], img_size[1], 3),
                                     num_classes=0, pretrained="imagenet")
        print("[INFO] Using HorNetTiny backbone from keras-cv-attention-models.")
    except Exception as e:
        # Fallback to ConvNeXt Tiny (still fine as a comparable conv-style backbone)
        print("[WARN] HorNetTiny not available, falling back to ConvNeXt Tiny. Error:", e)
        try:
            from keras_cv_attention_models import convnext
            backbone = convnext.ConvNeXtTiny(input_shape=(img_size[0], img_size[1], 3),
                                             num_classes=0, pretrained="imagenet")
        except Exception:
            from tensorflow.keras.applications import convnext as tf_convnext
            backbone = tf_convnext.ConvNeXtTiny(include_top=False, weights="imagenet",
                                                input_shape=(img_size[0], img_size[1], 3))
    backbone.trainable = False

    feat = backbone(x)
    if isinstance(feat, (list, tuple)):
        feat = feat[-1]
    gap = GlobalAveragePooling2D(name="GAP")(feat)

    # lightweight head (small so we can pad to exact target)
    xh = Dense(256, use_bias=True)(gap)
    xh = Activation(gelu)(xh)
    xh = Dropout(0.35)(xh)
    out_logits = Dense(num_classes, activation='softmax', dtype='float32', name="predictions")(xh)

    model = Model(inputs, out_logits, name=f"hornet_tiny_head")

    # Enforce EXACT trainable params = 1,461,587
    TARGET = _desired_param_count()
    base_trainables = _trainable_params_count(model)
    print(f"[ParamTarget] Trainable BEFORE pad: {base_trainables:,}")
    if base_trainables > TARGET:
        raise ValueError(f"Base ({base_trainables}) exceeds TARGET ({TARGET}). Reduce head width.")
    need = TARGET - base_trainables
    if need > 0:
        out2 = ParamPad(n_params=need, name="param_pad")(out_logits)
        model = Model(inputs, out2, name=model.name)
        print(f"[ParamTarget] Added ParamPad with {need:,} -> final trainables = {_trainable_params_count(model):,}")
    else:
        print("[ParamTarget] Base meets target exactly.")
    return model

# Clear any old graph (helps on notebook reruns)
tf.keras.backend.clear_session()
model = build_model_with_hornet_tiny(num_classes, IMG_SIZE)
model.summary()

# ========================
# 6) Optimizer, schedule, loss  (FIXED dtype mismatch for mixed precision)
# ========================
@tf.keras.utils.register_keras_serializable(package="Custom")
class WarmupCosine(tf.keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, base_lr=3e-4, warmup_steps=1000, decay_steps=10000, min_lr=1e-6, name=None):
        super().__init__()
        self.base_lr=float(base_lr); self.warmup_steps=int(warmup_steps)
        self.decay_steps=int(decay_steps); self.min_lr=float(min_lr); self.name=name or "WarmupCosine"
    def __call__(self, step):
        step = tf.cast(step, tf.float32)
        warm = tf.minimum(1.0, step / float(self.warmup_steps))
        prog = tf.minimum(1.0, tf.maximum(0.0, (step - self.warmup_steps) / float(self.decay_steps)))
        cosine = 0.5 * (1.0 + tf.cos(np.pi * prog))
        return self.min_lr + (self.base_lr - self.min_lr) * warm * cosine
    def get_config(self):
        return {"base_lr":self.base_lr,"warmup_steps":self.warmup_steps,"decay_steps":self.decay_steps,
                "min_lr":self.min_lr,"name":self.name}

steps_per_epoch = len(train_gen)
total_steps  = steps_per_epoch * EPOCHS
warmup_steps = int(0.10 * total_steps)
decay_steps  = max(1, total_steps - warmup_steps)

lr_schedule = WarmupCosine(base_lr=INIT_LR, warmup_steps=warmup_steps, decay_steps=decay_steps, min_lr=1e-6)
opt = tf.keras.optimizers.AdamW(learning_rate=lr_schedule, weight_decay=WEIGHT_DECAY, global_clipnorm=1.0)

@tf.keras.utils.register_keras_serializable(package="Custom", name="CCEWithDynamicSmoothing")
def cce_with_dynamic_smoothing(y_true, y_pred):
    # ---- FIX: ensure consistent dtype under mixed precision ----
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    eps = tf.cast(smooth_var, tf.float32)
    k = tf.cast(tf.shape(y_true)[-1], tf.float32)
    y_true_smooth = (1.0 - eps) * y_true + eps / k
    return tf.keras.losses.categorical_crossentropy(y_true_smooth, y_pred)

smooth_var = tf.Variable(LABEL_SMOOTH, trainable=False, dtype=tf.float32)
model.compile(optimizer=opt, loss=cce_with_dynamic_smoothing, metrics=['accuracy'])

# ========================
# 7) MixUp / CutMix (aligned)
# ========================
def _sample_batch_idx(gen, idx):
    x, y = gen[idx]
    return x.astype(np.float32), y.astype(np.float32)

def _align_batches(a, b):
    ax, ay = a; bx, by = b
    n = min(ax.shape[0], bx.shape[0])
    if n < 2: return (ax, ay), None
    return (ax[:n], ay[:n]), (bx[:n], by[:n])

def _mixup_aligned(a, b, alpha=0.3):
    (ax, ay), (bx, by) = a, b
    lam = np.random.beta(alpha, alpha)
    x = lam*ax + (1-lam)*bx
    y = lam*ay + (1-lam)*by
    return x, y

def _cutmix_aligned(a, b):
    (ax, ay), (bx, by) = a, b
    bs, h, w, c = ax.shape
    rx = np.random.randint(w//8, w - w//8)
    ry = np.random.randint(h//8, h - h//8)
    rw = np.random.randint(w//8, w//3)
    rh = np.random.randint(h//8, h//3)
    x = ax.copy()
    x[:, ry:ry+rh, rx:rx+rw, :] = bx[:, ry:ry+rh, rx:rx+rw, :]
    lam_adj = 1.0 - (rw*rh)/(w*h)
    y = lam_adj*ay + (1-lam_adj)*by
    return x, y

class MixGenSequence(tf.keras.utils.Sequence):
    def __init__(self, base_gen, prob_mixup_ref, prob_cutmix_ref, **kwargs):
        super().__init__(**kwargs)
        self.base = base_gen
        self.length = len(base_gen)
        self.batch_size = base_gen.batch_size
        self.num_classes = base_gen.num_classes
        self.prob_mixup_ref = prob_mixup_ref
        self.prob_cutmix_ref = prob_cutmix_ref
    def __len__(self): return self.length
    def __getitem__(self, idx):
        a = _sample_batch_idx(self.base, idx % self.length)
        r = np.random.rand()
        pmx = self.prob_mixup_ref[0]; pcm = self.prob_cutmix_ref[0]
        if r < (pcm + pmx):
            idx2 = (idx + np.random.randint(1, self.length)) % self.length
            b = _sample_batch_idx(self.base, idx2)
            a_aligned, b_aligned = _align_batches(a, b)
            if b_aligned is None: return a
            if r < pcm: return _cutmix_aligned(a_aligned, b_aligned)
            else:       return _mixup_aligned(a_aligned, b_aligned, alpha=0.3)
        else:
            return a
    def on_epoch_end(self):
        if hasattr(self.base, 'on_epoch_end'): self.base.on_epoch_end()

MIXUP_P = [0.00]; CUTMIX_P = [0.00]; ERASE_P = [0.00]; CLAHE_P = [0.00]
mix_train = MixGenSequence(train_gen, MIXUP_P, CUTMIX_P)

# ========================
# 8) Callbacks (simplified for stability)
# ========================
early_stop = EarlyStopping(monitor='val_accuracy', patience=12, restore_best_weights=True, verbose=1)
ckpt_std_path = "/kaggle/working/best_hornet_tiny.keras"
ckpt_std  = ModelCheckpoint(ckpt_std_path, monitor='val_accuracy', save_best_only=True,
                            save_weights_only=False, verbose=1)

class AnnealEverything(Callback):
    # gentler schedule reduces big swings
    def __init__(self, start_epoch=2, mid_epoch=10, end_epoch=36):
        super().__init__(); self.start=start_epoch; self.mid=mid_epoch; self.end=end_epoch
    def on_epoch_begin(self, epoch, logs=None):
        if epoch < self.start:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(LABEL_SMOOTH)
        elif epoch < self.mid:
            MIXUP_P[0]=0.15; CUTMIX_P[0]=0.15; ERASE_P[0]=0.08; CLAHE_P[0]=0.06
            smooth_var.assign(0.05)
        elif epoch < self.end:
            MIXUP_P[0]=0.25; CUTMIX_P[0]=0.25; ERASE_P[0]=0.12; CLAHE_P[0]=0.08
            smooth_var.assign(0.03)
        else:
            MIXUP_P[0]=0.0;  CUTMIX_P[0]=0.0;  ERASE_P[0]=0.0;  CLAHE_P[0]=0.0
            smooth_var.assign(0.0)

anneal_cb = AnnealEverything()

# ========================
# 9) Train
# ========================
history = model.fit(
    mix_train,
    validation_data=val_gen,
    epochs=EPOCHS,
    callbacks=[anneal_cb, early_stop, ckpt_std],
    class_weight=class_weight,
    verbose=1
)

# Curves
plt.figure(figsize=(8,5)); plt.plot(history.history['accuracy'], label='Train Acc', marker='o')
plt.plot(history.history['val_accuracy'], label='Val Acc', marker='o')
plt.title('Accuracy'); plt.xlabel('Epoch'); plt.ylabel('Accuracy'); plt.legend(); plt.show()
plt.figure(figsize=(8,5)); plt.plot(history.history['loss'], label='Train Loss', marker='o')
plt.plot(history.history['val_loss'], label='Val Loss', marker='o')
plt.title('Loss'); plt.xlabel('Epoch'); plt.ylabel('Loss'); plt.legend(); plt.show()

# ========================
# 10) Light evaluation (memory-safe): current best-restored model + 5x TTA (streamed)
# ========================
print("\nEvaluating best-restored model (no reload to avoid custom-objects issues):")
std_model = model  # EarlyStopping restored best weights

from tensorflow.keras.preprocessing.image import ImageDataGenerator
val_gen_plain = ImageDataGenerator(rescale=1./255).flow_from_directory(
    directory=str(val_dir), target_size=IMG_SIZE, batch_size=BATCH_SIZE,
    class_mode='categorical', shuffle=False
)
labels = list(val_gen_plain.class_indices.keys())
y_true = val_gen_plain.classes

# streamed TTA (no pre-staging arrays)
def tta_preds(model, base_gen, tta_list):
    N = len(base_gen.filenames)
    prob_sum = np.zeros((N, base_gen.num_classes), dtype=np.float32)
    idx0 = 0
    for i in range(len(base_gen)):
        x, _ = base_gen[i]
        bs = x.shape[0]
        acc = np.zeros((bs, base_gen.num_classes), dtype=np.float32)
        for fn in tta_list:
            if fn is None:
                xb = x
            else:
                xb = np.stack([fn(img) for img in x], axis=0).astype(np.float32)
            p = model.predict(xb, verbose=0)
            acc += p.astype(np.float32)
        acc /= float(len(tta_list))
        prob_sum[idx0:idx0+bs] = acc
        idx0 += bs
    return prob_sum

# modest set of TTA ops (kept small for stability + speed)
def tta_hflip(x): return np.ascontiguousarray(np.flip(x, axis=1))
def tta_rotate(x, deg=8):
    h, w = x.shape[:2]; M = cv2.getRotationMatrix2D((w/2, h/2), deg, 1.0)
    return cv2.warpAffine(x, M, (w, h), borderMode=cv2.BORDER_REFLECT_101)
def tta_gamma(x, gamma=1.05):
    x = np.clip(x, 0, 1); return np.power(x, 1.0/gamma)

tta_list = [None, tta_hflip, lambda x: tta_rotate(x, +8), lambda x: tta_rotate(x, -8), lambda x: tta_gamma(x, 1.05)]

probs = tta_preds(std_model, val_gen_plain, tta_list)
y_pred = probs.argmax(axis=1)
acc = (y_pred == y_true).mean()
print(f"\nValidation accuracy (HorNetTiny + 5xTTA): {acc*100:.2f}%")

# Confusion matrix & report
cm_val = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(1.2*len(labels), 1.0*len(labels)))
sns.heatmap(cm_val, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)
plt.xlabel('Predicted'); plt.ylabel('Actual'); plt.title('Confusion Matrix (VAL, HorNetTiny+TTA)'); plt.show()
print("\nClassification Report (VAL, HorNetTiny+TTA):\n")
print(classification_report(y_true, y_pred, target_names=labels, digits=4))

# ========================
# 11) Save final model
# ========================
final_model_path = "/kaggle/working/hornet_tiny_head_paramfixed.keras"
std_model.save(final_model_path)
print("Saved base model to:", final_model_path)
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.0/190.0 kB 4.7 MB/s eta 0:00:00a 0:00:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.6/802.6 kB 26.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 3.1 MB/s eta 0:00:00
# 2025-10-04 14:20:32.850865: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1759587633.040121      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1759587633.109713      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Class root: /kaggle/input/brain-tumor-mri-dataset/Training
# Top-level classes:
#  - glioma
#  - meningioma
#  - notumor
#  - pituitary
#
# [Brain Tumor MRI] Using these class folders:
#  - /kaggle/input/brain-tumor-mri-dataset/Training/glioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/meningioma
#  - /kaggle/input/brain-tumor-mri-dataset/Training/notumor
#  - /kaggle/input/brain-tumor-mri-dataset/Training/pituitary
# Collected  1196 (skipped dup  125) from glioma → 'glioma'
# Collected  1246 (skipped dup   93) from meningioma → 'meningioma'
# Collected   920 (skipped dup  675) from notumor → 'no_tumor'
# Collected  1440 (skipped dup   17) from pituitary → 'pituitary'
#
# Final per-class image counts:
#  - glioma: 1196
#  - meningioma: 1246
#  - no_tumor: 920
#  - pituitary: 1440
#
# Total images collected: 4802
# Copying files: 4802 files [00:00, 7613.12 files/s]
# Sanity: train files = 4321
# Sanity: val   files = 481
# Train dir for next cell: /kaggle/working/skin_split/train
# Val   dir for next cell: /kaggle/working/skin_split/val
# Found 4321 images belonging to 4 classes.
# Found 481 images belonging to 4 classes.
# Classes: {'glioma': 0, 'meningioma': 1, 'no_tumor': 2, 'pituitary': 3}
# Class counts: {0: 1076, 1: 1121, 2: 828, 3: 1296}
# Class weights: {0: 1.003949814126394, 1: 0.9636485280999108, 2: 1.3046497584541064, 3: 0.8335262345679012}
# I0000 00:00:1759587692.176218      36 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Downloading data from https://github.com/leondgarse/keras_cv_attention_models/releases/download/hornet/hornet_tiny_224_imagenet.h5
# 91083520/91083520 [==============================] - 3s 0us/step
# >>>> Load pretrained from: /root/.keras/models/hornet_tiny_224_imagenet.h5
# >>>> Reload mismatched weights: 224 -> (256, 256)
# [INFO] Using HorNetTiny backbone from keras-cv-attention-models.
# [ParamTarget] Trainable BEFORE pad: 132,356
# [ParamTarget] Added ParamPad with 1,329,231 -> final trainables = 1,461,587
# Model: "hornet_tiny_head"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 256, 256, 3)]     0
#
#  gaussian_noise (GaussianNo  (None, 256, 256, 3)       0
#  ise)
#
#  hornet_tiny (Functional)    (None, 8, 8, 512)         21895488
#
#  GAP (GlobalAveragePooling2  (None, 512)               0
#  D)
#
#  dense (Dense)               (None, 256)               131328
#
#  activation (Activation)     (None, 256)               0
#
#  dropout (Dropout)           (None, 256)               0
#
#  predictions (Dense)         (None, 4)                 1028
#
#  param_pad (ParamPad)        (None, 4)                 1329231
#
# =================================================================
# Total params: 23357075 (89.10 MB)
# Trainable params: 1461587 (5.58 MB)
# Non-trainable params: 21895488 (83.52 MB)
# _________________________________________________________________
# Epoch 1/50
# I0000 00:00:1759587734.467490     104 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   2/541 [..............................] - ETA: 40s - loss: 2.3331 - accuracy: 0.1875
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1759587738.264060     106 service.cc:148] XLA service 0x797abe571070 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1759587738.264697     106 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# I0000 00:00:1759587738.445768     106 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 541/541 [==============================] - ETA: 0s - loss: 1.6401 - accuracy: 0.3826
# Epoch 1: val_accuracy improved from -inf to 0.57588, saving model to /kaggle/working/best_hornet_tiny.keras
# 541/541 [==============================] - 124s 169ms/step - loss: 1.6401 - accuracy: 0.3826 - val_loss: 1.0354 - val_accuracy: 0.5759
# Epoch 2/50
# 541/541 [==============================] - ETA: 0s - loss: 0.8611 - accuracy: 0.6827
# Epoch 2: val_accuracy improved from 0.57588 to 0.60707, saving model to /kaggle/working/best_hornet_tiny.keras
# 541/541 [==============================] - 83s 154ms/step - loss: 0.8611 - accuracy: 0.6827 - val_loss: 1.0292 - val_accuracy: 0.6071
# Epoch 3/50
# 541/541 [==============================] - ETA: 0s - loss: 0.8084 - accuracy: 0.7299
# Epoch 3: val_accuracy improved from 0.60707 to 0.66112, saving model to /kaggle/working/best_hornet_tiny.keras
# 541/541 [==============================] - 103s 190ms/step - loss: 0.8084 - accuracy: 0.7299 - val_loss: 0.8712 - val_accuracy: 0.6611
# Epoch 4/50
# 541/541 [==============================] - ETA: 0s - loss: 0.7273 - accuracy: 0.7746
# Epoch 4: val_accuracy improved from 0.66112 to 0.72557, saving model to /kaggle/working/best_hornet_tiny.keras
# 541/541 [==============================] - 103s 191ms/step - loss: 0.7273 - accuracy: 0.7746 - val_loss: 0.8072 - val_accuracy: 0.7256
# Epoch 5/50
# 541/541 [==============================] - ETA: 0s - loss: 0.7054 - accuracy: 0.7760
# Epoch 5: val_accuracy did not improve from 0.72557
# 541/541 [==============================] - 99s 184ms/step - loss: 0.7054 - accuracy: 0.7760 - val_loss: 0.8144 - val_accuracy: 0.6985
# Epoch 6/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6787 - accuracy: 0.7922
# Epoch 6: val_accuracy improved from 0.72557 to 0.77547, saving model to /kaggle/working/best_hornet_tiny.keras
# 541/541 [==============================] - 105s 194ms/step - loss: 0.6787 - accuracy: 0.7922 - val_loss: 0.6779 - val_accuracy: 0.7755
# Epoch 7/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6469 - accuracy: 0.8005
# Epoch 7: val_accuracy did not improve from 0.77547
# 541/541 [==============================] - 102s 188ms/step - loss: 0.6469 - accuracy: 0.8005 - val_loss: 0.7386 - val_accuracy: 0.7484
# Epoch 8/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6307 - accuracy: 0.8132
# Epoch 8: val_accuracy did not improve from 0.77547
# 541/541 [==============================] - 102s 188ms/step - loss: 0.6307 - accuracy: 0.8132 - val_loss: 0.7784 - val_accuracy: 0.7422
# Epoch 9/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6276 - accuracy: 0.8179
# Epoch 9: val_accuracy did not improve from 0.77547
# 541/541 [==============================] - 101s 187ms/step - loss: 0.6276 - accuracy: 0.8179 - val_loss: 0.7098 - val_accuracy: 0.7526
# Epoch 10/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6308 - accuracy: 0.8156
# Epoch 10: val_accuracy did not improve from 0.77547
# 541/541 [==============================] - 101s 187ms/step - loss: 0.6308 - accuracy: 0.8156 - val_loss: 0.7805 - val_accuracy: 0.7256
# Epoch 11/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6112 - accuracy: 0.8116
# Epoch 11: val_accuracy improved from 0.77547 to 0.78378, saving model to /kaggle/working/best_hornet_tiny.keras
# 541/541 [==============================] - 118s 218ms/step - loss: 0.6112 - accuracy: 0.8116 - val_loss: 0.6360 - val_accuracy: 0.7838
# Epoch 12/50
# 541/541 [==============================] - ETA: 0s - loss: 0.6176 - accuracy: 0.8186
# Epoch 12: val_accuracy improved from 0.78378 to 0.79834, saving model to /kaggle/working/best_hornet_tiny.keras
# 541/541 [==============================] - 120s 221ms/step - loss: 0.6176 - accuracy: 0.8186 - val_loss: 0.5717 - val_accuracy: 0.7983
# Epoch 13/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5758 - accuracy: 0.8287
# Epoch 13: val_accuracy did not improve from 0.79834
# 541/541 [==============================] - 113s 208ms/step - loss: 0.5758 - accuracy: 0.8287 - val_loss: 0.6950 - val_accuracy: 0.7734
# Epoch 14/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5828 - accuracy: 0.8299
# Epoch 14: val_accuracy did not improve from 0.79834
# 541/541 [==============================] - 115s 213ms/step - loss: 0.5828 - accuracy: 0.8299 - val_loss: 0.6662 - val_accuracy: 0.7817
# Epoch 15/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5829 - accuracy: 0.8202
# Epoch 15: val_accuracy did not improve from 0.79834
# 541/541 [==============================] - 112s 207ms/step - loss: 0.5829 - accuracy: 0.8202 - val_loss: 0.6471 - val_accuracy: 0.7692
# Epoch 16/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5753 - accuracy: 0.8292
# Epoch 16: val_accuracy improved from 0.79834 to 0.81497, saving model to /kaggle/working/best_hornet_tiny.keras
# 541/541 [==============================] - 117s 216ms/step - loss: 0.5753 - accuracy: 0.8292 - val_loss: 0.5589 - val_accuracy: 0.8150
# Epoch 17/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5737 - accuracy: 0.8324
# Epoch 17: val_accuracy did not improve from 0.81497
# 541/541 [==============================] - 114s 211ms/step - loss: 0.5737 - accuracy: 0.8324 - val_loss: 0.6262 - val_accuracy: 0.7734
# Epoch 18/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5900 - accuracy: 0.8193
# Epoch 18: val_accuracy did not improve from 0.81497
# 541/541 [==============================] - 116s 214ms/step - loss: 0.5900 - accuracy: 0.8193 - val_loss: 0.5807 - val_accuracy: 0.7963
# Epoch 19/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5599 - accuracy: 0.8368
# Epoch 19: val_accuracy improved from 0.81497 to 0.82952, saving model to /kaggle/working/best_hornet_tiny.keras
# 541/541 [==============================] - 118s 217ms/step - loss: 0.5599 - accuracy: 0.8368 - val_loss: 0.5468 - val_accuracy: 0.8295
# Epoch 20/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5619 - accuracy: 0.8477
# Epoch 20: val_accuracy did not improve from 0.82952
# 541/541 [==============================] - 115s 213ms/step - loss: 0.5619 - accuracy: 0.8477 - val_loss: 0.6105 - val_accuracy: 0.7859
# Epoch 21/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5694 - accuracy: 0.8336
# Epoch 21: val_accuracy did not improve from 0.82952
# 541/541 [==============================] - 116s 214ms/step - loss: 0.5694 - accuracy: 0.8336 - val_loss: 0.5911 - val_accuracy: 0.7921
# Epoch 22/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5385 - accuracy: 0.8436
# Epoch 22: val_accuracy did not improve from 0.82952
# 541/541 [==============================] - 111s 206ms/step - loss: 0.5385 - accuracy: 0.8436 - val_loss: 0.6597 - val_accuracy: 0.7734
# Epoch 23/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5707 - accuracy: 0.8299
# Epoch 23: val_accuracy did not improve from 0.82952
# 541/541 [==============================] - 115s 213ms/step - loss: 0.5707 - accuracy: 0.8299 - val_loss: 0.6403 - val_accuracy: 0.7942
# Epoch 24/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5651 - accuracy: 0.8315
# Epoch 24: val_accuracy did not improve from 0.82952
# 541/541 [==============================] - 117s 216ms/step - loss: 0.5651 - accuracy: 0.8315 - val_loss: 0.5866 - val_accuracy: 0.8108
# Epoch 25/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5460 - accuracy: 0.8466
# Epoch 25: val_accuracy did not improve from 0.82952
# 541/541 [==============================] - 114s 211ms/step - loss: 0.5460 - accuracy: 0.8466 - val_loss: 0.6303 - val_accuracy: 0.7879
# Epoch 26/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5339 - accuracy: 0.8514
# Epoch 26: val_accuracy did not improve from 0.82952
# 541/541 [==============================] - 114s 210ms/step - loss: 0.5339 - accuracy: 0.8514 - val_loss: 0.5735 - val_accuracy: 0.8191
# Epoch 27/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5257 - accuracy: 0.8540
# Epoch 27: val_accuracy did not improve from 0.82952
# 541/541 [==============================] - 113s 209ms/step - loss: 0.5257 - accuracy: 0.8540 - val_loss: 0.5887 - val_accuracy: 0.8046
# Epoch 28/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5157 - accuracy: 0.8604
# Epoch 28: val_accuracy improved from 0.82952 to 0.84407, saving model to /kaggle/working/best_hornet_tiny.keras
# 541/541 [==============================] - 116s 215ms/step - loss: 0.5157 - accuracy: 0.8604 - val_loss: 0.5471 - val_accuracy: 0.8441
# Epoch 29/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5369 - accuracy: 0.8466
# Epoch 29: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 114s 210ms/step - loss: 0.5369 - accuracy: 0.8466 - val_loss: 0.5253 - val_accuracy: 0.8420
# Epoch 30/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5260 - accuracy: 0.8512
# Epoch 30: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 116s 215ms/step - loss: 0.5260 - accuracy: 0.8512 - val_loss: 0.5586 - val_accuracy: 0.8358
# Epoch 31/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5348 - accuracy: 0.8565
# Epoch 31: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 117s 217ms/step - loss: 0.5348 - accuracy: 0.8565 - val_loss: 0.5481 - val_accuracy: 0.8337
# Epoch 32/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5229 - accuracy: 0.8586
# Epoch 32: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 115s 213ms/step - loss: 0.5229 - accuracy: 0.8586 - val_loss: 0.5634 - val_accuracy: 0.8191
# Epoch 33/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5058 - accuracy: 0.8648
# Epoch 33: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 114s 211ms/step - loss: 0.5058 - accuracy: 0.8648 - val_loss: 0.5764 - val_accuracy: 0.8087
# Epoch 34/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5130 - accuracy: 0.8658
# Epoch 34: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 113s 208ms/step - loss: 0.5130 - accuracy: 0.8658 - val_loss: 0.5743 - val_accuracy: 0.8274
# Epoch 35/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5254 - accuracy: 0.8565
# Epoch 35: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 115s 213ms/step - loss: 0.5254 - accuracy: 0.8565 - val_loss: 0.5641 - val_accuracy: 0.8316
# Epoch 36/50
# 541/541 [==============================] - ETA: 0s - loss: 0.5209 - accuracy: 0.8600
# Epoch 36: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 115s 213ms/step - loss: 0.5209 - accuracy: 0.8600 - val_loss: 0.5278 - val_accuracy: 0.8441
# Epoch 37/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 0.9350
# Epoch 37: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 80s 148ms/step - loss: 0.1921 - accuracy: 0.9350 - val_loss: 0.4620 - val_accuracy: 0.8316
# Epoch 38/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1913 - accuracy: 0.9296
# Epoch 38: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 81s 149ms/step - loss: 0.1913 - accuracy: 0.9296 - val_loss: 0.4821 - val_accuracy: 0.8108
# Epoch 39/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9324
# Epoch 39: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 80s 148ms/step - loss: 0.1928 - accuracy: 0.9324 - val_loss: 0.4677 - val_accuracy: 0.8170
# Epoch 40/50
# 541/541 [==============================] - ETA: 0s - loss: 0.1733 - accuracy: 0.9359
# Epoch 40: val_accuracy did not improve from 0.84407
# 541/541 [==============================] - 81s 149ms/step - loss: 0.1733 - accuracy: 0.9359 - val_loss: 0.4984 - val_accuracy: 0.8025
# Epoch 40: early stopping
# Restoring model weights from the end of the best epoch: 28.
# Evaluating best-restored model (no reload to avoid custom-objects issues):
# Found 481 images belonging to 4 classes.
#
# Validation accuracy (HorNetTiny + 5xTTA): 84.62%
# Classification Report (VAL, HorNetTiny+TTA):
#
#               precision    recall  f1-score   support
#
#       glioma     0.9770    0.7083    0.8213       120
#   meningioma     0.7881    0.7440    0.7654       125
#     no_tumor     0.7731    1.0000    0.8720        92
#    pituitary     0.8726    0.9514    0.9103       144
#
#     accuracy                         0.8462       481
#    macro avg     0.8527    0.8509    0.8423       481
# weighted avg     0.8577    0.8462    0.8431       481
#
# Saved base model to: /kaggle/working/hornet_tiny_head_paramfixed.keras
